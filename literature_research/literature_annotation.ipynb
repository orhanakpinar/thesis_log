# %% [markdown]
# ## Literature Annotation Model
#
# Literature annotation plays an important part in forming the study. The researcher, in the beginning, creates a topic abstraction model based on their followed readings and the intention of the research project. The topic structure changes during this process, involving defining, merging, and eliminating the topics that are initially thought of. Hypotheses and arguments are formed by these presumed topics, followed by readings, and the researcher's framework.
#
# Here I defined my initial recuperées for later referencing how my thought process changed. There are some parameters for topic abstraction.
#
# 1. I am trying to keep topic number limited and avoid overloading the annotations with topics. This bias would lead to the underspecification of some annotations.
# 2. Preliminary readings were done throughout the last year. I started with 42 topics for the first recording process. These topics were exported from my first 10 recorded readings using Zotero. Since then, 2 new categories have been added.
# 3. To prevent underspecification, I employ less-used topics for a multi-theoretical approach to the food sovereignty. In general, I tend to use 2-3 categories for defining an annotation with the abstracted topics. I will use mutually referencing topics interchangeably, to not forget the connections in the agri-food system.
# 4. The third part can be considered for multiple topics at the same time, so underspecification will still occur. As said, annotations are kept under a limit of specification, but I wonder if there is a tendency to overspecify initial annotations and underspecify the last ones.
#
#
# Since the beginning:
# - Added topics are: History, TR_Peasant, Rurban
# - Merged topics are:
# - Eliminated topics are:
#
#
#
# Additionally, I packed two categories for implying another category that was not created. Here I used "Variable" and "Interdisciplinary" for indicating qualitative variables. Interdisciplinary on its own shows the socio-theoretical approach for agroecology and food system research.
#
# The use of "Food_Sovereignty" and "Food_Security" in the same annotation indicates the interplay and/or conflict between these theoretical frameworks.
#
# For other less-apparent categories:
# - "Survivorship_bias" indicates the socio-filtering process that is not considered for measuring the effect of agro-policies.
# - "Autonomy" indicates the local sustainability. The meaning of "local" changes similarly to the levels of analysis framework by Waltz(1959); but regarding household, village, town, city, national, or regional boundaries. Food sovereignty theory emphasizes local autonomy, therefore it is both a latent and target variable.

# %%
columns = ["Title", "Citation", "In_Text_Citation", "..."]

Agro_econ = "Agro_econ"
Agro_international = "Agro_international"
Agro_policy = "Agro_policy"
Agro_tech = "Agro_tech"
Agroecology =  "Agroecology"
Autonomy = "Autonomy"
Big_agro = "Big_agro"
Buyuksehir_Law = "Buyuksehir_Law"
Collectives = "Collectives"
Cooperatives = "Cooperatives"
Debt = "Debt"
Deruralization = "Deruralization"
Education = "Education"
Food_Network = "Food_Network"
Food_Security =  "Food_Security"
Food_Sovereignty = "Food_Sovereignty"
Gender =  "Gender"
Health = "Health"
History = "History"
Interdisciplinary = "Interdisciplinary"
Land_Consolidation = "Land_Consolidation"
Land_Policy = "Land_Policy"
Land_Use = "Land_Use"
Methodology = "Methodology"
Migration =  "Migration"
Monoculture = "Monoculture"
Monoculture_Poli = "Monoculture_Poli"
Policy_Access = "Policy_Access"
Risks_Global = "Risks_Global"
Rural_Development = "Rural_Development"
Rural_Family =  "Rural_Family"
Rural_Livelihood = "Rural_Livelihood" 
Rural_Policy =  "Rural_Policy"
Rurban = "Rurban"
Seed =  "Seed"
Shortfood = "Shortfood"
Small_holder = "Small_holder"
Survivorship_bias = "Survivorship_bias"
TR_agroEcon = "TR_agroEcon" 
TR_agroGov = "TR_agroGov"
TR_landUse = "TR_landUse"
TR_ruralGov = "TR_ruralGov"
TR_Peasant = "TR_Peasant"
Urbanization = "Urbanization"
Variable = "Variable"

# %%
import pandas as pd

class Annotation:
    def __init__(self):
        self.Title = ""
        self.Citation = ""
        self.In_Text_Citation = ""
        self.Agro_econ = []
        self.Agro_international = []
        self.Agro_policy = []
        self.Agro_tech = []
        self.Agroecology = []
        self.Autonomy = []
        self.Big_agro = []
        self.Buyuksehir_Law = []
        self.Collectives = []
        self.Cooperatives = []
        self.Debt = []
        self.Deruralization = []
        self.Education = []
        self.Food_Network = []
        self.Food_Security = []
        self.Food_Sovereignty = []
        self.Gender = []
        self.Health = []
        self.History = []
        self.Interdisciplinary = []
        self.Land_Consolidation = []
        self.Land_Policy = []
        self.Land_Use = []
        self.Methodology = []
        self.Migration = []
        self.Monoculture = []
        self.Monoculture_Poli = []
        self.Policy_Access = []
        self.Risks_Global = []
        self.Rural_Development = []
        self.Rural_Family = []
        self.Rural_Livelihood = []
        self.Rural_Policy = []
        self.Rurban = []
        self.Seed = []
        self.Shortfood = []
        self.Small_holder = []
        self.Survivorship_bias = []
        self.TR_agroEcon = []
        self.TR_agroGov = []
        self.TR_landUse = []
        self.TR_ruralGov = []
        self.TR_Peasant = []
        self.Urbanization = []
        self.Variable = []

    def add_annotation(self, attribute, annotation):
        if hasattr(self, attribute):
            current_value = getattr(self, attribute)
            if isinstance(current_value, list):
                current_value.append(annotation)
            else:
                raise AttributeError(f"Attribute {attribute} is not a list in Annotation class.")
        else:
            raise AttributeError(f"Attribute {attribute} does not exist in Annotation class.")


    def add_to_excel(self, filename):
        # Load existing Excel file
        df = pd.read_excel(filename)

        # Add a new row for the current instance
        new_row = {attr: getattr(self, attr) or 0 for attr in self.__dict__.keys()}
        df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)

        # Save back to Excel file
        df.to_excel(filename, index=False)


    
def store_annotations_in_dataframe(annotation_instances, include_categories=None, exclude_categories=None):
    annotation_dict = {}
    for annotation_obj in annotation_instances:
        for attribute in annotation_obj.__dict__.keys():
            if isinstance(getattr(annotation_obj, attribute), list):
                for annotation in getattr(annotation_obj, attribute):
                    if annotation not in annotation_dict:
                        annotation_dict[annotation] = {"categories": set(), "in_text_citation": annotation_obj.In_Text_Citation}
                    annotation_dict[annotation]["categories"].add(attribute)

    results = []
    for annotation, data in annotation_dict.items():
        categories = data["categories"]
        if include_categories:
            if all(cat in categories for cat in include_categories):
                if not exclude_categories or all(cat not in categories for cat in exclude_categories):
                    results.append([annotation, list(categories), data["in_text_citation"]])
        elif exclude_categories:
            if all(cat not in categories for cat in exclude_categories):
                results.append([annotation, list(categories), data["in_text_citation"]])
        else:
            results.append([annotation, list(categories), data["in_text_citation"]])

    df = pd.DataFrame(results, columns=["Annotation", "Categories", "In_Text_Citation"])
    return df

def add_annots_from_dict(annotation_obj, annotations_dict):
    """
    Add annotations to the provided Annotation object from a dictionary.
    
    Parameters:
    - annotation_obj: Instance of Annotation class
    - annotations_dict: Dictionary where keys are annotation texts and values are lists of categories
    """
    for annotation_text, categories in annotations_dict.items():
        for category in categories:
            annotation_obj.add_annotation(category, annotation_text)

# %% [markdown]
# recorded_annotations = [
# Aba2015,
# Akci2016,
# Akdeniz2023,
# AksanYildiz2022,
# AlmeidaFerre2019,
# Angin2016,
# AtikTaskan2020,
# AydogduTuzun2019,
# Baktybekova2024,
# Barclay2019,
# Birben2018,
# Can2014,
# Celebican1972,
# CevikEminagaoglu2007,
# Ceylan2019,
# Chand2019,
# DagdelenKizilaslan2023,
# Demirdogen2022,
# DemirtasKaya2018,
# Dilmac2014,
# Dorlach2019,
# Furat2013,
# GunayTuncer2017,
# Gursoy2012,
# Iban2020,
# jrc2017,
# Kandemir2011,
# KanSahin2022,
# Karsak2024,
# Kuzu2022,
# MazziottaPareto2013,
# Muhlenoff2021,
# oecd2008,
# OmarThorsoe2023,
# OzkayaYildiz2024,
# Ozyurt2020,
# SavgınZengin2016,
# Schulthess2017,
# Sezer2021,
# Sisman2023,
# SoztutarYontar2018,
# TeomanYeni2023,
# TolunayYilmaz2009,
# Unal2020,
# Uzundumlu2012,
# Yagci2019,
# YakarYazici2009,
# Yaman2021]
#
#
# annots_variables = store_annotations_in_dataframe(recorded_annotations, include_categories=["Variable"])
# annots_variables.to_excel("annots_variables.xlsx")
#
# annots_methodology = store_annotations_in_dataframe(recorded_annotations, include_categories=["Methodology"])
# annots_methodology.to_excel("annots_methodology.xlsx")
#
# annots_FSFS = store_annotations_in_dataframe(recorded_annotations, include_categories=["Food_Security", "Food_Sovereignty"])
# annots_FSFS.to_excel("annots_security_sovereignty.xlsx")

# %%
Kuzu2022 = Annotation() # Example Usage
# Create the annotation class


# Add references with functions
Kuzu2022.Title = "Güneydoğu Anadolu Bölgesinin Mevcut Tarımsal Yapısının Analizi"
Kuzu2022.Citation = "Kuzu, S. H. (2022). Güneydoğu Anadolu Bölgesinin Mevcut Tarımsal Yapısının Analizi. Ünye İktisadi Ve İdari Bilimler Fakültesi Dergisi, 5(1), 30-46."
Kuzu2022.In_Text_Citation = "Kuzu, 2022"

# Combine all annotations with their chosen categories
Kuzu2022_annot = {
"kapitalist üretim ilişkileri sonucunda kırsal yaşam gerilemeye, yoksulluk artmaya başlamış ve nüfus da kentlere akın etmiştir::p.31" : [Urbanization],
"Kır nüfusunda yaşanan düşüşle kent nüfusunda yaşanan artış birbiri ile kıyaslandığında 2012 yılından 2013 yılına geçişle birlikte bölge içerisinde kırdan kente muazzam bir göç yaşandığı::p.32" : [Buyuksehir_Law],
"Zoraki göçler::p.33" : [ Migration],
"alınan göç, verilen göç ve net göç istatistiklerine::p.33" : [Variable],
"bölgedeki işgücü ve istihdam::p.34" : [Variable],
"15 yaş ve üstü nüfusun yıldan yıla artış göstererek, 2004 yılında 3.764.000 iken 2020 yılında 5.791.000’e ulaştığı görülmektedir::p.34" : [Variable],
"istihdamın sektörel dağılımında::p.35" : [Variable],
"genel anlamda tarım sektöründe istihdam edilenlerin sayısında artış yaşanmakta iken oransal açıdan bir düşüş söz konusudur.::p.36" : [Agro_econ, Deruralization],
"cinsiyete dayalı ayrım da gözetilerek::p.37" : [ Gender, Variable],
"tarımda istihdamın işteki durumu ile ilgili::p.38" : [Variable],
"2004 yılından 2012 yılına doğru ise İşveren veya Kendi Hesabına çalışanların oranı arttığını belirtmiştik. Ancak bu dönemden sonra İşveren veya Kendi Hesabına çalışanların oranı azalma eğilimine girmiş 2004 yılında % 43,68, 2012 yılında % 46,11 olan istihdam oranı 2020 yılında 31,45::p.39" : [Agro_econ, Food_Sovereignty],
"Güneydoğu Anadolu Bölgesindeki arazilerin yaklaşık % 52’si tarım alanı şeklinde::p.40" : [TR_landUse],
"Tarım alanları::p.40" : [Variable],
"Bitkisel ürünlerin ekildiği alan 25.334.973 dekar iken 2020 yılında 20.456.655 dekara inmiştir. Bu durum sebze bahçeleri alanlarında da paralel yöndedir. 2007 yılında 823.818 dekarlık alanda sebze bahçeleri ürünleri üretilmekte iken 20::p.40" : [Agro_econ, Variable],
"su ve toprak kaynaklarının geliştirilmesine dayanan bir program olarak ele alınmış olan GAP kapsamında Bölgeye barajlar, hidroelektrik santralleri ile sulama şebekesi yapımı::p.40" : [TR_ruralGov],
"aşırı sulama, yoğun kimyasal ilaç ve gübre kullanımı doğal yapıyı olumsuz etkilemekte iken yeraltı suları::p.42" : [Agroecology, TR_agroGov],
"Tarımsal üretimde kimyasala en az başvurulan bölge olma özelliğini de taşımaktadır::p.42" : [Variable],
"Bu sebeple de Bölgede daha çok yağışa dayalı şartlarda, traktör girişinin zor olduğu yüksek ve dağlık kesimlerde yetiştirilmektedir.::p.46" : [Rural_Livelihood],
"Kimyasal gübre maliyetlerinin yüksek olması nedeniyle daha çok çiftliklerden elde edilen hayvan gübresi kullanılmaktadır::p.46" : [Agroecology, Food_Sovereignty]
        }

# Add annotations to the Annotation object    
add_annots_from_dict(Kuzu2022, Kuzu2022_annot)

# Add to excel
Kuzu2022.add_to_excel('literature_annotation.xlsx')

# %%
KanSahin2022 = Annotation()


# Alternative reference specification
Title = "Kırsal Kalkınma Yatırımlarının Desteklenmesi Programı: Kırsal Ekonomik Altyapı Projeleri 2021 Yılı Bolu Örneği"
Citation = "Şahin, A. E., & Kan, A. (2022). Kırsal Kalkınma Yatırımlarının Desteklenmesi Programı: Kırsal Ekonomik Altyapı Projeleri 2021 Yılı Bolu Örneği. Kırşehir Ahi Evran Üniversitesi Ziraat Fakültesi Dergisi, 2(2), 121-132"
in_text_cite = "Kan & Şahin, 2022"

KanSahin2022.Title = Title
KanSahin2022.Citation = Citation
KanSahin2022.In_Text_Citation = in_text_cite


KanSahin2022_annot = {
"Kırsal kalkınma yaklaşımlarında 1980’li yıllara kadar tarımda modernizasyon ve devlet müdahaleleri egemen olmuştur. 1980’li yıllardan sonra sürdürülebilir kalkınma, katılım, yönetişim, kırsal kalkınma politikalarını şekillendiren kavramlar olmuştur. 2000’li yıllardan sonrada çok sektörlülük, sosyal kapsama, rekabetçi toplum, yerelden talebin oluşturulması::p.122" : [Rural_Development],
"Avrupa Birliği tarafından yürütülen Ortak Tarım Politikası, BM 2030 Sürdürülebilir Kalkınma Amaçları::p.123" : [Agro_international],
"Tarım ve Orman Bakanlığı tarafından Tarım Reformu Genel Müdürlüğünce 2007 yılından bugüne kadar uygulanan Kırsal Kalkınma Yatırımlarının Desteklenmesi Programıdır(KKYDP).::p.124" : [Rural_Policy],
"Kırsal Kalkınma Yatırımlarının Desteklenmesi Programı (KKYDP), 81 ilde %50 hibe desteği::p124" : [Debt],
"Tarım Reformu Genel Müdürlüğü::p.125" : [TR_agroGov],
"Proje değerlendirme komisyonu, Vali Yardımcısı, İl Tarım ve Orman Müdürü, Çevre, Şehircilik ve İklim Değişikliği İl Müdürü, Ticaret İl Müdürü, Ziraat Odası Başkanı şeklinde teşekkül eder.::p.125" : [TR_ruralGov],
"orman kooperatifleri dikkat çekmektedir. 179 tarımsal kooperatif ve bunların üst birlikleri olarak 12 birlik bulunmaktadır::p.125" : [Cooperatives],
"22 tarihleri arasında 30 yatırımcı ile KKYD Programına ilişkin anket yapılmıştır. 30 yatırımcının tamamı ile yüz yüze anket yapılmıştır::p.127" : [Survivorship_bias],
"%80’i programdaki bürokrasinin azaltılmasını::p.129" : [Policy_Access],
"Yatırımlarının Desteklenmesi Programı (KKYDP) %50 hibe esasına dayanan bir programdır. Program kapsamında büyük ölçekli yatırım projelerine ve küçük ölçekli tarım işletmelerine yönelik destekler sunulmaktadır::p.129" : [Rural_Development, Small_holder],
"Çiftçi Kayıt Sistemi, Hayvan Kayıt Sistemi, Arıcılık Kayıt Sistemi::p.129" : [TR_ruralGov],
"kayıtlı Bolu çiftçilerinden programa talep az olmuştur. Bunun nedenleri arasında tarımsal makine satışı yapan firmaların programın açıklanmasıyla ürünlerine zam yapması, Bakanlığın belirlediği referans fiyatın serbest piyasa fiyatlarının aşağısında kalması,::p.130" : [Food_Sovereignty, Rural_Livelihood]
   
}



add_annots_from_dict(KanSahin2022, KanSahin2022_annot)

KanSahin2022.add_to_excel('literature_annotation.xlsx')

# %%
AksanYildiz2022 = Annotation()
AksanYildiz2022.Title = "Midyat İlçesi’nde (Mardin) Kırsal Yerleşim Sistemi"
AksanYildiz2022.Citation = "Aksan Kanat, N., & Yıldız, M. Z. (2022). Midyat İlçesi’nde (Mardin) Kırsal Yerleşim Sistemi. Van İnsani Ve Sosyal Bilimler Dergisi(3), 135-160."
AksanYildiz2022.In_Text_Citation = "Aksan & Yıldız, 2022"


AksanYildiz2022_annot = {
"Mardin ilinin Midyat ilçesine bağlı, günümüzde mahalle statüsündeki 60 kırsal yerleşmeyi kapsamaktadır.::p.138" : [Buyuksehir_Law],
"kuruluş yerleri ve merkeze olan uzaklıkları ile yerleşmelerin gelişimi arasında bir ilişki var mıdır::p.138" : [Variable],
"etnik ya da dinsel karakteri ile ekonomik faaliyet ve gelişmişlik düzeyi::p.138" : [Variable],
"büyükşehir hâline getirilmesi ile kırsal yerleşmeler sosyal, demografik ve ekonomik açıdan nasıl etkilenmiştir? Midyat kırsal yerleşmelerinde altyapı sorunlarının::p.138" : [Buyuksehir_Law, Variable],
"kurulduğu alanların yükseltisi::p.139" : [Variable],
"yağış alan arazilerin::p.140" : [Variable],
"güvenlik nedenli göçlerdir::p.140" : [ Migration],
"Köyünü terk etmeyerek korucu olmayı tercih eden köylerin nüfuslarını büyük ölçüde korudukları, günümüzde de yüksek nüfuslu kırsal yerleşmeler arasında yer aldığı söylenebilir::p.142" : [Rural_Livelihood],
"Kırsal yaşamın kalabalık aile yapısı zamanla yerini daha az bireye sahip ailelere bırakmaya başlamıştır::p.143" : [Rural_Family, Small_holder, Variable],
"Nüfusu az olan bu köylerin minibüsü olmadığından::p.145" : [Variable, TR_ruralGov],
"Sağlık olanakları::p.146" : [Variable],    
"çöp toplama::p.147" : [Variable],
"köylerin eski isimleri genellikle Süryanice ve Kürtçe kökenlidir.::p.148" : [Variable],
"Fıstık üretiminin ticari anlamda önemli kazanç kaynağı olacağının düşünülmesi nedeniyle, son yıllarda insanların ilgisini çekmeye başlamıştır.::p.153" : [Variable],
"köylerin arazi yapısı::p.153" : [Variable],
"kişi başına düşen ortalama tarımsal arazi miktarları::p.154" : [Variable],
"gelir düzeyi::p.155" : [Variable],
"köylüler ürünlerini pazarlamakta da çeşitli sorunlar yaşamakta ve ürünlerin satışından düşük gelirler elde etmektedir.::p.156" : [Agro_econ, Food_Network],
"birey köy dışına çalışmak için göç ederek, aile bütçesine ek gelir sağlamaktadır::p.156" : [ Migration],
"okulu bulunmayan köyler::p.156" : [Variable]
}

add_annots_from_dict(AksanYildiz2022, AksanYildiz2022_annot)

AksanYildiz2022.add_to_excel('literature_annotation.xlsx')

# %%
OmarThorsoe2023 = Annotation()

OmarThorsoe2023.Title = "Rebalance power and strengthen farmers’ position in the EU food system? A CDA of the Farm to Fork Strategy"
OmarThorsoe2023.Citation = "Omar, A., & Thorsøe, M. H. (2023). Rebalance power and strengthen farmers’ position in the EU food system? A CDA of the Farm to Fork Strategy. Agriculture and Human Values, 41(2), 631–646. https://doi.org/10.1007/s10460-023-10508-5"
OmarThorsoe2023.In_Text_Citation = "Omar & Thorsøe, 2023"

OmarThorsoe2023_annot = {
"EU’s Common Agricultural Policy (CAP)::p.631" : [Agro_international, Agro_policy],
"The European Union’s Farm to Fork (F2F) Strategy::p.632" : [Agro_econ, Food_Network, Food_Sovereignty, Shortfood],
"power imbalances in the EU food system::p.632" : [Small_holder],
"critical discourse analysis (CDA) approach.::p.633" : [Methodology],
"Bayer acquired Monsanto in 2016, followed by the Chinese stateowned ChemChina buying Syngenta in 2017::p.633" : [Big_agro, Seed],
"bargaining power::p.634" : [Variable],
"the lack of a democratic political and regulatory framework to govern the EU food system::p.634" : [Policy_Access],
"surplus dumping and export monopolies in developing countries::p.634" : [Agro_econ, Big_agro, Small_holder],
"power::p.635" : [Variable],
"The first climate-neutral continent by 2050::p.635" : [Agroecology],
"Value chain is mentioned 7 times in the context of reducing Greenhouse Gas (GHG) emissions::p.636" : [Agroecology, Shortfood],
"These business opportunities are linked to the circular bio-based economy and rely on investment in advanced bio-refineries that produce biofertilisers, protein feed, bioenergy, and bio-chemicals::p.636" : [Agro_econ, Agroecology, Big_agro],
"Communication document did not mention the importance of halting and addressing consolidation and concentration in the grocery retail sector::p.637" : [Food_Sovereignty],
"technology (including technologies/technological) are mentioned 8 times, digital and data are mentioned 6 and 15 times respectively, and innovation (including innovative)::p.637" : [Agro_tech],
"commodification of agroecological services (carbon farming) for creating greater investment opportunities through financial markets.::p.638" : [Agro_policy, Agro_econ, Agro_international],
"Consultative Group on International Agricultural Research (CGIAR)::p.638" : [Agro_international, Agro_tech],
"carbon farming is pitched as a “green business model::p.638" : [Agro_international, Agroecology, Monoculture, Rural_Livelihood, Agro_econ],
"These technologies encompass various aspects, ranging from high-speed broadband internet and artificial intelligence to the integration of precision farming, insect-based proteins, meat substitutes, and microbiome research. The primary beneficiaries will be SMEs and mid-cap companies::p.639" : [Agroecology, Food_Security, Food_Sovereignty],
"land grabbing and acquisition, has been recognized as a major flaw in the EU system::p.639" : [Land_Consolidation, Rural_Livelihood],
"from the hubris of the marriage between Big Ag and Big Tech, whereby creating what Duncan et al. (2021) term as ag tech.::p.640" : [Agro_policy, Agro_tech],
"Reveal a dominant discourse centred on technology and finance.::p.640" : [Agro_econ, Agro_policy],
"The revision of the LULUCF legislation (EP 2022a) also lacks measures to protect the land rights of small-scale farmers and local communitie::p.641" : [Rural_Development, Small_holder],
"Biodiversity and Farm to Fork Strategies on EU agriculture. The review covered studies conducted by the Commission’s Joint Research Centre, Wageningen University and Research, United States Department of Agriculture (USDA)::p.641" : [Agroecology, Food_Network],
"Land Use, Land-Use Change and Forestry (LULUCF) regulation within the Fit for 55 package::p.641" : [Land_Policy, Land_Use],
"In summary, there is a disconnect between the objectives, vision, and goals of the F2F Strategy, which aim for sociological transformation, and the implementation and action plans that deviate from social reform in the food system::p.642" : [Agro_policy, Food_Network],
"Grassroots organizations representing smallholder farmers were excluded from giving policy advice to the final F2F Strategy::p.642" : [Small_holder],
"Copa-Cogeca went from being a united voice of the farmers and agri-cooperatives in the EU to a hybrid lobby group now closely aligned with agri-businesses such as BASF, Syngenta, Bayer, Nestlé, Mondale, and Unilever::p.642" : [Cooperatives, Survivorship_bias]
}

add_annots_from_dict(OmarThorsoe2023, OmarThorsoe2023_annot)

OmarThorsoe2023.add_to_excel('literature_annotation.xlsx')

# %%
Akdeniz2023 = Annotation()

Akdeniz2023.Title = "Türkiye’de Uygulanmış Arazi Toplulaştırma Projelerinin Kırsal Kalkınmaya Etkisi Bakımından Değerlendirilmesi"
Akdeniz2023.Citation = "Akdeniz, H. B., İnam, Ş., & Çay, T. (2023). Türkiye’de Uygulanmış Arazi Toplulaştırma Projelerinin Kırsal Kalkınmaya Etkisi Bakımından Değerlendirilmesi. ÇOMÜ Ziraat Fakültesi Dergisi, 11(1), 18-30. https://doi.org/10.33202/comuagri.1232016"
Akdeniz2023.In_Text_Citation = "Akdeniz et al., 2023"

Akdeniz2023_annot = {
"Arazi Toplulaştırma::p.19" : [Land_Consolidation],
"22.11.1984 tarih ve 3083 sayılı Sulama Alanlarında Arazi Düzenlenmesine Dair Tarım Reformu Kanunu ve bu kanun uygulamasına yön veren 07.02.2019 tarihli Arazi Toplulaştırması ve Tarla İçi Geliştirme Hizmetleri Uygulama Yönetmeliği ile 03.07.2005 tarih ve 5403 sayılı Toprak Koruma ve Arazi Kullanımı Kanunu ve bu kanun uygulamasına yön veren 09.12.2017 tarihli Arazi Toplulaştırma Uygulama Yönetmeliği mevzuat altyapısında Devlet Su İşleri Genel Müdürlüğü tarafından yürütülmektedir.::p.21" : [Land_Policy], 
"Çiftçi bazındaki işletmelerin işledikleri arazi miktarı; sınırlı ve birbirinden uzak çok sayıda parçalardan meydana geldiği için bunlar üzerinde modern tarım tekniklerine dayalı işletmeler kurulamamakta ve mevcut durumuyla istenilen üretim artışı sağlanamamaktadır.::p.21" : [Land_Use],
"AT öncesi her parsel yüzölçümünden %10’a kadar bedelsiz alınan ortak tesislere katılım payı (OTKP) kesintisi ile tedarik edilmektedir.::p.27" : [Land_Policy],
"kırsal kesimden toprak ve işgücü koparmış, buna ilave yaşanan pandemi ve iklim değişimi gibi etkileşimler kırsal mekân ve doğal yaşamın önemini bir kez daha artırmıştır::p.28" : [Deruralization],
}

add_annots_from_dict(Akdeniz2023, Akdeniz2023_annot)

Akdeniz2023.add_to_excel('literature_annotation.xlsx')

# %%
TeomanYeni2023 = Annotation()

TeomanYeni2023.Title = "Agroekolojik Bakış Açısından Türkiye’de Tarımsal Sürdürülebilirlik"
TeomanYeni2023.Citation = "Yeni, O., & Teoman, Ö. (2023). Agroekolojik Bakış Açısından Türkiye’de Tarımsal Sürdürülebilirlik. Fiscaoeconomia, 7(Özel Sayı), 120-151. https://doi.org/10.25295/fsecon.1355937"
TeomanYeni2023.In_Text_Citation = "Yeni & Teoman"

TeomanYeni2023_annot = {
"tarımsal sürdürülebilirliğin en az üç boyutu olduğu öne sürülebilir: çevre boyutu, gıda güvenliği boyutu ve tarımsal üreticilerin yaşam standardı.::p.122" : [Agroecology, Food_Sovereignty, Food_Security],
"Agroekoloji, 1980’li yılların başında basitçe sürdürülebilir tarımın bilimi::p.123" : [Agroecology],
"Biyolojik çeşitlilik, tarım alanlarında çeşitli bitki türleri yetiştirerek (polikültür) ve doğal yaban hayatı için koridorlar oluşturarak korunabilir.::p.124" : [Monoculture_Poli],
"1999 yılında Uluslararası Para Fonu (IMF) ile imzalanan stand-by antlaşması::p.125" : [TR_agroGov, Food_Sovereignty],
"Tarım Satış Kooperatifleri ve Tarımsal Birliklerinin işlevlerinin sınırlandırılması::p.125" : [TR_agroGov],
"küçük ve küçük orta ölçekli tarımsal işletmelerin sayısındaki azalmayla birlikte orta büyük ve büyük işletmelerin sayısında ve tasarrufunda bulundukları arazilerin oranında artış olarak gerçekleşmiştir. 1990’ların başından itibaren 5 hektara kadar araziyi tasarrufunda bulunduran işletmelerin sayısında süreklilik gösteren azalışa 2000’li yıllarda 20 hektarın üzerindeki araziyi tasarrufunda bulunduran işletmelerin sayısında artış eşlik etmiştir.::p.126" : [Small_holder, TR_landUse, Variable],
"TÜİK verilerine göre 2022 yılında çayır ve meralar dâhil edildiğinde Türkiye topraklarının %50’sinin tarım alanı (çayır ve meralar dâhil::p.126" : [TR_landUse],
"%64’ünde aktif erozyon oluştuğu belirtilmektedir (T. C. Orman ve Su İşleri Bakanlığı, 2013: 14, 15). Genel olarak, topraklarının %62,2’si %12’den yüksek eğimli bölgelerde bulunan Türkiye’de (Şenol & Bayramin, 2013: 230), 61,3 milyon hektarlık alan erozyon tehdidi altında olup bunun 17,4 milyon hektarında çok şiddetli, 28,3 milyon hektarında şiddetli::p.127" : [Agroecology, Variable],
"AQUASTAT verilerine göre Türkiye’de 2019 yılında toplam su kullanımının yaklaşık %84,7’si tarım sektörü tarafından gerçekleştirilmiştir. Şekil 2’den de izlenebileceği gibi bu oran 2000’li yıllar boyunca %80’in üzerinde seyretmiştir.::p.128" : [Variable],
"Ayrıca, çiftçilerin yerel iklim ve tarım koşullarına uygun ürünler yerine daha yüksek gelir getiren ürünleri tercih etmesi::p.128" : [Agro_econ, Food_Sovereignty],
"Örneğin, sulama gerektiren bir tahıl olan mısır üretiminin 2022 yılında %76,5’ini gerçekleştiren on ilin altısı (Konya, Şanlıurfa, Mardin, Karaman, Eskişehir, Aksaray)5 Türkiye’de yıllık ortalama yağışın düşük ve zaman zaman meteorolojik kuraklığın etkili olduğu bölgelerde bulunmaktadır.::p.131" : [Agro_econ, Agroecology, TR_landUse, Food_Sovereignty],
"2020 yılında Türkiye’nin toplam metan salımının %61’i, nitrözoksit salımının ise %83,2’si tarım sektöründen kaynaklanmıştır.::p.134" : [Agroecology],
"Economist Impact tarafından Corteva Agriscience desteğiyle 2012 yılından bu yana hesaplanmakta olan Küresel Gıda Güvenliği Endeksi (KGGE)::p.136" : [Food_Security],
"Doktar firması tarafından 2018-2020 yılları arasında yapılan Çiftçinin Nabzı Araştırmaları (ÇNA) ile Kredi Kayıt Bürosu (KKB) tarafından 2019-2022 yılları arasında yapılan Türkiye Tarımsal Görünüm Saha Araştırmaları (TTGSA)::p.139" : [Agro_econ, TR_agroEcon, TR_agroGov],
"Çiftçilerin %84’ü çiftçilik faaliyetlerinden para biriktirecek kadar kazanmadıklarını belirtmiştir. Büyük çiftçilerin %23’ünün para biriktirebildiği ancak üretici ölçeği küçüldükçe bu oranın da düştüğü belirlenmiştir::p.139" : [Small_holder]
}

add_annots_from_dict(TeomanYeni2023, TeomanYeni2023_annot)

TeomanYeni2023.add_to_excel("literature_annotation.xlsx")

# %%
OzkayaYildiz2024 = Annotation()

OzkayaYildiz2024.Title = "Pioneering Communities in Dissemination of Local Wheat Varieties and Products in Turkey"
OzkayaYildiz2024.Citation = "Yıldız, M., & Özkaya, T. (2024). Pioneering Communities in Dissemination of Local Wheat Varieties and Products in Turkey. Tekirdağ Ziraat Fakültesi Dergisi, 21(2), 309-323. https://doi.org/10.33462/jotaf.1217580"
OzkayaYildiz2024.In_Text_Citation = "Özkaya & Yıldız, 2024"

OzkayaYildiz2024_annot = {
"green revolution::p.311" : [Agro_econ, Monoculture],
"Mexican seeds were grown on an area of 50 decars in 1964, in Turkey, it started to be grown on a land of 14,554,000 decars within 5 years::p.311" : [Food_Sovereignty, Seed],
"The negative effects of gluten protein, which is more abundant in the structure of improved wheat varieties, on human health have been the subject of many scientists::p.311" : [Health],
"where a different variety or type of wheat was grown in almost every village in the 1930s::p.311" : [Seed],
"gradually began to pay higher prices for these industrial inputs. On the other hand, the price received by the farmers for wheat has been respectively diminished due to the downsizing of State Grain Board (Toprak Mahsülleri Ofisi)::p.312" : [Agro_econ],
"However, it does not seem possible to expand local wheat varieties acreage::p.312" : [Food_Security, Food_Sovereignty],
"the Ministry does not show any interest in the production and development of local seeds in the hands of farmers and participatory plant breeding. The basic approach of the ministry is to preserve the basic structure of modern wheat varieties::p.312" : [TR_agroGov, TR_agroEcon],
"participatory plant breeding (PPB) are presented in the work of the Philippines-based Masipag organization called Food Security and Farmer Empowerment (www.masipag.org)::p.312" : [Food_Sovereignty, Seed, Food_Security],
"However, while the yield regularly increases over the years in the ecological farming group, it decreases in the conventional group::p.312" : [Food_Sovereignty, Agroecology],
"Evolutionary Populations (EPs) is seed laws. EPs do not meet the Distinctness, Uniformity and Stability (DUS) requirements for their official registration and marketing::p.313" : [Agro_international, Seed, Agro_policy],
"Colombian Free Seed Network” (RSCL)::p.313" : [Seed, Food_Sovereignty],
"agroecological practices which allow for spreading knowledge, principles, and practices among seed custodians::p.313" : [Education, Seed],
"OSSI (Open-Source Seed Initiative) in the USA, which implements the open-source approach, and OSSS (Open-Source Seed System) in India::p.313" : [Collectives, Seed],
"seed banks are more successful in protecting and developing local seeds and local knowledge, and enhancing the resilience of communities against climate crisis.::p.313" : [Seed, Risks_Global],
"local wheat producing farmers::p.314" : [Variable],
"these food groups do not have a contractual and prepayment relationship with farmers like the community supported agriculture groups in France, Belgium.::p.314" : [Food_Network, TR_agroEcon],
"Rapid Rural Appraisal (RRA), which was developed and implemented in the 1980s, quickly developed and became widespread, turning into Participatory Rural Appraisal (PRA) in the 1990s (Chambers, 1994). Afterwards, Participatory Rural Appraisal (PRA) has evolved into Participatory Learning and Action (PLA) covering a wide range of subject and location::p.315" : [Methodology],
"These members rarely contribute the farm. The group has also created a consumer community around itself. The community tried to establish relations with other peasants/farmers::p.315" : [Collectives, Cooperatives, Food_Network],
"he planted nearly twenty wheat varieties on the farm and put them to trial.::p.316" : [Collectives, Cooperatives, Agroecology],
"One of the aims of the group is to prevent the increasing rural gentrification::p.316" : [Rural_Livelihood],
"This transformation has given farmers a significant autonomy::p.316" : [Autonomy, Shortfood],
"In many municipalities, there is a strong will to protect and disseminate the local seed varieties contrary to the central government. Starting from 2010, municipalities with a progressive attitude mainly in Western Anatolia contributed to the organization of seed exchange festival::p.318" : [TR_agroGov, Seed],
"The municipality bought the wheat from the farmer and distributed the flour to the villagers who would make bread, thereby ensured the recognition of the bread::p.318" : [Food_Network, TR_agroEcon],
"Large flour, pasta and bread companies lead to the exclusion of local wheat varieties by determining the wheat varieties and standards they buy::p.318" : [TR_agroEcon, Agro_econ],
"Ecological products are considered expensive by consumers.::p.319" : [Food_Security, Food_Sovereignty], 
"The discourses that the ecological production of local wheat varieties cannot feed the world are very common at all levels. It should be explained that local wheat varieties are more nutritious and satisfying, and it may not decrease the production to use agroecological methods.::p.319" : [Agro_international, Agro_policy],
"Less waste::p.320" : [Variable],
"easy access to the product::p.320" : [Variable],
"More expensive::p.320" : [Variable],
"need for some interventions by municipalities and public institutions to promote::p.320" : [Variable],
"taxation::p.320" : [Variable]
}


add_annots_from_dict(OzkayaYildiz2024, OzkayaYildiz2024_annot)

OzkayaYildiz2024.add_to_excel("literature_annotation.xlsx")

# %%
DagdelenKizilaslan2023 = Annotation()

DagdelenKizilaslan2023.Title = "Genç Çiftçi Projesinin Sürdürülebilirliğinin İncelenmesi: Tokat İli Turhal İlçesi Örneği"
DagdelenKizilaslan2023.Citation = "Kızılaslan, N., & Dağdelen, K. (2023). Genç Çiftçi Projesinin Sürdürülebilirliğinin İncelenmesi: Tokat İli Turhal İlçesi Örneği. Gaziosmanpaşa Bilimsel Araştırma Dergisi, 12(2), 182-196."
DagdelenKizilaslan2023.In_Text_Citation = "Dağdelen & Kızılaslan, 2023"

DagdelenKizilaslan2023_annot = {
"kırsalda yaşlanma olgusu::p.183" : [Rural_Livelihood, Rural_Family, TR_agroEcon],
"Genç Çiftçi Destek Projesi’nin (GÇP)" : [Agro_policy, TR_agroGov],
"Genç çiftçilerin %56,09'u gelecekte çiftçiliğe devam edeceklerini, %43,91'i ise kente göç etmek istediklerini belirtmişlerdir." : [Rural_Livelihood, Migration],
"Çiftçilerin danışmanlık hizmetinden yararlanma" : [Agro_policy, TR_agroGov],
"Çiftçilerin %62,16’sı pazarlamada sorun yaşadığını belirtmiştir." : [Food_Network, Food_Sovereignty, TR_agroEcon],
"ürettiği ürünün satış fiyatının, ürün maliyetini karşılamadığını belirtmiştir." : [Rural_Livelihood, TR_agroEcon, TR_agroGov, Variable],
"genç çiftçilerin %25,70’i yedinci seçeneği, %24,30’u ikinci seçeneği, %18,90’ı dördüncü seçeneği" : [Debt, TR_agroEcon],
"bürokratik işlemlerin uzun sürmesi ve proje kapsamındaki tesis yapım maliyetinin yüksek olması" : [Policy_Access, TR_agroEcon, TR_agroGov],
}

add_annots_from_dict(DagdelenKizilaslan2023, DagdelenKizilaslan2023_annot)

DagdelenKizilaslan2023.add_to_excel("literature_annotation.xlsx")

# %%
Sisman2023 = Annotation()

Sisman2023.Title = "Ankara Kırsalında Tarımsal Gıda Sistemi Olarak Agroekolojinin Sosyolojik Analizi"
Sisman2023.Citation = "Şişman, B. (2023). Ankara Kırsalında Tarımsal Gıda Sistemi Olarak Agroekolojinin Sosyolojik Analizi. Sosyoloji Araştırmaları Dergisi, 26(2), 230-253. https://doi.org/10.18490/sosars.1382530"
Sisman2023.In_Text_Citation = "Sisman, 2023"

Sisman2023_annot = {
"Belirtilmek istenen bir diğer nokta ise disiplinlerarası araştırmaların önemidir. Bu sebeple artan çevresel sorunlara paralel olarak, tüm sorunların birbiriyle bağlantılı olduğunu::p.232" : [Interdisciplinary, Agroecology],
"tek tip bitki ve hayvan yetiştiriciliğine dayanan, yoğun kimyasalların kullanıldığı, dış girdilere oldukça bağımlı bir üretimi kapsamaktadır.::p.234" : [Autonomy, Food_Sovereignty, Agro_econ],
"bu zincir içerisinde üretici, gıdanın son tüketicisinden oldukça uzaktır::p.234" : [Food_Network, Agro_econ],
"Monokültür olarak tanımlanan, tek tip ürünün yetiştirilmesine dayalı olan konvansiyonel üretim, doğanın çeşitliliğe doğru gitme eğiliminde olan yapısını bozarak, tek bir tür veya çeşidin geniş bir alana yayılmasına yol açmaktadır::p.234" : [Monoculture, Seed],
"bu terimi ilk olarak Basil M. Bensin 1928’de Agroecological Characteristics Description and Classification of the Local Corn Varieties Chorotypes adlı çalışmasında kullanmıştır. Bu terim agronomi ve ekoloji disiplinlerinden türetilmiştir::p.235" : [Agroecology],
"agroekoloji hem bilimsel yönü bakımından geliştirilen kavramsal çerçeveye hem de çiftçilerin bilgi ve deneyimlerine dayalı uygulamaları kapsamaktadır::p.236" : [Food_Sovereignty, Agroecology],
"küçük ölçekli çiftçiliğin eşitlik ve sürdürülebilirlik boyutlarını vurgulamaktadır:.p.236" : [Agroecology, Small_holder],
"Bunlardan biri olan üretici pazarları, doğrudan üretici ve tüketici ilişkilerini içeren kısa tedarik zincirlerinin içerisinde yer almaktadır::p.236" : [Agro_econ, Shortfood],
"Bir diğer doğrudan satış seçeneği ise çiftçiden çevrimiçi gerçekleştirilen satıştır::p.237" : [Shortfood, Agro_econ],
"TADYA (Tahtacıörencik Doğal Yaşam Kolektifi)::p.237" : [Collectives],
"Topluluk Destekli Tarım (TDT)::p.237" : [Food_Network, Food_Sovereignty],
"Nitel araştırmalar genel anlamıyla keşfedici çalışmalardır::p.239" : [Methodology],
"yüksek düzeyde borçlanma::p.241" : [Debt],
"çiftçiden çiftçiye öğrenme::p.243" : [Education, Food_Sovereignty],
"Köyler içerisinde gerçekleştirilen toplantılara kadın ve erkek üreticilerin hepsi katılım sağlamaya çalışmaktadır::p.245" : [Gender]
}
add_annots_from_dict(Sisman2023, Sisman2023_annot)

Sisman2023.add_to_excel("literature_annotation.xlsx")

# %%
Unal2020 = Annotation()

Unal2020.Title = "Türkiye’de Kırsal Değişme Süreçleri"
Unal2020.Citation = "Ünal, H. E. (2020). Türkiye’de Kırsal Değişme Süreçleri. Sosyal Ve Beşeri Bilimler Araştırmaları Dergisi, 21(47), 22-49."
Unal2020.In_Text_Citation = "Ünal, 2020"


Unal2020_annot = {
"1950'lerde ortaya çıkan ekonomik-politik değişimler::p.23" : [History],
"Traktör kullanımının yaygınlaşması, yol ve taşıt vasıtalarının yoğunlaşması::p.23" : [History, Migration, Agro_tech],
"2012 yılında 17 milyon olan kırsal nüfus çıkarılan Büyükşehir Kanunu ile birlikte 2013 yılında yaklaşık 7 milyon olarak tespit edilmiştir::p.23" : [Buyuksehir_Law, TR_ruralGov],
"1948 yılı sonrası Marshall PLanı ile tarımda modernleşmeye hız verilmiştir::p.24" : [History, Agro_policy, Agro_international, Debt],
"Türkiye'de tarıma yönelik politikalar açısından amaç ve öncelikler bakımından teknokratik ve reformcu olmak üzere iki politika çeşidi söz konusu olmuştur::p.25" : [History, TR_agroGov],
"teknokratik politikalar ile amaçlanan 1950-1960 yıllarında ekilmeyen toprakların ekime açılması:p.25" : [History, TR_agroGov],
"reformcu politikalar ise birinci politika sonucu oluşan gelir adaletsizliğini çözmek için konmuş ancak başarılı olunamamıştır::p.25" : [History, TR_ruralGov],
"Tarımda koruyucu politikalardan uzaklaşılması::p.25" : [TR_ruralGov, TR_agroGov, History],
"1980-1989 döneminde katma değeri düşük olan tarımsal hammade satışı ile ... döviz girişi sağlamak için ... ilerleme kaydedilemiştir::p.25" : [History, TR_agroEcon],
"32 Sayılı Karar çıkarılarak yabancı sermayenin gelmesi teşvik edilmiştir::p.25" : [TR_agroEcon],
"tarımda serbest rekabet ekonomisi, ... 1950-1980 tarımsal üreticiler koruma altındaydı::p.26" : [TR_agroEcon, Small_holder, History],
"tarımda yeni teknolojiler::p.27" : [Variable, Small_holder, Agro_econ],
"Akaryakıt satış fiyatı::p.29" : [Variable, TR_agroEcon],
"1970'de uygulanan teşvik politikaları tarımsal girdinin daha da yaygınlaşmasını sağlamıştır::p.30" : [History, Debt, TR_agroEcon, Variable],
"1970 yılında .. 2.2 milyon tonluk gübre tüketimi::p.30" : [Variable],
"Sulanan arazi miktarı::p.31" : [Variable],
"mülkiyet biçimleri::p.31" : [Variable, TR_landUse, TR_agroEcon],
"işlenebilir araziler::p.31" : [Variable, TR_landUse],
"toprağını tamamen kaybeden ve tarımsal işçi durumuna düşenler::p.32" : [Rural_Livelihood, TR_agroEcon, Variable, Food_Sovereignty],
"tarımsal mülkiyetin dağılımında büyük mülklerdeki birikim güçlenmiştir::p.32" : [Food_Sovereignty, Small_holder],
"ekilen toprak miktarı::p.33" : [Variable],
"işletme ölçeğine göre mülkiyet dağılımı::p.33" : [Variable, Rural_Family],
"<<kır-kent legal statüsünden bağımsız olarak dönüştürülen mahallelerin nüfüsları, = gerçek kır nüfusu, Veya Rurban>>::p.36" : [Variable, TR_ruralGov],
"Kırsal kesimde yaşayan yoksulların gelir getirici faaliyetleri::p.40" : [Variable, Rural_Livelihood, Interdisciplinary],
"Geleneksel tarım toplumunda aile yapısı::p.41" : [History, Rural_Family],
"sektörlere göre işsizlik oranı<<tarım çoğunlukla informel sektör, nasıl işsizlik ölçülüyor?>>::p.40" : [Variable],
"Özellikle 1980'lerde yaşanan girdi faaliyetlerinin artması::p.42" : [Debt, Rural_Livelihood, TR_Peasant],
"Ziraat bankasının çiftçilere sağladığı kredilerin artması, ...Toprak Mahsülleri Ofisi (TMO)'nun köylüden buğday satın alma işlemini artırması::p.42" : [Policy_Access, Debt, TR_agroEcon],
"Çiftçilerin sosyal güvenceye sahip olmaları, ... 1960-2000::p.43" : [Variable, TR_Peasant, History]
}


    
add_annots_from_dict(Unal2020, Unal2020_annot)

Unal2020.add_to_excel("literature_annotation.xlsx")

# %%
AydogduTuzun2019 = Annotation()

AydogduTuzun2019.Title = "Tarımsal Finansman: Mersin İlinde Tarımsal Kredi Kullanımı"
AydogduTuzun2019.Citation = "Tüzün Rad, S., & Aydoğdu, C. (2019). Tarımsal Finansman: Mersin İlinde Tarımsal Kredi Kullanımı. Tarım Ekonomisi Araştırmaları Dergisi, 5(2), 58-67."
AydogduTuzun2019.In_Text_Citation = "Aydogdu & Tüzün, 2019"

AydogduTuzun2019_annot =  {
"tarım sektörünün GSYİH’ ya katkısı %6,1::p.59" : [TR_agroEcon, Variable],
"Bu bağlamda; tarım sektörünün finansmanı çok önemlidir. Ellis’e (1996) göre, tarımsal finansman politikalarının amaçları::p.59" : [Agro_econ, Variable],
"Tarımsal üretimdeki dalgalanmaya bağlı olarak, tarımsal gelir de dalgalanmaktadır::p.59" : [Agro_econ, Variable],
"Tarımsal ürün arzının fiyat esnekliği düşüktür::p.59" : [Agro_econ, Variable],
"Tarımsal girdi fiyatları, ürün fiyatlarına göre daha hızlı artmaktadır::p.59" : [Agro_international, Debt, Variable],
"kadınların eğitim düzeyinin yükseldiği yerlerde gelir artmaktadır::p.60" : [Gender],
"Tarımsal krediler - kullanımı::p.60" : [Agro_econ, Debt, Variable],
"Bir kooperatife üye olan çiftçilerin, kredi kullanma olasılıkları artmaktadır::p.60" : [Cooperatives, Autonomy],
"Tarımsal Kredi Miktarına Göre Sıralama -  <<Bölü tarımsal üretim değerine göre sıralama>>::p.63" : [Variable, Debt, TR_agroEcon],
"Tarımsal Kredi Performans Oranına Göre::p.63" : [Variable, Debt],
"daha düşük faizli kredi verebilmektedir::p.63" : [Variable, TR_agroEcon],
"kredilerin geri ödeme süresi, teminat süresi:.p.64": [Variable],
"(ihtiyaç duymama), diğer bölgelerde yüksek faiz::p.65" : [Variable, Interdisciplinary]
}

add_annots_from_dict(AydogduTuzun2019, AydogduTuzun2019_annot)

AydogduTuzun2019.add_to_excel("literature_annotation.xlsx")

# %%
Muhlenoff2021 = Annotation()

Muhlenoff2021.Title = "Financial inclusion in the Global South: An analysis of index-based agricultural insurance and Farmer Food Security in India"
Muhlenoff2021.Citation = "Mühlenhoff, S. C. (2021, October 26). Financial inclusion in the Global South: An analysis of index-based agricultural insurance and Farmer Food Security in India. KOBRA. https://kobra.uni-kassel.de/handle/123456789/13325"
Muhlenoff2021.In_Text_Citation = "Mühlenoff, 2021"


Muhlenoff2021_annot = {
"Pradhan Mantri Fasal Bima Yojana and Weather Based Crop Insurance Scheme (WBCIS)::p.1" : [Policy_Access, Risks_Global, Variable],
"Its central argument is that IBAI (index-based agricultural insurance) cannot deliver the proposed benefits because it does not address the underlying causes of farmer's food insecurity. The methodology includes qualitative research that facilitates an in-depth study::p.2" : [Food_Security, Interdisciplinary, Methodology],
"insurance was a technical solution that did not consider how risk depended on an individual's social position::p.2" : [Food_Security, Food_Sovereignty, Rural_Family],
"In many cases, people starve even when there is adequate food available regionally::p.2" : [Autonomy],
"Advocates of food sovereignty criticise food security as apolitical and negligent on questions of origin and production of food::p.3" : [Food_Security, Food_Sovereignty],
"take out credits to invest in new farming technologies and inputs. ... leaving farmers with debts they cannot repay::p.3" : [Agro_tech, Debt],
"farmers often rely on on-farm and off-farm employment::p.3" : [Rural_Livelihood, Variable],
"market-centred logic that food sovereignty rejects::p.3" : [Food_Security, Food_Sovereignty],
"how index-based insurance affects the livelihood strategies of Indian farmers::p.4" : [Variable, Interdisciplinary],
"In-Vivo coding as a method to use the words of participants themselves to generate coding:.p.5" : [Methodology, Interdisciplinary],
"The availability of crop insurance claim is very little; it is very little amount. It doesn ́t cover the whole expenditure that they have done on the crop rising::p.5" : [Variable, Methodology],
"insufficient water supply and irrigation (for an area), <<sulamaya açılan arazi>>::p.5" : [Variable],
"land ownership is a central issue for the discussion of IBAI. In many cases, the holders of insurance policies are landowners who have migrated to Bangalore and rented out their land to tenant farmers. The tenant farmers who work the land are unable to apply for insurance coverage because a land title is required::p.6" : [Land_Use, Policy_Access, Variable],
"lack of influence over their economic environment::p.6" : [Autonomy]
}


add_annots_from_dict(Muhlenoff2021, Muhlenoff2021_annot)

Muhlenoff2021.add_to_excel("literature_annotation.xlsx")

# %%
Chand2019 = Annotation()

Chand2019.Title = "Construction of Composite Index"
Chand2019.Citation = "??Chand, P. Construction of Composite Index. Chapter 33, p.351-360, in Vinayak Nikam, A. J. (2019). Quantitative Methods for Social Science. New Delhi: ICAR - National Institute of AgriculturalEconomics and Policy Research"
Chand2019.In_Text_Citation = "Chand, 2019"

Chand2019_annot = {
"the (composite) indexing approach recognized as a simple and useful tool (for multi-dimensional issues) in policy analysis and public communication::p.351" : [Methodology, Variable],
"The indicator selection should be based on the analytical soundness, requirement of data complexity, measurability, geographical coverage, cost effectiveness in collection of data, relevance of indicators to the theme of measurement and their relationship to each other. Wherever, data are not available directly for an indicator, proxy variables should be used::p.352" : [Methodology],
"Three substeps for a composite index... Normalization of indicators...(Min-max, Z-score, Benchmarks, Thresholds, Ranking)... Assigning weights to different indicators...(Statistical tools..., Subjective weights...)... Construction of an aggregate index...(Additive, Geometric, Non-compensatory multi-criteria analysis).::p.352-356" : [Methodology, Variable],
"Step1- Selection of indicators: Economic Indicators, Social Indicators, Ecological Dimension ... Step2- Assigning of scores... Step3- Construction of index ::p.356-358" : [Methodology, Variable]
}

add_annots_from_dict(Chand2019, Chand2019_annot)

Chand2019.add_to_excel("literature_annotation.xlsx")

# %%
MazziottaPareto2013 = Annotation()

MazziottaPareto2013.Title = "Methods for constructing composite indices: One for all or all for one?"
MazziottaPareto2013.Citation = "Mazziotta, M., & Pareto, A. (2013). Methods for constructing composite indices: One for all or all for one?. Rivista italiana di economia, demografia e statistica, 67, 67-80."
MazziottaPareto2013.In_Text_Citation = "Mazziotta & Pareto, 2013"

MazziottaPareto2013_annot = {
"Phenomena such as development, progress, poverty, social inequality, well-being, quality of life, provision of infrastructures, etc., require, to be measured, the ‘combination’ of different dimensions, to be considered together as the proxy of the phenomenon::67" : [Methodology],
"following factors <<for best measuring method,p.71>> : type of indicators (substitutable/non-substitutable), type of aggregation (simple/complex), type of comparisons to be made (relative/absolute), type of weights of the indicators (subjective /objective)::p.69" : [Methodology],
"lively debate about the use of the most famous indicator of well-being: the Gross Domestic Product (GDP) .... The only alternative that has been successful, globally, is the Human Development Index or HDI (UNDP, 2010); it is published annually by the United Nations and it considers 3 individual indicators: Life expectancy at birth, Education and GDP per capita. It is a composite index itself (expressed in absolute form) since the 3 indicators were aggregated, until 2009, through a simple arithmetic mean .... Since 2010 United Nations Development Programme (UNDP) Report, the index has changed aggregation method: the arithmetic mean has been replaced with a geometric mean. In this way the problems of compensation are solved, but other problems are introduced, for example the case in which there are null values (or very close to zero). A further difficulty is linked to the same nature of the geometric mean, which assumes a multiplicative relationship of the variables ....::p.68" : [Methodology],
"Regional Quality of Development (QUARS) with the aim of providing a multidimensional measure of the development of Italian regions, based on 41 individual indicators from different sources. The considered dimensions are 7: Environment, Economy and labour, Rights and citizenship, Health, Education and culture, Equal opportunities, Participation .... The main weakness of the indices mentioned above is the use of a compensatory approach. Not assigning a weight to the indicators and dimensions, each variable has the same importance::p.69" : [Methodology, Variable],
"Defining the phenomenon to be measured. The definition of the concept should give a clear sense of what is being measured by the composite index. It should refer to a theoretical framework...Selecting a group of individual indicators. Ideally, indicators should be selected according to their relevance, analytical soundness, timeliness, accessibility, etc. The selection step is the result of a trade-off between possible redundancies caused by overlapping information and the risk of losing information. A statistical approach to indicators choice involves calculating correlation...Normalizing the individual indicators. This step aims to make the indicators comparable. Normalization is required prior to any data aggregation as the indicators in a data set often have different measurement units. Therefore, it is necessary to bring the indicators to the same standard, some indicators may be positively correlated with the phenomenon be measured (positive ‘polarity’), whereas others may be negatively correlated with it (negative ‘polarity’). We want normalize the indicators so that an increase in the normalized indicators corresponds to increase in composite index...Aggregating the normalized indicators. It is the combination of all the components to form one or more composite indices (mathematical functions). Different aggregation methods are possible::p.70-71" : [Methodology, Variable],
"theoretical part (definition of the phenomenon and selection of the indicators) is not separate from the statistical-methodological part::.p.71"  : [Methodology, Interdisciplinary],
"composite index is a complex process that involves stages of work well defined, where the arbitrary choices of the researcher has a significant effect on the final results::p.79" : [Methodology, Interdisciplinary]
}

add_annots_from_dict(MazziottaPareto2013, MazziottaPareto2013_annot)

MazziottaPareto2013.add_to_excel("literature_annotation.xlsx")

# %%
Ozyurt2020 = Annotation()

Ozyurt2020.Title = "IPARD II Desteklerinin Tarım-Sanayi İlişkisi Çerçevesinde Makro Ekonomik Açıdan Değerlendirilmesi"
Ozyurt2020.Citation = "Özyurt, İ. (2020). IPARD II DESTEKLERİNİN TARIM-SANAYİ İLİŞKİSİ ÇERÇEVESİNDE MAKRO EKONOMİK AÇIDAN DEĞERLENDİRİLMESİ. Finans Ekonomi Ve Sosyal Araştırmalar Dergisi, 5(2), 254-269. https://doi.org/10.29106/fesa.728127"
Ozyurt2020.In_Text_Citation = "Özyurt, 2020"

Ozyurt2020_annot = {
"IPARD (Katılım Öncesi Mali Yardım Aracı Kırsal Kalkınma Bileşeni) .... Program kapsamında verilecek destekler TKDK (Tarım ve Kırsal Kalkınmayı Destekleme Kurumu)’nun yapmış olduğu çağrılar ile duyurulmuş::p.255" : [TR_agroGov],
"hibelerin, imalat sanayisindeki girişim sayısı, üretim değeri ve satış değeri bazında olumlu etkileri olduğu, aynı olumlu etkilerin kısmen de olsa süt ve arıcılık üretim faaliyetlerine yansıdığı ancak tarımsal işsizlik, istihdam ve tarımsal işgücüne katılım oranları bakımından kırsal kalkınmada başarılı olma yönünde çok fazla bir etkisi olmadığı sonucu::p.255" : [TR_agroEcon, Rural_Livelihood, TR_Peasant],
"Tarım arazilerinin konut, sanayi, karayolu yapımı gibi amaçlar için imara açılması, plansız şehirleşme Türkiye'de tarım alanlarının yıllar itibariyle azalmasına yol açmıştır::p.256" : [TR_landUse],
"Tarım sektöründeki risk ve belirsizlikleri en aza indirebilmek için ülkemizde devlet destekli tarım sigortası uygulaması mevcuttur.::p.256" : [TR_agroGov],
"Ancak tarımsal üretici yeterli geliri elde edemediğinden sigorta uygulaması istenilen seviyeye gelememekte, üreticiler bu konuya gerekli ilgiyi göstermemektedir.::p.256" : [Policy_Access, Small_holder],
"tarım arazilerinin % 58'i sigortalanmıştır::p.256" : [Variable],
"Kırsal alandaki eğitim ihtiyacının giderilmesi için gerekli yatırımların yapılması şarttır. Okuma-yazma ya da MEB müfredatı dışında tarımsal üretim, finansman, pazarlama ve yönetim ile ilgili temel eğitimlerin verilmesi gerekmektedir.... Ülkemizde tarım alanında meslek okulları vardır.::p.256" : [Education, Variable],
"düğümü tarımsanayi entegrasyonudur ve üretim, işleme, pazarlama, mevzuat, örgütlenme, destekleme, yöneylem, bütünleşme, rekabet analizi, dış ticaret gibi birçok disiplini ve faaliyet sahasını/safhasını ihtiva ede::p.257" : [Agro_econ, Food_Network],
"Ekonomik sınıflandırma sistemlerinin geliştirilmesinin temel amacı, homojen özelliklere sahip sektörel bölümlendirmenin oluşturulması ve veri setlerinin istatistiksel olarak anlamlı özelliklere sahip olmasının sağlanmasıdır::p.257" : [Methodology],
"rasyonel tarım üretimi yapabilen ülkelerde tarımsal ürünlerin yaklaşık % 60'ının sanayi tesislerinde mamül veya yarı mamül hale getirilebildiği, Türkiye için bu oranın en iyimser rakamlarla % 30 düzeyinde olduğu belirtilmektedir (Gürler, 2016, s.430). Yani Türkiye, tarımsal ürünleri hammadde olarak pazarlamaktadı::p.258" : [Agro_international, TR_agroEcon],
"Çiftçi sanayici entegrasyonunu sağlamada bir araç olarak karşımıza çıkan sözleşmeli yetiştiricilik modeli::p.258" : [Autonomy, Small_holder, Food_Network],
"Kırsal kalkınma, en genel tanımıyla kırsal alanda yaşayan fertlerin ekonomik ve sosyal refahı ile yaşam kalitesini artırma sürecidir:.p.259" : [Rural_Development],
"Planda; kırsal nüfusun iş ve yaşam koşullarının iyileştirilmesi, kırsal kesimdeki refah düzeyinin ülke ortalamasına yaklaştırılması, kırsal ekonominin ve istihdamın güçlendirilmesi::p.259" : [Buyuksehir_Law, Rural_Development],
"OECD'ye göre kırsal alan, nüfus yoğunluğunun kilometre kare başına 150 kişinin altında olduğu yerlerdir.... OECD kırsal alan kavramını açıklarken 'kırsallığı baskın bölgeler', 'önemli ölçüde kırsal bölgeler' ve 'kentselliği baskın bölgeler olmak üzere 3'lü bir tasnif yapmıştır. Buna göre eğer nüfusun % 50'den fazlası kırsal kesimde ise kırsallığı baskın bölge, %15 ile % 50 arası ise önemli ölçüde kırsal bölge ve %15'ten az ise kentselliği baskın bölge olarak bir ayrım yapılmıştır::p.259" : [Rural_Policy, Variable, Agro_international],
"1962 yılında Avrupa Tarımsal Garanti ve Yönverme Fonu (FEOGA) kurmuşlardır.::p.260" : [Agro_international, History],
"IPARD ajansları, Araştırma-Planlama ve Koordinasyon Kurulu Başkanlığı, Planlama ve Projeler Dairesi Başkanlığı, Tarım ve Kırsal Kalkınmayı Destekleme Kurumu, Tarım Reformu Genel Müdürlüğü gibi idari yapılar kurulmuş ve kısa vadeli hedefler kapsamında da Ulusal Çiftçi Kayıt Sistemi, Ulusal Hayvan Kayıt Sistemi, Ulusal Kırsal Kalkınma Stratejisi oluşturulmuştur.::p.260" : [TR_agroGov],
"IPARD programı ülkemizde 42 ilde yürütülmektedir.::p.262" : [Policy_Access, Variable, TR_agroEcon],
"Buna göre IPARD II kapsamında 25.04.2019 tarihi itibariyle 3.967 adet sözleşme imzalanmıştır. Fesih edilen sözleşme sayısı ise 417'dir. Çalışmanın materyalini imzalanan ve fesih edilen projeler oluşturmaktadır.:.p.261" : [Survivorship_bias],
"imzalanan sözleşmelerin en fazla kırmızı et ve süt üretiminde yoğunlaştığını görüyoruz. Bu kapsamda % 53 ile en fazla kırmızı et üretimi alanında sözleşme imzalandığı görülmektedir. Bunu % 35 ile süt üretimi izlemektedir.103 nolu tedbirin dağılımını incelediğimizde % 52 ile en fazla meyve ve sebze işleme ve pazarlama faaliyetlerinin desteklendiğini görüyoruz. Bunu % 27 ile süt ürünleri, % 15 ile et ürünleri izlemiştir::p.263" : [Policy_Access, Rural_Livelihood, TR_ruralGov],
"Tedbirleri genel olarak değerlendirdiğimizde en fazla yatırım tutarı ve TKDK desteğinin sırasıyla 101.2 kırmızı et üreten tarımsal işletmeler, 101.1 süt üreten tarımsal işletmeler, 302.4 kırsal turizm ve rekreasyon ve son olarak 103.5 meyve ve sebze işleme ve pazarlama faaliyetlerine istinaden planlanıp verildiğini görüyoruz. İmzalanan sözleşme adedi bakımında da 301.1 bitkisel üretim çeşitlendirilmesi ve bitkisel ürünlerin işlenmesi ve pazarlanması ile 301.2 arıcılık faaliyetleri öne çıksa da bunların her biri küçük yatırımlardır::p.264" : [Policy_Access, Rural_Development, TR_agroEcon],
"103 nolu tedbir faydalanıcılar tarafından daha az tercih edilmiştir. Çünkü bu tip yatırımlar maliyetlidir ve özel şahıslarda 103 tedbiri kapsamında tesis kurulumu sağlayabilecek bir sermaye birikimi yoktu::p.264" : [Policy_Access, Small_holder],
"Aynı bölgede 2017 yılında tarımsal işgücüne katılmayanların oranında % 32'lik ve 2018 yılında % 13'lük bir artış olmuştur. Diyarbakır, Şanlıurfa Bölgesi'nde 2018 yılı tarımsal işsizlik artışı % 34'tür. Hatay, Kahramanmaraş, Osmaniye Bölgesi'nde tarımsal işsizlik 2018 yılında % 41 oranında artmış ve yine aynı bölgede aynı yıl tarımsal işgücüne katılmayanların oranı % 17'lik bir artış göstermiştir. Ankara'da 2018 yılında tarımsal işsizlik % 50 oranında artmıştır::p.265" : [Variable, TR_Peasant],
"Sözleşmelerin % 78'i gerçek kişi statüsünde basit usulde vergilendirilen mükelleflerle imzalanmıştır. Sözleşmelerin % 20'si sermaye şirketi statüsündeki tüzel kişiler ile imzalanmıştır. Bunun % 18'i limited şirket, % 0,2'si anonim şirkettir. Sermaye şirketleri ile imzalanan sözleşmelerin % 15'i fesih edilmiştir. Gerçek kişilerde fesih oranı % 0,9'dur::p.266" : [Big_agro, Small_holder, TR_agroEcon]
}

add_annots_from_dict(Ozyurt2020, Ozyurt2020_annot)

Ozyurt2020.add_to_excel("literature_annotation.xlsx")

# %%
AtikTaskan2020 = Annotation()

AtikTaskan2020.Title = "Kentsel Yayılmanın Gölgesinde Değişen Kırsal-Tarımsal Peyzajlar İçin Sürdürülebilir Tarımsal Kuşak Planlaması Önerisi: “Burse Kenti” Örneği"
AtikTaskan2020.Citation = "Taşkan, G., & Atik, M. (2020). Kentsel Yayılmanın Gölgesinde Değişen Kırsal-Tarımsal Peyzajlar İçin Sürdürülebilir Tarımsal Kuşak Planlanması Önerisi: “Bursa Kenti” Örneği. Peyzaj Araştırmaları Ve Uygulamaları Dergisi, 2(1), 1-10."
AtikTaskan2020.In_Text_Citation = "Atik & Taşkan, 2020"

AtikTaskan2020_annot = {
"kent çeperindeki kırsal peyzajlar olarak tanımladığımız bu alanlar, doğal niteliklerinin yanı sıra insan faaliyetlerini de barındıran::p.2" : [Rurban],
"sınırlayan bir bölge oluşturulması fikri dünya genelinde yaygın olarak kullanılan bir koruma yöntemidir. Kırsal alanların korunmasındaki bu yöntem yaklaşımında kırsal alanların tanımlanmasını takiben bir kuşak belirlenmekte ve böylece kentsel yayılmanın kırsal alanlar üzerindeki baskısının önlenmesi amaçlanmaktadır::p.2" : [Urbanization],
"arasındakini değişimini yorumlayabilmek adına 1990-2000-2006-2012 ve 2019 yılları arazi kullanım haritaları oluşturulurmuştur::p.3" : [Land_Use, Methodology, Variable],
"peri-kentleşme eğilimleri::p.3" : [Rurban],
"kentsel gelişimi kentin artan konut ihtiyacına olan talebin karşılanması sonucudur::p.5" : [Land_Use, TR_Peasant],
"1998 yılında imzalanan ve 2020 yılını hedef alan Bursa 2020 1/100000 Ölçekli Çevre Düzeni Planı ile alt ölçekli planlama çalışmalarını yönlendirecek ve sınırlarını belirleyecek planlama bölgeleri, Bursa Metropolitan Alanı ve Metropolitan Alan Planlama Bölgeleri tanımlanmıştır::p.5" : [Buyuksehir_Law],
"Ancak 5403 sayılı toprak koruma ve arazi kullanımı kanunu ile tarım arazilerinin sınıflamaları, bölünemez büyüklükleri, tarımsal yapılar, tarım dışı kullanım izinleri, toprak kurulu gibi mevzuatta yaşanan köklü değişikliklerin mevcut plana yansıtılmaması amacı ile revizyona gerek görülmüştür.::p.5" : [Land_Policy, TR_agroGov],
"2012 tarihinde 6360 sayılı Yasa ile Bursa Büyükşehir belediye sınırlarının il sınırlarına kadar genişletilmiştir.::p.6" : [Buyuksehir_Law],
"hangi yayılma modelinin (saçaklanma,yayılma, sıçrama)::p.6" : [Land_Use, Variable],
"<<TDİOSB'ler>>Bursa Ovası ve Yenişehir Ovası 2000 yılı ve öncesi şeftali, zeytin ya da sebze bahçesi olarak kullanılan tarımsal alanların yoğunlukta olduğu bir kesit iken (Ünaldı ve ark. 2007); bugün BursaEskişehir karayolu üzerinde yer alan soğuk hava depoları, meyve suyu fabrikalarının yanı sıra 2001 yılında Uludağ (Gürsu) Organize Sanayi Bölgesi ve ardından 2004 yılında Kestel Organize Sanayi Bölgesi (KOSAB) tescilini alması ile iki adet sanayi bölgesi bulunmaktadır.::p.7" : [Rural_Development, Urbanization, Variable],
"göç sebebi ile ovadaki tarım topraklarının yerleşime açılması sebebi ile ve kentin plânsız gelişmesine ve çevredeki akarsuları kirletmesine neden olduğunu tartışmışlarıdır.::p.8" : [Agroecology, Urbanization], 
"Tarımsal kuşak planlaması, Aktif kırsal yaşam özelliklerinin ve tarımsal olarak üretkenliğin hayatta kalmasına katkı sağlamaktadır::p.9" : [Agroecology]
}

add_annots_from_dict(AtikTaskan2020, AtikTaskan2020_annot)
AtikTaskan2020.add_to_excel("literature_annotation.xlsx")

# %%
Yaman2021 = Annotation()

Yaman2021.Title = "Kırsal Alanın Dönüşümü: Kırklarelı–Lüleburgaz-Pınarhisar Örneği"
Yaman2021.Citation = "Yaman, A. (2021). Kırsal Alanın Dönüşümü: Kırklarelı–Lüleburgaz-Pınarhisar Örneği. Dünya İnsan Bilimleri Dergisi, 2021(1), 188-209."
Yaman2021.In_Text_Citation = "Yaman, 2021"


Yaman2021_annot = {
"tarım politikası iki ana başlık altında ele alınmaktadır. Birincisi tarımsal gelişimi kalkındırma ve gelir eşitsizliğini azaltma, ikincisi ise devlet politikalarının değerlendirilmesi ile ilgilidir::p.190" : [TR_agroGov],
"1980 sonrası... 24 Ocak kararlarıyla birlikte... yeni arz ve talebin piyasaya göre belirleneceği bir varsayıma dayanmaktadır. .. İhracatın artırılmasına yönelik politikalara başvurulmuştur::p.190" : [History, TR_agroEcon],
"Sanayi için girdi fiyatlarının düşük tutulması yolu ile tarımsal ürünlerin fiyatlarını aşağı çekmiş böylece kentsel nüfusun ihtiyaçlarının karşılanması hedeflenmiştir::p.191" : [Urbanization, Deruralization, History],
"2001'de uygulanmaya başlanan Tarım Reformu Uygulama projesi... bu bağlamda 2001'de Çiftçi Kayıt Sistemi(ÇKS) uygulamaya... Doğrudan Gelir Desteği(DGD)::p.192" : [History, TR_agroGov],
"ABD ile AB'nin DGD uyguladığı alanlar (bizdeki çay, tütün, fındık gibi), aşırı üretim dolayısıyla pazarlama ve stok sorunları yaşayan kesimdir::p.193" : [Agro_econ, Agro_policy],
"DGD ile ürün ayrımı yapmadan, tapuya kayıtlı toprağa göre para dağıtılması::p.193" : [Agro_policy, TR_agroGov, TR_Peasant],
"Özellikle son yıllarda hayvancılık yatırımlarını cazip hale getirmek için %100'e ulaşan kredi destek uygulamalarına ağırlık verilmiştir::p.194" : [Debt, TR_ruralGov],
"yeni uygulamalara hız verilmiştir. Örneğin 2007'de Tarıms ve Kırsal Kalkınma Destekleme Kurumu (TKDK) kurulmuştur.::p.194" : [Rural_Development, TR_ruralGov, TR_agroGov],
"Tarımsal arazilerin parçalanması ise işletme ölçeğinin küçülmesine ve dolayısıyla tarımsal verimliliğin azalmasına neden olmaktadır::p.195" : [Rural_Livelihood, TR_landUse],
"Türkiye'de buna yol açan en öneöli neden, miras ve intikal yoluyla tarım arazilerinin parçalanması görülmektedir::p.196" : [TR_landUse, TR_Peasant],
"ölçek ekonomisinin tarımsal üretim araçlarına ve üretime olan etkisi araştırılmaktadır::p.196" : [Variable, Agro_econ],
"Tarım Bakanı Mehdi Eker 2009'da Denizli Acpıpayam'da kurulan..... ziyaretinde verdiği bir röportajda, yeni hayvancılık destekleme stratejilerinde ölçek ekonomisini hedeflediklerini, hijyene önem veren, büyük ölçekli işletmeleri destekleyeceklerini söyleyerek::p.197" : [Small_holder, Food_Sovereignty, Food_Security, TR_agroGov],
"haritada gösterilen yerler 2011 yılna kadar tarım alanı olarak hububat ekimi için kullanılmaktaydı. Ancak 2011 yılı sonrasında bölgeye gelerek belirli bölgelerde arazi satın alan kır dışı sermaye tarafından entegre büyükbaş hayvan çiftliklerine dönüştürülmüştür::p.199" : [TR_Peasant, Big_agro, TR_landUse],
"Köyümüzde aileden çiftçi olan gençlerin artık kendi işlerini yapmak yerine kurulan bu çiftliklerde sigortalı olarak çalışmayı tercih ettiklerini söylemektedir::p.201" : [TR_Peasant, Food_Sovereignty, Deruralization],
"..erkek çocuklarımın.. ikisi de çiftçilik yapmak istemiyor. Ben kendi arazilerimi işleyip geçinemiyorum, emekliyim... o yüzden köyde kurulan çiftlikte 1200 lira maaşla çalışıyorum... hem de çiftlik sahibinin tarım arazilerini kendi arazilerimle birlikte işliyorum::p.201" : [Rural_Livelihood, Deruralization, Food_Sovereignty],
"süt üretiminde makine kullanımı sayısı artışı - <<tarımda makine kullanımı, traktör sayıları>>::p.203" : [Variable, Agro_tech]
}

add_annots_from_dict(Yaman2021, Yaman2021_annot)

Yaman2021.add_to_excel("literature_annotation.xlsx")

# %%
Sezer2021 = Annotation()

Sezer2021.Title = "Modern Köyün İnşası: Erken Cumhuri̇yet Dönemi̇ Kırsalında İskan Poli̇ti̇kaları Üzeri̇ne Bi̇r Değerlendi̇rme"
Sezer2021.Citation = "Sezer, Ö. (2021). Modern Köyün İnşası: Erken Cumhuri̇yet Dönemi̇ Kırsalında İskan Poli̇ti̇kaları Üzeri̇ne Bi̇r Değerlendi̇rme. TÜBA-KED Türkiye Bilimler Akademisi Kültür Envanteri Dergisi(24), 127-144. https://doi.org/10.22520/tubaked2021.24.007"
Sezer2021.In_Text_Citation = "Sezer, 2021"

Sezer2021_annot = {
"birlikte bir milyondan fazla Ortodoks Rum Anadolu ve Trakya’dan Yunanistan’a gönderilmiş, çoğunluğu tarımla uğraşan köylülerden oluşan 400 bine yakın Müslüman Türk ise Yunanistan topraklarından ülkeye getirilmiştir.::p.130" : [History, TR_ruralGov],
"11 Haziran 1945 yılında Çiftçiyi Topraklandırma Kanunu’nun kabul edilmesi..Fakat Çiftçiyi Topraklandırma Kanunu ile hedeflenen toprak reformu hiçbir zaman kırsal nüfusun ekonomik gelişiminde önemli ölçüde rol oynamamıştır::p.130" : [History, TR_Peasant, TR_ruralGov],
"Halkevlerinin Köycülük Kolu üzerinden hareket eden çalışmalar köylülerin ihtiyaçlarının karşılanmasında destek sağlayacak eğitmenlerin yetiştirildiği özel bir programın geliştirilmesine doğru evirilmiştir. İlk olarak 1937’de Köy Eğitmenleri Kanunu kabul edilir. (Köy Eğitmenleri Kanunu, 1937) 1938’de ülkenin farklı bölgelerinde Köy Eğitmenleri yetiştirmek için kurulan köy okulları, 1940’ta yürürlüğe giren kanun ile yasal olarak Köy Enstitüleri’ne dönüşür::p.131" : [History, TR_ruralGov],
"ilanından sonra yasal olarak atılan iki önemli adım 18 Mart 1924’te yürürlüğe konan Köy Kanunu ve 31 Mayıs 1926’da kabul edilen İskân Kanunu olmuştur. Köy Kanunu ilk kez köyü tüzel anlamda bir birim olarak tanımlar::p.132" : [History, TR_ruralGov]
}

add_annots_from_dict(Sezer2021, Sezer2021_annot)

Sezer2021.add_to_excel("literature_annotation.xlsx")

# %%
Iban2020 = Annotation()

Iban2020.Title = "Türkiye Kırsal Arazi Kullanımına Yönelik Bir Konumsal Veri Altyapısının Modellenmesi"
Iban2020.Citation = "İban, M. C. (2020). Türkiye Kırsal Arazi Kullanımına Yönelik Bir Konumsal Veri Altyapısının Modellenmesi. Geomatik, 5(3), 209-227. https://doi.org/10.29128/geomatik.644623"
Iban2020.In_Text_Citation = "İban, 2020"

Iban2020_annot = {
"KVA girişiminin kurulması ile sonuçlanmıştır (İng. Infrastructure for Spatial Information in Europe – kıs. INSPIRE). Buradaki amaç, yasal bir direktif vasıtasıyla Avrupa’nın çevre politikalarını destekleyecek konumsal verilerin bütüncül bir çerçevede çalışmasını sağlamaktır::p.210" : [Methodology, Rural_Development],
"mevzuatımızdaki iki büyük değişiklikle.. birincisi 5403 sayılı Tarım Alanlarının Korunması ve Arazi Kullanımı Kanunu’dur::p.211" : [TR_agroGov],
"Büyükşehirlerin, ilin bütününü planlama ve planlarını uygulama sorumluluklarının doğmasıyla, aslında “arazi yönetimi ve kullanımı idari birimleri” büyükşehir belediyeleri olmuştu::p.211" : [Buyuksehir_Law, TR_ruralGov],
"APTS çalışmaları kapsamında kullanılan arazi kullanımı / örtüsü sınıflandırma sistemleri, tarım arazilerinin anlaşılması için gereken detaylı toprak sınıflaması anlayışından uzaktır::p.211" : [Land_Use, Variable],
"Tarımsal İzleme ve Bilgi Sistemi Projesi (TARBİL), 2008 yılında başlatılan::p.211" : [TR_agroGov],
"Türkiye’de 23.1 milyon kadastro parseline karşılık, 32.5 milyon tarım parselinin varlığı tespit edilmiştir::p.212" : [TR_landUse, Variable],
"Aynı zamanda, 81 ilde 10 bine yakın personelin çalıştırılması ile Tarım Envanteri Yönetim Sistemi::p.212" : [TR_agroGov],
"mera varlığı, “Türkiye Geneli Mera Tespit ve Tahdit Çalışmaları::p.212" : [Variable],
"TARBİL Projesi için kullanılan sensör verileri, 5403 sayılı Kanun’un yüklediği arazi kullanım planlaması ve arazi sınıflandırması sorumluluğunu yeterli derecede karşılamamaktadır... Dolayısıyla, TARBİL çalışmalarına toprak sınıflandırmasında önemli yer tutan analitik verileri üretebilecek optik, jeoelektrik, mekanik ve elektrokimyasal sensörlerin de dahil edilmesi gerekmektedir.::p.213" : [Methodology, Variable],
"Dolayısıyla 5403 sayılı yasaya göre yapılan sınıflandırmayı içeren veri setinde, hem yerel olarak kullandığımız eski Amerikan sınıflandırmasına dayanan 1984 yılında tamamlanan Türkiye Toprak Envanteri’nde kullanılmış “Büyük Toprak Grubu” sınıfları, hem de FAO’nun World Reference Base (kıs. WRB) toprak sınıfları bir arada öznitelik olarak sunulmuştur::p.213" : [Methodology, TR_landUse],
"“tarimsalNitelik” özniteliği, “5403Siniflandirma” veri tipi ile bağdaştırılarak::p.214" : [Variable],
"TarimParseli özellik tipi ile ilişkilendirilen diğer öznitelikler ise “GidaSertifikasi, CATAK ve TarimDisiAraziKullanimi::p.214" : [Variable],
"“Sertifikalar” kod listesinde sunulmuştur. Bu sertifikalar, mevzuattaki şartları sağlayan şirketlere verilen organik tarım, iyi tarım uygulamaları ya da gıda güvenliği sertifikaları olarak::p.214" : [Variable, TR_agroGov],
"“5403AraziTuru” kod listesi ile betimlenen “tur” özniteliğidir. Bu öznitelik aslında, elde edilen diğer veriler aracılığıyla karar verilen sınıflandırma sonucu olup, arazinin mutlak, marjinal, örtü altı, dikili ya da özel ürün tarım arazisi olması arazi kullanım planlaması kararlarını doğrudan etkilemektedir::p.215" : [Methodology, Variable],
"Her mera alanı için, otlatma hakkı ve kapasitesi, tahsis bilgileri ve büyükbaş hayvan birimi gibi nitel ve nicel veriler öznitelik olarak eklenmiştir::p.215" : [Variable],
"“OrmanNesne” özellik tipi, “OrmanAlanlari”, “OrmanYangin” ve “2bAlanlari” özellik tiplerini kapsamaktadır. 6831 sayılı Orman Kanunu’nun tanımları::p.215" : [Variable],
"5403 Sınıflandırma Veri Tipi ve Kapsadığı Kod Listeleri::p.216" : [Risks_Global, TR_landUse, Variable],
"kooperatifleşme kapasitesi::p.218" : [Cooperatives, Variable],
"tarım arazilerinin ortaklaşa kullanımı tapu sicil sisteminde kayıt altında değildir::p.218" : [Rural_Livelihood, Variable]

}

add_annots_from_dict(Iban2020, Iban2020_annot)

Iban2020.add_to_excel("literature_annotation.xlsx")

# %%
Birben2018 = Annotation()

Birben2018.Title = "Hızlı Kırsal Değerlendirmeden Katılımcı Kırsal Değerlendirmeye: Benzerlikler, Farklılıklar ve Avantajlar"
Birben2018.Citation = "Ünal, H. E., Birben, Ü., & Özden, S. (2018). Hızlı Kırsal Değerlendirmeden Katılımcı Kırsal Değerlendirmeye: Benzerlikler, Farklılıklar ve Avantajlar. Sosyal Ve Beşeri Bilimler Araştırmaları Dergisi, 19(41), 129-140."
Birben2018.In_Text_Citation = "Birben et al., 2018"


Birben2018_annot = {
"hayvancılık yönetimi::p.130" : [Variable],
"köy sağlığı teşviki::p.130" : [Variable],
"havza yönetimi::p.130" : [Variable],
"kent temizliği önlemleri::p.130" : [Variable],
"toplumsal cinsiyet farkındalığı::p.130" : [Variable],
"mikro kredi kuruluşları::p.130" : [Agro_econ, Food_Sovereignty, Variable],
"KKD yaklaşımında bilgilerin yerel gruplar tarafından analiz edilip::p.130" : [Food_Sovereignty, Methodology],
"HKD’de ise daha çok yerel düşüncelere önem verilmesi::p.130" : [Food_Security, Methodology],
"kırsal turizm::p.132" : [Rural_Livelihood],
"Katılımcı Kırsal Değerlendirme (KKD) KKD 1980’lerde ortaya çıkan bir yaklaşım olup::p.132" : [History, TR_ruralGov, Collectives],
"Kapasite geliştirme::p.133" : [Variable, Autonomy],
"yerel halk çevre konusunda dışardan gelen uzmanlardan daha bilgilidir::p.133" : [Agroecology, Education, Interdisciplinary],
"HKD ve KKD’de kullanılan birçok yöntem olmakla birlikte bu yöntemlerin çoğu her iki yaklaşımda da kullanılabilmektedir.::p.136" : [Food_Security, Food_Sovereignty, Methodology],
"okul::p.137" : [Variable],
"nüfus değişimi::p.137" : [Variable],
"yerel bir ürün::p.137" : [Seed, Food_Sovereignty, Variable],
"mevsim ve aylara göre günleri ve yağmurun dağılımını::p.137" : [Variable],
"Geçim analizi İstikrar::p.137" : [Variable],
"hanehalkı kümeleri::p.138" : [Variable, Rural_Livelihood],
"meslek::p.138" : [Rural_Livelihood, TR_Peasant, Variable],
"tohumları kullanarak puanlama ile kıyaslama. Örneğin, farklı ağaçlar ya da farklı topraklar::p.138" : [Agroecology],
"karşılıklı kritik yapma ve yardımlaşma::p.138" : [Cooperatives, Rural_Development, Variable],
"Köylülerin kendi plan, bütçelerini ve programlarını hazırlayıp::p.138" : [Autonomy, Variable]

}

add_annots_from_dict(Birben2018, Birben2018_annot)

Birben2018.add_to_excel("literature_annotation.xlsx")

# %%
DemirtasKaya2018 = Annotation()

DemirtasKaya2018.Title = "Evaluation of Public Agricultural Extension Programs: The Case of Hatay Province (Turkey)"
DemirtasKaya2018.Citation = "Demirtaş, B., & Kaya, A. (2018). Evaluation of Public Agricultural Extension Programs: The Case of Hatay Province (Turkey). Türk Tarım Ve Doğa Bilimleri Dergisi, 5(2), 203-210. https://doi.org/10.30910/turkjans.421369"
DemirtasKaya2018.In_Text_Citation = "Demirtaş & Kaya, 2018"

DemirtasKaya2018_annot = {
"every increase in agricultural production is achieved by higher output per hectare since lowcost land transformation opportunities do not exist:.p.204" : [Agro_econ, Big_agro, Small_holder],
"all-scale farms (Labarthe and Laurent, 2013). The small-scale farms, by and large, that have benefited from extension services have marked a better productivity when compared to middle and large scale enterprises::p.204" : [Rural_Policy, Small_holder],
"Agricultural sector, still, mainly consists of small and geographically disjointed units and resultantly, the information is still internally preserved:.p.205" : [Education, Land_Use],
"Public agricultural extension services play an important role for the implementation of rural development strategies based on sustainable management of natural resources::p.205" : [Rural_Policy, Variable],
"Training and Visiting system (T&V) introduced by the World Bank in 1970s::p.206" : [History, Agro_international],
"technological transfer’’. In Turkey, Agricultural Extension and Applied Research Project (AEARP)::p.206" : [Education, History, Agro_tech],
"In the current five-year development plan (2014-2018), the small and scattered organization of agricultural businesses, insufficiencies in market access and sectorial organization and the lack in the extension of education-extension services are mentioned as serious problems.::p.206" : [TR_agroGov],
"farmer's training:.p.207" : [Variable],
"soil analysis::p.207" : [Variable],
"During farm days, various topics were covered including certified seed plantation, organic farming (strawberries and olives), integrated fighting (farming grains, cottons and olives, as well as, greenhouse production and viniculture), developing alternative production methods (strawberries and blackberries), extending modern irrigation techniques and expending the plantation of honey plants for increasing the productivity in beekeeping.::p.207" : [Education],
"switch from supply-oriented extension to participant-oriented extension approaches::p.209" : [TR_Peasant, TR_agroGov]
}

add_annots_from_dict(DemirtasKaya2018, DemirtasKaya2018_annot)

DemirtasKaya2018.add_to_excel("literature_annotation.xlsx")

# %%
Angin2016 = Annotation()

Angin2016.Title = "Sulama Mekanizasyonu Hibe Destekleri ve Bölgesel Farklılıklar"
Angin2016.Citation = "Vurarak, Y., Çatalkaya, V., Angın, N., Bilgili, E. (2016). Sulama Mekanizasyonu Hibe Destekleri ve Bölgesel Farklılıklar. Tarım Makinaları Bilimi Dergisi, 12(2), 85-93."
Angin2016.In_Text_Citation = "Angın et al., 2016"


Angin2016_annot = {
"112 milyar m3 kullanılabilir su kaynağından yararlanma oranı yaklaşık %39 olup, bu kaynağın yaklaşık 32 milyar m3 ‘ü (%73) sulamada, geri kalan ise içme/kullanım ile sanayide::p.86" : [Variable],
"arazi toplulaştırılması, arazi ıslahı çalışmaları, sulama alt yapısı ve sulama tasarrufu sağlayan modern sulama sistemlerinin yaygınlaştırılması::p.86" : [TR_agroGov, TR_landUse, TR_ruralGov],
"alt yapı destekleme politikaları::p.86" : [Buyuksehir_Law, TR_agroGov, Variable],
"gerçek kişiler için 100 000 TL yi, tüzel kişiler için 200 000 TL yi geçmemektedir::p.86" : [Small_holder, TR_agroGov],
"Asya ve Pasifik Ülkelerinin ise %65’inin ciddi su sorunu ile karşı karşıya kalacakları rapor edilmiştir (Soylu ve ark., 2006). Türkiye, su zengini olmayan ülkelerden biri durumundadı::p.86" : [Risks_Global],
"sulama sistemlerinin toplam içindeki payları::p.87" : [Variable],
"GAP ile sulamaya açılan alanları::p.89" : [Variable],
"hibe desteği ile alınan hareketli başlıklı yağmurlama sulama sistem::p.90" : [Variable],
"Sulama sistemleri içinde kurulum (enerjisi) karbon eşdeğeri/ha olarak en fazla yağmurlama::p.92" : [Variable],
"bölgelere göre desteklenecek sulama sistemlerinin belirlenmesi gibi daha spesifik ayrımlara gidilmesi ile mekanizasyon parklarının büyük ve pahalı bir hurda yığını halini almalarının da engellenebileceği söylenebilir::p.92" : [Agroecology, TR_agroGov]
}

add_annots_from_dict(Angin2016, Angin2016_annot)

Angin2016.add_to_excel("literature_annotation.xlsx")

# %%
Akci2016 = Annotation()

Akci2016.Title = "Tarım Arazilerindeki Yapılaşma Baskısının Azaltılmasında Köy Gelişme Alanı ve İmar Uygulamaları: İç Anadolu Bölgesi Örneği"
Akci2016.Citation = "Akci, A., Demirel, M. K., & Şen Becu, H. (2016). Tarım Arazilerindeki Yapılaşma Baskısının Azaltılmasında Köy Gelişme Alanı ve İmar Uygulamaları: İç Anadolu Bölgesi Örneği. Nevşehir Bilim V e Teknoloji Dergisi, 5, 372-384. https://doi.org/10.17100/nevbiltek.211028"
Akci2016.In_Text_Citation = "Akçı et al., 2016"


Akci2016_annot = {
"5 milyar hektarını tar ım arazileri oluşturmaktadır::p.373" : [Variable],
"1,5 milyar hektar alanda tarla bitkileri yetiştiriciliğinin yapıldığı, yine 1,5 milyar hektarda çok yıllık bitkilerin dikili bulunduğu görülmektedir. Geriye kalan 2 milyar hektar alan ise çayır ve mera şeklinde değerlendirilmektedir::p.373" : [Agro_international, Land_Use],
"İşlemeli Tarıma Uygun Araziler::p.373" : [Variable],
"nadasa bırakılan arazilerde yıllar itibariyle azalma görülmesine rağmen ekilen araziler her yıl azalmaktadı::p.373" : [TR_landUse, Variable],
"Mera Kanunu::p.373" : [TR_ruralGov],
"21,4 milyon hektarı işlenen tarım arazisi olup::p.374" : [Variable],
"mülga Tarım ve Köyişleri Bakanlığı::p.374" : [TR_agroGov, TR_ruralGov],
"tarımsal fiyat ve destekleme politikasının olumsuz etkileri::p.375" : [TR_ruralGov],
"tarım arazileri üzerindeki yapılaşma::p.376" : [Variable],
"Köy gelişme alanı olarak ayrılan hazine arazisinde::p.376" : [TR_ruralGov, Rural_Development],
"sağlık ocağı::p.377" : [Variable],
"mevsimsel yağışlara::p.379" : [Variable],
"sel baskını::p.379" : [Variable],
"konut yapmak için yeterli alan olmadığından::p.379" : [Variable],
"442 Sayılı Köy Kanunu ve Köy Yerleşim Alanı Uygulama Yönetmeliği::p.382" : [Rural_Policy, TR_ruralGov],
"3083 Sayılı Sulama Alanlarında Arazi Düzenlenmesine Dair Tarım Reformu Kanunu ve 5403 Sayılı Toprak Koruma ve Arazi Kullanımı Kanunu’na göre uygulanan köy gelişme alanıdır.::p.382" : [Rural_Policy, TR_ruralGov, TR_landUse],
"Köy gelişme alanı::p.383" : [Food_Security, Food_Sovereignty, Rural_Livelihood]
}

add_annots_from_dict(Akci2016, Akci2016_annot)

Akci2016.add_to_excel("literature_annotation.xlsx")

# %%
Aba2015 = Annotation()

Aba2015.Title = "IPARD Makine ve Ekipman Desteklerinin Mardin Tarımına Etkisi"
Aba2015.Citation = "Cihangir, H., Bilgiç, B., & Aba, T. (2015). IPARD Makine ve Ekipman Desteklerinin Mardin Tarımına Etkisi. Tarım Makinaları Bilimi Dergisi, 11(1), 25-31."
Aba2015.In_Text_Citation = "Aba et al., 2015"

Aba2015_annot = {
"Katılım Öncesi Yardım Aracı’nın (Instrument for Pre-Accession Assistance-IPA) Kırsal Kalkınma bileşenidir. 2007-2013 yıllarını kapsayan IPARD programı, Avrupa Birliği’nin Ortak Tarım Politikası, Kırsal Kalkınma Politikası ve ilgili politikaların uygulanması ve yönetimi için uyum hazırlıklarını::p.26" : [Agro_international, Agro_policy, Rural_Policy],
"AB komisyonu tarafından akredite edilen TKDK, 1. ve 2. faz olmak üzere toplam 42 ilde teşkilatlanmasını gerçekleştirerek, 2011 yılından itibaren proje kabulüne başlamıştır.::p.26" : [TR_agroGov, TR_ruralGov],
"makine ekipman sayısı bakımından arıcılık faaliyetlerine en fazla desteği verildiği görülmektedir.::p.27" : [Rural_Livelihood],
"12. Çağrı ilanından (2014 yılı) itibaren TKDK makine ekipman destek kaleminde olan traktörün, 2014 yılında destek kapsamından çıkarılmasıdır::p.30" : [TR_agroEcon, TR_agroGov]
}

add_annots_from_dict(Aba2015, Aba2015_annot)

Aba2015.add_to_excel("literature_annotation.xlsx")

# %%
Can2014 = Annotation()

Can2014.Title = "İzmir İlinde Tarımsal Üretici Örgütlerinin Hibelerden Yararlanma Durumları"
Can2014.Citation = "Yılmazçoban, M., Sayılı, M., & Can, M. (2014). İzmir İlinde Tarımsal Üretici Örgütlerinin Hibelerden Yararlanma Durumları. Çankırı Karatekin Üniversitesi Sosyal Bilimler Enstitüsü Dergisi, 5(1), 193-210." 
Can2014.In_Text_Citation = "Can et al., 2014"

Can2014_annot = {
"doğal kaynak potansiyelini::p.194" : [Variable],
"Tarımsal üreticilerin ürün ve üretimlerinin çeşitliliği, sorun ve ihtiyaçlarının farklılığı farklı örgütlenme modellerini doğurmuştur.::p.194" : [Collectives, Cooperatives, Rural_Livelihood],
"sağladığı istihdam ve yarattığı gelir ile köyden kente göçe frenleyici etki yapmaktadır::p.194" : [Migration],
"Kalkınma Ajansları ile tarım ve gıda sektörünün gelişmesini amaçlayan Gıda Tarım ve Hayvancılık Bakanlığı (GTHB)’nca verilen hibelerdi::p.194" : [TR_ruralGov],
"İzmir Kalkınma Ajansı (İZKA)::p.194" : [Food_Sovereignty],
"Ziraat Odaları  Tarımsal Üretici Birlikleri  Yetiştirici Birlikleri  Tarımsal Amaçlı Kooperatifler  Tarım Satış Kooperatifleri  Tarım Kredi Kooperatifleri::p.195" : [Collectives, Cooperatives, Food_Network, Rural_Development],
"veteriner ilaçları, gübre, tohum gibi girdi satış yerleri, her türlü ziraat ve ziraî sanayi tesisleri, fidanlık ve ağaçlıklar, damızlık ve örnek ahır ve ağılları, aşım durakları, ziraat işletmeleri, çiftçi danışmanlığı merkezleri::p.195" : [Food_Sovereignty, Variable],
"İzmir ili ve ilçelerinde toplam 21 adet Ziraat Odası bulunmaktadır::p.196" : [Policy_Access, Variable],
"pazarlama gücü::p.196" : [Variable],
" Tarımsal Amaçlı Kooperatifler , Tarım Satış Kooperatifleri , Tarım Kredi Kooperatifleri::p.197" : [Agro_econ, Cooperatives, Variable],
"Ege Bölgesi'ndeki 7 ilde, TARİŞ ortak ismi altında pamuk, üzüm, incir ve zeytinyağı olarak 4 ürün dalında çalışan her biri ayrı tüzel kişiliğe sahip toplam 106 adet tarım satış kooperatifi bulunmakta::p.199" : [Cooperatives, TR_agroEcon],
"sahip olduğu tesislerde::p.200" : [Agro_econ, Autonomy, Variable],
"Bölgede kütlü pamuk rekoltesinin yaklaşık %40’ını alarak::p.200" : [Food_Network, Variable],
"tohumluk, fide, fidan::p.201" : [Seed, Variable],
"kimyevi gübre, zirai mücadele ilacı::p.201" : [Food_Security, Variable],
"akaryakıt::p.201" : [Agro_international, Variable],
"Türkiye’de her bir NUTS 2 bölgesinde bir tane olacak şekilde 26 adet Kalkınma Ajansı faaliyet göstermektedir::p.202" : [TR_landUse, TR_ruralGov, Variable],
"insan kaynakları ve sosyal sermayenin geliştirilmesi::p.203" : [Food_Sovereignty, Rural_Development, Variable],
"kırsalda sosyo-ekonomik kalkınmayı hızlandıracak tarım dışı sektörlerde::p.203" : [Food_Sovereignty, Rural_Development],
"Gayrimenkul yatırımları::p.204" : [TR_Peasant, Variable],
"ZKA’nın bu üç program kapsamında toplam 119 adet projeyi desteklediği görülmektedir. Bunlardan yalnızca 15 tanesi tarımsal örgütlerce yürütülen projelerdir::p.204" : [TR_agroEcon, TR_agroGov],
"çeşitli mali araçları da kullanmaktadır. Bu araçlardan birisi de Köy Bazlı Yatırımcı Destekleme Programı olarak 16 ilde uygulanmaya başlanan ve ardından “Kırsal Kalkınma Yatırımlarının Desteklenmesi Programı (KKYDP)” adıyla ülke geneline::p.205" : [TR_agroGov, TR_ruralGov],
"26 adet Tarımsal Üretici Birliği olmasına karşılık yalnızca 1 adet proje bulunmaktadır::p.207" : [Policy_Access]
}

add_annots_from_dict(Can2014, Can2014_annot)

Can2014.add_to_excel("literature_annotation.xlsx")

# %%
SavgınZengin2016 = Annotation()

SavgınZengin2016.Title = "KATILIM ÖNCESİ AB KIRSAL KALKINMA FONLARI IPARD KIRSAL TURİZM DESTEKLERİNİN İNCELEMESİ"
SavgınZengin2016.Citation = "Zengin, B., & Savgın, E. C. (2016). KATILIM ÖNCESİ AB KIRSAL KALKINMA FONLARI IPARD KIRSAL TURİZM DESTEKLERİNİN İNCELEMESİ. Akademik Bakış Uluslararası Hakemli Sosyal Bilimler Dergisi(57), 84-100."
SavgınZengin2016.In_Text_Citation = "Savgın & Zengin, 2016"

SavgınZengin2016_annot = {
"Kırsal alanda yaşayan insanların %66,4’ü tarımla uğraşmaktadır::p.85" : [Rural_Livelihood, Variable],
"“kırsal alan“ ile “tarımsal alan” ve “ kırsal kalkınma” ile “tarımsal kalkınma” kavramlarını özdeş ya da aynı anlamda saymamak gerekir. Yalın bir anlatımla, “kentsel yerleşmeler dışında kalan yerler” diye nitelendirilebilecek “kırsal alan” kavramı, aslında tanımlayıcı öğeleri bulunan bir mekândır::p.86" : [Agroecology, Food_Network, Rural_Development],
"Kırsal Kalkınma Tedbirleri 1698/2005 sayılı Konsey Tüzüğüne (Kırsal Kalkınma için Avrupa Tarım Fonu-EAFRD) göre kırsal kalkınma destekleri başlıklar altında toplanmıştır (DPT 2006:126)::p.88" : [Agro_policy, TR_agroGov],
"insan kaynaklan, mesleki eğitim ve bilgi faaliyetleri, genç çiftçilikler, çiftçiler ve tarım işçileri için erken emeklilik düzenlemeleri, danışmanlık hizmetleri gibi konular bulunmaktadır::p.88" : [Rural_Development],
"Desteklerden 50 kişiden az çalışanı istihdam eden veya yıllık cirosu veya bilançosu 8 milyon TL’yi aşmayan mikro ve küçük ölçekli zanaatkarlar ve işletmeler faydalanabilmektedir::p.90" : [Policy_Access, Small_holder, Survivorship_bias, Debt, TR_agroGov],
"Kriter olarak nüfusu 20.000 altında olan yerleşim yerleri kurum tarafından kırsal alan olarak nitelendirilmektedir::p.91" : [TR_ruralGov, Variable],
"Görüşülen işletme sahiplerinden üçünün İPARD programı kapsamında aldıkları desteklerden daha önce haberdar olmadıkları ve tesadüfi olarak çevrelerindeki kişilerden duydukları sonrasında TKDK kurumuna giderek detaylı bilgi aldıklarını::p.96" : [Education],
"yerli ürün şartı sebebiyle kaliteli ürün alamadığını şu an alınan bazı makinalarda sorunlar yaşadığını belirtmiştir. Bazı yerli malı ürünlerin bazı aksamlarının dahi Çin de üretildiğini belirten katılımcı yerli malı olarak projede yer verdikleri malzemelerin bu sebeple uygun olmayan harcama::p.97" : [TR_ruralGov]
}

add_annots_from_dict(SavgınZengin2016, SavgınZengin2016_annot)

SavgınZengin2016.add_to_excel("literature_annotation.xlsx")

# %%
SoztutarYontar2018 = Annotation()

SoztutarYontar2018.Title = "Kırsal Alanda Girişimcilik, Üretim ve Kalkınma Boyutlarıyla Tarım ve Kırsal Kalkınmayı Destekleme Kurumu TKDK - Manisa İl Koordinatörlüğü Örneği"
SoztutarYontar2018.Citation = "Yontar, İ. G., & Söztutar, M. (2018). Kırsal Alanda Girişimcilik, Üretim ve Kalkınma Boyutlarıyla Tarım ve Kırsal Kalkınmayı Destekleme Kurumu TKDK - Manisa İl Koordinatörlüğü Örneği. Sayıştay Dergisi(111), 43-77."
SoztutarYontar2018.In_Text_Citation = "Söztutar & Yontar, 2018"

SoztutarYontar2018_annot = {
"IPA I kapsamında ortaya konulan bileşenlerden kırsal kalkınma bileşeninin (Instrument for Pre-Accession Assistance-Rural Development: IPARD) amacı, Avrupa Birliği’nin Ortak Tarım Politikası, Kırsal Kalkınma Politikası ve ilgili politikalar bağlamında aday ülkelerle eş güdümünün ve politika uyum süreçlerinin yönetilmesinin sağlanmasıdır::p.44" : [Agro_international, TR_agroGov, TR_ruralGov],
"IPARD Ajansı olarak TKDK, 18 Mayıs 2007 tarih ve 26526 sayılı Resmi Gazete’de yayımlanan 5648 sayılı Tarım ve Kırsal Kalkınmayı Destekleme Kurumu Kuruluş::p.45" : [TR_ruralGov],
"Kontrolsüz göçün durdurulması ve tarımsal istihdam::p.46" : [Migration, Variable],
"hijyen koşulları::p.47" : [Variable],
"Kırsal girişimcilik::p.48" : [Rural_Development, Variable],
"Ortak Tarım Politikası (OTP) ekseninde uyumlaştırmalarını sağlamak ve aday ülkenin kırsal kalkınma çabalarına destek::p.50" : [Agro_econ, TR_agroEcon],
"2007 yılına kadar PHARE, ISPA ve SAPARD gibi farklı isimlerle sunulan bu teknik ve finansal destekler, 2007 yılından itibaren tek çatı altında bir araya getirilerek IPA::p.50" : [Agro_policy],
"IPA’nın bu beş farklı bileşeninden sonuncusu olan kırsal kalkınma bileşeni, IPARD olarak::p.51" : [TR_agroGov],
"tüm mali denetimini yine destekten yararlanan ülkeye bırakarak Merkezi Olmayan Uygulama Sistemi’ni (Decentralised Implementation System-DIS)::p.51" : [TR_agroGov],
"2007-2013 dönemini kapsayan UKKS-I’in uygulama süresinin sonuna yaklaşılmasıyla birlikte, 2014-2020 yıllarını içine alacak UKKS-II::p.53" : [TR_agroGov, TR_ruralGov],
"2013 Programı’nda 42 il desteklenecek iller içinde yer almıştır. Fakat tecrübe ve kapasite artırımı sağlayabilmek için ilk uygulama döneminde bunlardan sadece 20 tanesine (Afyonkarahisar, Amasya, Balıkesir, Çorum, Diyarbakır, Erzurum, Hatay, Isparta, Kahramanmaraş, Kars, Konya, Malatya, Ordu, Samsun, Sivas, Şanlıurfa, Tokat, Trabzon, Van, Yozgat)....Programın ikinci uygulama dönemiyle diğer 22 il de (Ağrı, Aksaray, Ankara, Ardahan, Aydın, Burdur, Bursa, Çanakkale, Çankırı, Denizli, Elazığ, Erzincan, Giresun, Karaman, Kastamonu, Kütahya, Manisa, Mardin, Mersin, Muş, Nevşehir, Uşak) kapsama alınarak 42 ilde hibeler....Seçilen 42 il, IPARD I belgesinde yer alan Avrupa Komisyonu’nun işaret ettiği kriterler bağlamında belirlenmiştir. Buna göre; illerin GSYİH değerleri (Türkiye ortalamasının %75’inin altında olan), kırdan kente vermiş olduğu ya da iller arasındaki göç oranları ve illerin tarım sektörü ile kırsal alanlarının potansiyelleri açısından zayıf ve güçlü olduğu özellikler::p.54" : [Policy_Access, TR_ruralGov],
"Kurumdan faydalanıcılara verilecek katkının en fazla %75’i AB kaynaklarından kalanı ise ulusal bütçeden finanse edilecektir. Örneğin maliyeti 100 olan bir yatırımın %50’si yatırımcı tarafından kalanı ise TKDK tarafından verilecektir. Bunun ise en fazla %37,5’i AB katkısı olarak verilebilecektir (Göksu, 2010: 114). Tüm bunların yanında, 2014-2020 yıllarını kapsayan IPARD II ile birlikte TKDK desteğinin üst sınırlarında değişikliğe gidilmiştir. Artık yeni dönemde destekler %50 ile %70 arasında olacaktır. Böylelikle proje sahipleri en üst sınırdan destek aldıkları takdirde yatırımlarının sadece %30’luk kısmını kendileri finanse edeceklerdir::p.56" : [TR_Peasant, TR_agroEcon, TR_agroGov],
"2016/8541 sayılı Bakanlar Kurulu Kararı ile “Kırsal Kalkınma Destekleri Kapsamında Tarıma Dayalı Yatırımların Desteklenmesine İlişkin Karar” neticesinde daha önceden 42 il kapsamında yürütülen TKDK desteklerinin tüm illeri kapsayacak şekilde genişletilmesi için bir adım::p.56" : [TR_agroGov],
"Manisa İl Koordinatörlüğü, 2012 yılında kurulmuş ve 2013 yılından itibaren aktif olarak faaliyetlerini sürdürmeye başlamıştır. Bu doğrultuda Manisa ili, IPARD I kapsamında duyurulan 15 proje çağrı döneminin ilk 8’inden yararlanamamıştır.::p.58" : [Policy_Access, TR_agroGov],
"hammadde ihtiyaçlarını yerel kaynaklardan ne ölçüde elde edip edemedikleri::p.61" : [Variable],
"Bunun nedeni olarak üretim kapasitesi genişleyen işletmelerin yatırım maliyetlerindeki artış temel bir gerekçe olarak ileri sürülmüştür. Bu durumda ilerleyen süreçte tarımsal üretim kapasitelerini büyüten işletmelerin konjonktürel bir değişim olmadığı takdirde::p.63" : [Agro_econ, Methodology],
"İşletmeler Çevresel Temizliğe::p.65" : [Rural_Policy, Variable],
"TKDK Projelerinin Orta ve Büyük Ölçekli Tarımsal İşletmelerin Yanı Sıra Küçük Ölçekte Faaliyet Gösteren Çiftçilere de Yaygınlaştırılması::p.73" : [Policy_Access, Small_holder, TR_agroGov]
}

add_annots_from_dict(SoztutarYontar2018, SoztutarYontar2018_annot)

SoztutarYontar2018.add_to_excel("literature_annotation.xlsx")

# %%
CevikEminagaoglu2007 = Annotation()

CevikEminagaoglu2007.Title = "KIRSAL YERLEŞMELERE İLİŞKİN TASARIM POLİTİKALARI VE ARAÇLAR"
CevikEminagaoglu2007.Citation = "Eminağaoğlu, Z., & Çevik, S. (2007). KIRSAL YERLEŞMELERE İLİŞKİN TASARIM POLİTİKALARI VE ARAÇLAR. Gazi Üniversitesi Mühendislik Mimarlık Fakültesi Dergisi, 22(1)."
CevikEminagaoglu2007.In_Text_Citation = "Çevik & Ağaoğlu, 2007"

CevikEminagaoglu2007_annot = {
"1924 tarihli 422 sayılı Köy Kanunu’nda, köyün ortasına meydan yapılması, Bir köy odası, misafirhane yapılması, köy korusunun korunması, evlerin badanalanması, sokakların yapımı gibi köye yönelik bazı düzenleme ilkeleri verilmektedir. Ancak bunlar çok genel ve yetersiz kalmaktadır::p.158" : [History, TR_ruralGov],
"İklim, arazi yapısı, jeoloji, su kaynakları, bitki örtüsü::p.159" : [Variable],
"1985 sonrasında yürürlüğe giren İmar Yasası’nın 8. Maddesinde, belediye ve mücavir alan dışında kalan yerlerde yapılacak planların valilik veya ilgilisince yapılıp yaptırıldığı, valilikçe uygun görüldüğü takdirde onaylanarak yürürlüğe girdiği ifade edilmektedir. Aynı yasada yer alan “Belediye ve Mücavir Alan Sınırları İçinde ve Dışında Planı Bulunmayan Alanlarda Uygulanacak İmar Yönetmeliği” yerleşik alan olarak belirtilen mahalle, köy, mezra gibi kırsal yerleşmeleri de kapsamakta::p.161" : [History, TR_ruralGov],
"Son dönemlerde, 5286 Sayılı Kanun ile Köy Hizmetleri Müdürlüğü kaldırılmış, söz konusu hizmetler il özel idarelerine, iskan konuları ise Bayındırlık ve İskan bakanlığı’na devredilmiştir::p.161" : [History, TR_ruralGov]
}

add_annots_from_dict(CevikEminagaoglu2007, CevikEminagaoglu2007_annot)

CevikEminagaoglu2007.add_to_excel("literature_annotation.xlsx")

# %%
Dilmac2014 = Annotation()

Dilmac2014.Title = "Kırsal Alanda Tarımsal Finansman Desteği Olarak Doğrudan Gelir Desteği Üzerine Bir Alan Araştırması: Narman İlçesi Örneği"
Dilmac2014.Citation = "Keleş, Ş., Dilmaç, M., & Tural Dikmen, A. (2014). Kırsal Alanda Tarımsal Finansman Desteği Olarak Doğrudan Gelir Desteği Üzerine Bir Alan Araştırması: Narman İlçesi Örneği. Alinteri Journal of Agriculture Science, 27(2), 10-17."
Dilmac2014.In_Text_Citation = "Dilmaç et al., 2014"

Dilmac2014_annot = {
"üretimden bağımsız olanlar (decoupled payments) ve üretimle ilişkili olan ödemelerdir::p.12" : [Agro_policy, Small_holder],
"Gıda Tarım ve Hayvancılık Bakanlığı İlçe Müdürlüğü kayıtlarında yer alan 238 DGD faydalanıcısı çalışmanın evrenini oluşturmaktadır.::p.12" : [Policy_Access, Survivorship_bias],
"Hane Başkanlarının Yaş ve Cinsiyeti::p.13" : [Gender, Rural_Family, Variable],
"Eğitim Durumu::p.13" : [Variable],
"Aile Büyüklüğü::p.14" : [Rural_Family, Variable],
"gelir::p.14" : [Variable],
"Sosyal güvenlik sahibi çiftçilerle sosyal güvencesi olmayanlar hemen hemen eşittir.::p.14" : [Agro_econ, Variable],
"Çiftçilikle uğraşanların tamamının kendi toprağı vardır.::p.14" : [TR_agroEcon, TR_Peasant, Variable],
"çiftçilerin %9,6’sında traktör bulunmakta..Genelde geleneksel tarımsal üretim yapıldığından ve dağlık arazi yapısı modern tarımsal araçların kullanımını azaltmaktadır::p.15" : [Variable],
"çiftçilerin çok azı %16,8’i kooperatif üyesidir::p.15" : [Cooperatives, Variable],
"Narman kırsalında tarımla uğraşan çiftçilerin genelde orta yaştaki kişilerden oluştuğu, gençlerin çiftçiliği tercih etmedikleri tespit edilmiştir.::p.16" : [Migration, Rural_Livelihood, Variable],
"çiftçilerin hemen hemen tamamı % 99’ u yıllık 8.000 TL’nin altında kazanç elde etmektedir. Bu tarımsal kazanç yetmediğinden belirli zamanlarda kentlerde inşaat işleri ve diğer sahalarda işçilik yapmaktadırlar.::p.16" : [Rural_Livelihood]
}

add_annots_from_dict(Dilmac2014, Dilmac2014_annot)

Dilmac2014.add_to_excel("literature_annotation.xlsx")

# %%
Furat2013 = Annotation()

Furat2013.Title = "Küresel Politika Değişimleri ve Türkiye'de Kırsal Kalkınma"
Furat2013.Citation = "Furat, M. (2013). Küresel Politika Değişimleri ve Türkiye'de Kırsal Kalkınma. Gaziantep University Journal of Social Sciences, 12(3)."
Furat2013.In_Text_Citation = "Furat, 2013"

Furat2013_annot = {
"Türkiye’nin azgelişmiş bir ülke olmasının getirdiği sosyo-ekonomik ve kültürel özelliklere bağlı olarak ortaya çıktığı da söylenebilir. Bu özelliklerden bazıları, tarımın yaygın olarak küçük üreticiliğe dayalı olması, küçük ve parçalı arazi yapısı, tarımsal üreticilerin, tarımsal teknik ve becerilerindeki yetersizlikler::p.590" : [Food_Sovereignty, Policy_Access, Variable],
"Modern kırsal kalkınma paradigması ulus devletlerin, tarımsal makineleşme ve biyo-kimyasal girdiler kullanarak belli ürünlerde uzmanlaşmış tarımsal üretim yapmaları üzerine kuruluydu:.p.591" : [Agro_econ, History],
"Fakat 1980’lerden sonra, azgelişmiş ülkeler kalkınmak yerine, ödemeler dengesi ve bütçe açıkları, kırsal üretimin sürdürülebilmesinin zorlaşması, çevre kirliliği problemleri ve artan dış sermaye bağımlılığıyla karşılaştılar. Bu yüzden (Uluslararası Para Fonu) IMF’nin kamusal kurumların özelleştirmesini ve sosyal programların azaltılmasını zorunlu kılan yapısal uyum programlarını::p.591" : [History, TR_agroEcon],
"1990’larda ise, kırsal yoksulluk arttıkça kırsal alanda geçimin sağlanması için daha dengeli bir kırsal kalkınma yaklaşımı benimseme ihtiyacı doğdu. Böylece, kırsal kalkınma; zaman ve mekâna bağlılık, katılımcılık, yerellik, kültürel çoğulculuk, çevresel sürdürülebilirlik, doğal kaynakları akılcı kullanım, insani gelişme, örgütlenme, katılımcı gözlem ve değerlendirme, kapasite geliştirme, sosyal sermaye::p.591" : [Agroecology, Food_Sovereignty, History],
"1990 - 2010: Mikro kredi, katılımcı kırsal değerlendirme (Participatory Rural Appraisal), aktör yönelimli kırsal kalkınma, paydaş analizi, Toplumsal cinsiyet ve Kalkınma (Gender and Development) çevre ve sürdürülebilirlik::p.592" : [Debt, Gender, Rural_Development, Small_holder],
"ölçek ekonomisinden vazgeçme::p.593" : [Food_Sovereignty, Food_Security],
"yeni gıda rejiminin özelliklerini::p.593" : [Agro_policy, Food_Security, History],
"MAFF (1999)’ın da belirttiği gibi; AB kırsal kalkınma kuralları üç temel::p.595" : [History, Rural_Development, Rural_Policy],
"AB’nin “yeni kalkınma paradigması”nda, kırsal haneler, çok- görevli (multi-tasking) ve çok-işlevsel olarak, yerel çevrelerine üretebilecekleri, hizmet olarak sunabilecekleri veya pazarlayabilecekleri ne varsa; onunla parasal ekonomiye katılmaları öngörülüyor::p.596" : [Agro_international, Rural_Development, Rural_Family],
"Türkiye’de tarım ve kırsal kalkınma politikalarının tarihsel değişimi::p.597" : [History, TR_agroGov, TR_ruralGov],
"1980’lerden sonra ise devletin, genel olarak tarımsal ürünleri destekleyen ürün alma, girdileri sağlama (tohum, gübre ve ilaç)::p.599" : [Food_Sovereignty, History, TR_agroEcon],
"1. TKKB’nin (Türkiye Kalkınma Kooperatifleri Birliği) 2005’te, 5330 no’lu kanun ve 533 nolu kanun hükmünde kararname ile yeniden yapılandırılması (TKKB, 2012) 12. TMO’nun (Toprak mahsülleri Ofisi), faaliyetleri azaltılarak, yeniden yapılandırılmıştır.::p.600" : [Small_holder, TR_agroGov],
"pazara erişim, ihracat rekabeti ve iç tarımsal destekler::p.600" : [Food_Network, Food_Security, Food_Sovereignty],
"Türkiye, gümrüklerini ortalama %24 oranla, her yıl eşit oranda olmak üzere ve bir ürün için en az %10 olmak üzere 2004 yıllına kadar indirmey::p.600" : [Agro_international, Food_Sovereignty, TR_agroEcon, TR_agroGov],
"Şahinöz’e (1996:300) göre, GATT Uruguay turu kararları, azgelişmiş ve gelişmiş ülkeler arasındaki kişi başına düşen üretim, üretim giderleri ve ticaret altyapısı açısından farklar olduğu için adil olmayan ticareti zorunlu kılan düzenlemeler getirmektedir.::p.601" : [Agro_econ, Agro_international, Small_holder],
"yerine sektörel ve küçük ölçekli tarım-gıda bütünleşmesi öngören tarımsal işletmelerin arttırılmasına yönelik destekler::p.602" : [Agro_international, TR_agroEcon, TR_agroGov],
"Gıda, Tarım ve Hayvancılık Bakanlığı, IPARD programını hazırlayan ve uygulanmasından sorumlu kurumdur. Bu program (T.C. TKDK, 2013: 14), Türkiye’nin uyguladığı genel makro ekonomik politikalara ve önceki paragraflarda belirtilen IMF ve DTÖ’ne taahhütlerini bozmayacak şekilde hazırlanmıştır.::p.602" : [Agro_international, TR_agroGov],
"IPARD programı (T.C. TKDK, 2013:116-124) tarafından, 2006-2013 döneminde tarımsal destek programları, kırsal kalkınma destekleri ve kırsal altyapı destekleri olmak üzere tarımsal destekler oluşturulmuştur ve uygulanmaktadır:   1. Tarımsal Destek Programları: Doğrudan Gelir Destekleri, Fark Ödemeleri, Telafi Edici Ödemeler, Hayvancılık Destekleri, Tarım Sigortası Destekleri, Çevre Destekleme Projesi (ÇATAK) (ÇATAK, DB’sı desteklidir). 2. Kırsal Kalkınma Destekleri: Kırsal Kalkınma Yatırımlarının Desteklenmesi Programı (KKYDP): Bireysel veya bir arada tarım üreticilerinin yapacakları öz sermayeye dayalı tarım ürünlerinin depolanması, işlenmesi ve ambalajlanmasına yönelik ekonomik faaliyetlerin ve altyapıya yönelik yatırım projelerinin hibeyle desteklenmesini içerir. Bu program 2006’dan beri 81 ilde uygulanmaktadır. 3. Kırsal Altyapı Destekleri: 3.1. Köy Altyapısı Destekleme Projesi (KÖYDES): Bu proje köylerde sağlıklı ve yeterli içme suyu sağlamaya ve köy yollarının altyapısını güçlendirme amaçlıdır. 3.2. Belediyelerin Altyapısının Desteklenmesi Projesi (BELDES): Nüfusu 10.00’den az olan beldelerin altyapı hizmetlerinin geliştirilmesi içindir.:.p.603" : [History, TR_agroGov, TR_ruralGov],
"sertifikalı tohum uygulamasının arttırılmasına yönelik desteklerdir::p.603" : [Agro_international, Food_Sovereignty, Small_holder, Variable],
"erozyon kontrolü::p.604" : [Variable],
"su kaynaklarının korunması::p.604" : [Variable],
"biyolojik çeşitlilik::p.604" : [Agroecology, Variable],
"biyolojik çeşitlilik gibi alt başlıkları içerir.::p.604" : [Agro_international, Agro_policy],
"IPARD programı (T.C. TKDK, 2013:36-37) organik tarımı, suni tarımsal kimyasalları, suni hormonları, suni gübreleri kullanmayı reddeden; çevreye dost, organik ve yeşil gübreleme yapan, toprağı koruyan bir tarımsal üretim sistemi kurmayı hedefleyen “bir alternatif üretim tekniği” olarak tanımlamıştır.::p.604" : [Agroecology, Food_Security, Food_Sovereignty],
"genetiği değiştirilmiş tohumların kullanımının risklerini anlamaya yönelik politikalar oluşturulması::p.604" : [Agro_tech, Health, Seed],
"sağlık, eğitim ve altyapı::p.605" : [Variable],
"Özellikle, et-süt ürünlerine verilen öncelik, tarım sektörü GATT antlaşmasındaki vergi oranları indirimlerinin en düşüğünün et ve süt ürünlerinde olmasında da görülebilir.::p.605" : [Agro_international, Agroecology, TR_agroEcon],
"pratik olarak uygulanması yerel yönetimler ve belediyeler, STK’lar, taban örgütlenmeler, hedeflenen gruplar gibi kalkınmanın aktörleri arasında karmaşık ve yoğun ilişkileri içermektedir. Bu prensiplerin hayata geçirilmesi ve bununla ilgili kanunların uygulanması::p.607" : [Agro_international, Agro_policy, Food_Network]
}

add_annots_from_dict(Furat2013, Furat2013_annot)

Furat2013.add_to_excel("literature_annotation.xlsx")

# %%
Kandemir2011 = Annotation()

Kandemir2011.Title = "Tarımsal Destekleme Politikalarının Kırsal Kalkınmaya Etkisi"
Kandemir2011.Citation = "Kandemir, O. (2011). Tarımsal Destekleme Politikalarının Kırsal Kalkınmaya Etkisi. Ekonomi Bilimleri Dergisi, 3(1), 103-113."
Kandemir2011.In_Text_Citation = "Kandemir, 2011"

Kandemir2011_annot = {
"ORTAK TARIM POLİTİKASININ ORTAYA ÇIKIŞI 1962 yılında yürürlüğe giren OTP‘nın::p.2" : [Agro_international, History],
"OTP, AB’de üretilen tarımsal ürünlerin %90’ının yüksek fiyatlarla satın alınıp, AB’deki tüketicilere düşük fiyatlarla satılması anlayışına dayanmaktaydı.::p.2" : [Agro_econ, History],
"4 Nisan 1962 tarihinde Avrupa Tarımsal Garanti ve Yön Verme Fonu (FEOGA)’nu kurmuşlardır (Karluk, 1998:186–200).::p.2" : [History],
"topluluk üreticileri her geçen yıl daha çok üreterek üretim stoklarını artırmıştır. AB stokları eritilebilmek için dış pazarlarda ABD ile sübvansiyonlar savaşına girerken, tüm bu gelişmeler yüksek bütçe yükünü ve uluslararası alanda sürtüşmeleri ortaya çıkarmıştır (Günaydın, 2005). OTP’nin AB içinde neden olduğu mali sorunların ve dünya piyasalarında yol açtığı ticari karmaşanın ortadan kaldırılması için Mayıs 1992 tarihinde düzenlenen Lizbon Zirvesi'nde tarımsal destekleme fiyatlarının dünya piyasa fiyatları düzeyine çekilmesi ve üretim fazlasının ortadan kaldırılması:.p.3" : [History],
"1996 yılında uygulamaya giren Gümrük Birliği çerçevesinde, Türk tarım politikalarının OTP’ye uyumu zorunluluğu ortaya çıkmıştır::p.3" : [History, TR_agroEcon],
"fiyat denetimleri::p.3" : [Variable],
"tarımsal kamu yönetimi::p.3" : [Variable],
"DGD için bütçeden ayrılana pay 2008 yılında 1.140 milyon TL.’ye kadar düşmüş, 2009 yılında ise bütçeden tamamen kaldırılmıştır::p.3" : [Small_holder, TR_Peasant],
"25 Nisan 2006 tarihli Resmi Gazete’de yayımlanarak yürürlüğe giren 5488 sayılı Tarım Kanunu’nun 21. maddesine göre Tarımsal destekleme programlarına bütçeden ayrılacak kaynak, gayrisafi millî hâsılanın yüzde birinden az olamaz::p.4" : [TR_agroGov, TR_ruralGov],
"Buna karşın bütçeden faize aktarılan kaynak hızla artmış::p.5" : [Agro_econ, Variable],
"fert başına desteğin 1800 euro olmasına karşın, Türkiye nüfusunun %27’sini oluşturan tarım nüfusu için verilen fert başına desteğin ise sadece 246 dolar::p.5" : [Agro_international, Interdisciplinary, Variable],
"tarımsal desteklerin bütçe içindeki payı::p.5" : [Variable],
"DGD bazı bölgelerdeki çiftçiler için önemli bir gelir kaynağı olurken, bazı bölgelerde üreticinin desteklerden yararlanmak için katlanmak zorunda olduğu başvuru masraflarını bile karşılamamıştır.::p.5" : [Policy_Access, Variable],
"Avrupa Birliği’nin üretim fazlası olan ürünlerde üretim artışını yavaşlatmak için uyguladığı DGD politikalarının Türkiye’de uygulanması::p.6" : [Agro_international, Food_Sovereignty],
"tarım kesiminde yoksulluk oranı::p.6" : [TR_Peasant, Variable],
"hayvan ithalatı, kırmızı et fiyatlarındaki yükselme::p.7" : [Food_Sovereignty, Variable],
"Romanya’da 5 dolar, Bulgaristan’da 3,5 dolar, Avusturya’da 2,5 dolar, Brezilya’da 2 dolar civarında olan kırmızı et fiyatı, canlı hayvan ithalatına rağmen Türkiye’de ortalama olarak 16 dolar civarında seyretmeye devam etmektedir::p.7" : [Agro_econ, Agro_international, Variable],
"Tarımsal ürünler içinde gıda maddelerinde ticaret fazlası verilirken, tarımsal hammaddelerde ithalat ihracattan fazla gerçekleşmiştir::p.8" : [Food_Sovereignty, TR_agroEcon, Variable],
"DGD uygulamaları ile desteklerin üretim yerine arazi büyüklüğüne göre verilmesi::p.8" : [Land_Policy, TR_agroGov]
}

add_annots_from_dict(Kandemir2011, Kandemir2011_annot)

Kandemir2011.add_to_excel("literature_annotation.xlsx")

# %%
GunayTuncer2017 = Annotation()

GunayTuncer2017.Title = "TÜRKİYE’DE TARIMA YÖNELİK DESTEKLERİN AVRUPA BİRLİĞİ PERSPEKTİFİNDEN DEĞERLENDİRİLMESİ"
GunayTuncer2017.Citation = "Tunçer, M., & Günay, H. F. (2017). TÜRKİYE’DE TARIMA YÖNELİK DESTEKLERİN AVRUPA BİRLİĞİ PERSPEKTİFİNDEN DEĞERLENDİRİLMESİ. Avrasya Sosyal Ve Ekonomi Araştırmaları Dergisi, 4(8), 15-30."
GunayTuncer2017.In_Text_Citation = "Günay & Tunçer, 2017"

GunayTuncer2017_annot = {
"Roma Antlaşması’nın imzalanmasından bu yana, AB’de de ağırlıklı ve temel bir politika alanı olmuştur::p.16" : [Agro_international, Agro_policy],
"Doğal şartlara bağlılık, tarımın en önemli özelliklerinden biridir.::p.17" : [Agroecology],
"Tarım ürünlerinin arzı da, talebi de az elastiktir.::p.17" : [Agro_econ],
"Tarım sektöründe, iş ve aile yaşantısı iç içedir::p.17" : [Rural_Family, Rural_Livelihood],
"Örneğin, bitkisel üretimde önce toprak hazırlığı, sonra ekim-dikim işleri yapılır, bunları ise bakım ve hasat-harman işleri izler. İşlerin belirli zamanlarda, sırayla yapılması zorunluluğu, çiftçinin bir bakıma her çeşit işten anlamasını ve her işi yapmasını gerekli kılmaktadır::p.17" : [Agro_tech, Agroecology, Food_Sovereignty],
"toprağın kalite, miktar ve niteliklerini::p.18" : [Variable],
"Sanayi sektörü ve tarım sektörü arasında yakın ilişki::p.18" : [Variable],
"tarımsal nüfus yoğunluğu::p.19" : [Variable],
"Tahıl üretim ve verimliliği::p.20" : [Variable],
"tahıl ekilen alan::p.20" : [Variable],
"işletmelerin bölünmüşlüğü::p.23" : [TR_landUse, Variable],
"sektördeki kayıtdışılık::p.23" : [Variable],
"sermaye birikimi::p.23" : [Food_Sovereignty, Small_holder, Variable],
"iklim şartları::p.23" : [Variable],
"tarımsal gelirde dalgalanmalar::p.23" : [Variable, Agro_econ],
"bitkisel ve hayvansal üretime ilişkin verim düzeyi::p.23" : [Food_Security, Food_Sovereignty, Variable],
"gübre ve tarımsal ilaçların yanlış kullanımı::p.23" : [Education, Variable],
"Doğrudan Ödemeler: Doğrudan ödemeler çiftçilerin kazançlarına istikrar kazandırmak amacıyla::p.24" : [Agro_econ, Agro_policy],
"Piyasa Önlemleri::p.24" : [Agro_policy, Variable],
"OTP harcamalarından en fazla yararlanan ülkelerin Fransa, Almanya ve İspanya olduğu görülürken, en az yararlananlar ise Malta, Lüksemburg ve Kıbrıs’tır::p.25" : [Agro_international, Agro_policy, Big_agro],
"Finlandiya, Lüksemburg, Avusturya, İsveç, İngiltere gibi ülkeler OTP bütçesine katkılarının fazla, bütçeden yararlandıkları miktarın ise az oluşu bu ülkelerde mali kayıp yaratmaktadır.::p.25" : [Agro_international, Agro_policy, Variable],
"1999 yılından sonra ise, IMF ile yapılan stand-by anlaşmasıyla birlikte tarımsal destekleme konusunda da önemli adımlar atılmıştır. Özelleştirilen birçok kurumun yanı sıra, mevcut destekleme uygulamaları aşamalı olarak sona erdirilerek doğrudan gelir desteği sistemine geçiş öngörülmüştür. Türkiye’de uygulanmış veya uygulanmakta olan, tazminat ödemeleri, destekleme primi ödemeleri, alternatif ürüne geçiş ödemeleri ve doğal afet ödemeleri gibi destekleme araçları OTP kapsamında yer almamaktadır::p.25" : [History, TR_agroEcon],
"Alan bazlı gelir desteği::p.25" : [Rural_Policy, TR_agroGov],
"Tarım sigortası ödemeleri::p.26" : [Variable],
"Çevre amaçlı tarımsal arazilerin korunması programı destekleri; erozyon ve olumsuz çevresel etkilere maruz kalan tarım arazilerinde, işlemeli tarım yapan üreticilerin, arazilerini doğal bitki örtüleri, çayır, mera, organik tarım ve ağaçlandırma için kullanmalarını teşvik::p.26" : [TR_agroGov, Agroecology],
"arz açığı olan ürünlere::p.27" : [Food_Sovereignty, Variable],
"AB bütçesinde %40’a yakın paya sahip olan OTP harcamaları::p.28" : [Food_Network, Food_Security]
}

add_annots_from_dict(GunayTuncer2017, GunayTuncer2017_annot)

GunayTuncer2017.add_to_excel("literature_annotation.xlsx")

# %%
TolunayYilmaz2009 = Annotation()

TolunayYilmaz2009.Title = "AVRUPA BİRLİĞİ KIRSAL KALKINMA POLİTİKALARINDA YENİ YÖNELİMLER VE TÜRKİYE"
TolunayYilmaz2009.Citation = "Yılmaz, H., & Tolunay, A. (2009). AVRUPA BİRLİĞİ KIRSAL KALKINMA POLİTİKALARINDA YENİ YÖNELİMLER VE TÜRKİYE. Turkish Journal of Forestry, 8(1), 107-122. https://doi.org/10.18182/tjf.65998"
TolunayYilmaz2009.In_Text_Citation = "Tolunay & Yılmaz, 2009"

TolunayYilmaz2009_annot = {
"AB Ortak Tarım Politikası ‘nın geçirdiği köklü değişim süreci çerçevesinde, 1257/1999 sayılı kırsal kalkınmanın desteklenmesi hakkında “Avrupa Tarımsal Yönlendirme ve Garanti Fonu-EAGGF” 1 Ocak 2007 den itibaren “az gelişmiş alanlara” yönelik birkaç tedbirin uygulaması haricinde yürürlükten kalkacaktır. Bu Fon 1290/2005 sayılı Tüzük kapsamında; “Avrupa Tarımsal Garanti Fonu (European Agricultural Guarantee Fund-EAGF)” ve “Kırsal Kalkınma Đçin Avrupa Tarımsal Fonu (European Agricultural Fund for Rural DevelopmentEAFRD)” olarak farklı uygulama mekanizmalarına sahip olmak üzere birbirinden tamamıyla ayrılmıştır.::p.110" : [History],
"kırsal gelişme politikası son biçimini 2003 reformlarıyla almıştır. Ancak bu reformların ilk adımları, 1996 'da, “Cork Adasında (Đrlanda)” yapılan “kırsal kalkınma” konferansıyla atılmıştır::p.111" : [History],
"fon kullanım miktarını ülkenin kaynak kullanma kapasitesi belirleyecektir::p.112" : [Agro_econ, Agro_international],
"işleme/ pazarlama kapasitesi::p.114" : [Food_Network, Food_Sovereignty, Variable],
"Dağlık alanlar::p.114" : [Variable],
"Tarım-hayvancılık ile çevresel denge::p.114" : [Agroecology],
"Orman ve çevre dengesi::p.114" : [Agroecology],
"üretici birliklerini::p.116" : [Variable]
}

add_annots_from_dict(TolunayYilmaz2009, TolunayYilmaz2009_annot)

TolunayYilmaz2009.add_to_excel("literature_annotation.xlsx")

# %%
Karsak2024 = Annotation()

Karsak2024.Title = "Between ‘moral economy’and ‘social banditry’: harvest theft in a peasant community"
Karsak2024.Citation = "Karsak, B. (2024). Between ‘moral economy’and ‘social banditry’: harvest theft in a peasant community. The Journal of Peasant Studies, 51(2), 512-532."
Karsak2024.In_Text_Citation = "Karsak, 2024"

Karsak2024_annot = {
"high-value crop booms on peasant communities::p.512" : [Food_Sovereignty, Rural_Livelihood, TR_agroEcon, Variable],
"valuable and relatively easy to harvest::p.512" : [Variable],
"alternatives to their traditional export commodities::p.513" : [Agro_econ, Variable],
"classical export commodities (coffee, tea, sugar, tobacco, cocoa and so on)::p.513" : [Methodology],
"HVF crops are socially destructive for community-level relations. This is shown to be the case even when the HVF in question is, in itself, non-impoverishing::p.514" : [Food_Security, Food_Sovereignty],
"left behind and left out::p.515" : [Agro_econ, Agro_international, Small_holder, Survivorship_bias],
"1980; the agricultural sector, especially smallholders, enjoyed continued populist policies under consecutive liberal center-right::p.515" : [History],
"In the 2000s, two consecutive international agreements/negotiations were effective in dismantling the long-lasting state support for the Turkish peasantry. The first was the Agricultural Reform Implementation Project (ARIP), introduced after the structural adjustment program signed with the World Bank and the IMF. Between 2001 and 2008, ARIP::p.515" : [History],
"labor-intensive greenhouse vegetables::p.516" : [Variable],
"land consolidation::p.516" : [Rural_Policy, TR_ruralGov, TR_landUse],
"commodity booms in the global South::p.517" : [Agro_econ, Food_Network, TR_agroEcon],
"initial inequality and vulnerability of poorer households’ as well as incentives and opportunities for ‘outside investors to acquire increasingly valuable land from smallholders’::p.517" : [Big_agro, Small_holder],
"gleaning (gathering of leftover grains following harvest)::p.519" : [Food_Sovereignty, Rural_Livelihood],
"long harvest period::p.525" : [Agro_econ, Variable],
"minimal labor::p.525" : [Agro_econ, Variable],
"It was treated in the same category as ‘gleaning’, but not theft. In other words, theft in traditional cash crops was handled within a functioning moral economy as a mild form of income redistribution::p.525" : [Agro_econ, Food_Security, Food_Sovereignty, Rural_Livelihood],
"Turkey’s new agricultural policy favored large-scale, export-oriented, ‘entrepreneurial’ farming. This, coupled with continuing land consolidation policies, effectively squeezed smallholders out of the agricultural sector::p.528" : [TR_Peasant, TR_agroEcon, TR_agroGov]
}

add_annots_from_dict(Karsak2024, Karsak2024_annot)

Karsak2024.add_to_excel("literature_annotation.xlsx")

# %%
YakarYazici2009 = Annotation()

YakarYazici2009.Title = "Emirdağ İlçesinde Göçlerin Tarım Alanlarına Etkileri"
YakarYazici2009.Citation = "Yakar, M., & Yazıcı, H. (2009). Emirdağ İlçesinde Göçlerin Tarım Alanlarına Etkileri. Coğrafi Bilimler Dergisi, 7(2), 163-176. https://doi.org/10.1501/Cogbil_0000000100"
YakarYazici2009.In_Text_Citation = "Yakar & Yazıcı, 2009"

YakarYazici2009_annot = {
"Kırsal alanda arazinin mevcut kullanım deseni ve potansiyeli, nüfus taşıma kapasitesini büyük ölçüde belirlemektedir....Arazi kullanım deseninin mekâna bağlı değişiminin nüfus hareketleri üzerindeki etkisi, sahanın doğal ortam özellikleri yanında tarımsal üretimi belirleyen politik, ekonomik ve toplumsal faktörlerle de ilişkilidir::p.164" : [Land_Use, TR_landUse, TR_ruralGov],
"Ayrıca geride kalan hane halkının yaşlılardan oluşması üretimin devamlılığını engellediği gibi::p.164" : [Rural_Family],
"Sonuçta tarım arazilerinin mülkiyet ve kullanım bakımından bir değişim/dönüşüm içinde olduğu saptanmaktadır::p.164" : [Food_Security, Food_Sovereignty, Land_Use],
"Yani göç veren merkez ile göç alan merkez arasındaki gelişmişlik farklılığı, göç sonrasında azalarak eşitlenme yönünde bir gelişmeye değil, tam tersine daha da derinleşmesine ve ayrışmasına neden olmaktadır::p.165" : [Migration, Rural_Development],
"Göçmenler tarafından gönderilen paranın kırsaldaki kullanımı konusunda şimdiye kadar yapılan araştırmalar, hanenin üretim kaynaklarını geliştirmeden ziyade tüketimini artırmaya yönelik olduğunu göstermektedir::p.166" : [Debt, Migration, Rural_Development],
"Köy Envanter Etütlerinden::p.166" : [TR_ruralGov, Variable],
"Emirdağ İlçesi’nde arazi kullanımının zamansal değişimi ve etkileri::p.169" : [History, TR_agroGov, TR_ruralGov],
"Çünkü çiftçilik yapmadığı ve göç ettiği halde köyde sahip oldukları arazilerin dönümü başına ücret alanlar olmuştur::p.170" : [History, TR_agroGov],
"Emirdağ ilçesinde 1981 yılında tarıma elverişli olduğu halde kullanılmayan arazilere rastlanmazken 2001 yılında 48.564 dekar olmuştur.::p.171" : [TR_landUse, Variable],
"Kalker ve mermerlerden oluşan plato sahasında çok tipik olarak görülen ekilmeyen tarım alanlarında erozyonun şiddetine bağlı olarak yer yer ana kaya yüzeylenmiştir. Buna karşın sulu tarım alanlarında ve geniş vadi tabanlarında::p.172" : [Land_Use, Risks_Global, Variable],
"Çiftçi ailesi başına düşen tarım alanı::p.173" : [Variable],
"Arazi büyüklüklerine göre detaylandırılmış 1981 kayıtlarına göre 100 dekardan az toprağa sahip haneler 200 dekardan daha fazla toprağa sahip hanelere oranla daha fazla göç etmiştir. Nitekim bu sonuç, grafiklerde de görüldüğü gibi, 200 dekardan daha fazla toprağa sahip hane sayısındaki azalmanın en az olmasıyla da doğrulanmaktadır::p.174" : [Agro_econ, Small_holder, Survivorship_bias],
"Türkiye’de kırsaldan olan göçlerin kentlerde ortaya çıkardığı sonuçları ve sorunları bilinmesine karşın, aynı göç sürecinin kırsal alanları nasıl etkilediği üzerinde pek durulmamıştır::p.174" : [Migration, Urbanization]
}

add_annots_from_dict(YakarYazici2009, YakarYazici2009_annot)

YakarYazici2009.add_to_excel("literature_annotation.xlsx")

# %%
Demirdogen2022 = Annotation()

Demirdogen2022.Title = "Heterogeneous impact of agricultural support policies: evidence from Turkey"
Demirdogen2022.Citation = "Demirdöğen, A., Olhan, E.,  & Hasdemir, M., (2022). Heterogeneous impact of agricultural support policies: evidence from Turkey.  ENVIRONMENT DEVELOPMENT AND SUSTAINABILITY , vol.24, no.10, 12203-12225."
Demirdogen2022.In_Text_Citation = "Demirdöğen et al., 2022"

Demirdogen2022_annot = {
"Although transfers to farmers significantly declined after the mid1980s, trends in agricultural subsidies nearly reversed after 2008. Support payments began to increase in several countries that significantly affected agriculture markets and policies::p.12204" : [Agro_econ, Agro_international, Agro_policy],
"These distorting transfers were also relatively high for other big agricultural producer countries, around 70% in China and Russia and 80% in Turkey::p.12204" : [Agro_international, TR_agroEcon],
"support policies::p.12204" : [Variable],
"the support variables might be endogenous for at least three reasons. Firstly, the support payments mostly depend on the variable on which their effect is estimated...The second problem of the support variable is selection bias. The datasets are mostly created using data from farmers who receive payments....Thirdly, farmers may have expectations for future payments, and they may change their behavior to affect future policies or in order to be eligible to obtain payments::p.12204" : [Methodology, Small_holder, Survivorship_bias, Variable],
"the impact of a support policy may vary considerably between farmers and regions::p.12205" : [Methodology, Variable],
"cotton-growing areas reduce the lands’ organic matter over time, causing soil degradation, the clay content of the soil to increase, and the groundwater level to rise::p.12205" : [Agroecology, TR_agroEcon],
"child and seasonal workers in its production processes. Cotton production has played a significant role exploiting child labor::p.12205" : [Migration, Rural_Livelihood, TR_Peasant, Risks_Global],
"However, in the mid-2000s, the nature of this direct income support changed, and its share in the agricultural support budget began to decrease in Turkey. As the World Bank project ended, coupled payments increased, and deficiency payments became the main tool in Turkey’s agricultural policies::p.12206" : [History, TR_agroEcon, TR_agroGov],
"For instance, deficiency payments account for more than 95% of total support payments received by cotton farmers in Turkey::p.12206" : [TR_agroEcon, TR_agroGov, Variable],
"the total land area used for cotton farming::p.12207" : [Agro_econ, Variable, Agroecology],
"land area, production, and support levels::p.12208" : [TR_agroEcon, Variable],
"price variable varies between provinces (in our case, two provinces) and years::p.12208" : [TR_agroEcon, Variable],
"fuel oil prices::p.12208" : [Variable],
"to real terms using TurkStat’s Producer Price Index::p.12208" : [Variable],
"model of the farmer::p.12209" : [Variable],
"farmer’s risk preferences::p.12209" : [Variable],
"The farmer forecasts the yield and prices after the harvest::p.12209" : [Variable],
"input usage::p.12210" : [Variable],
"System GMM estimates a system of two simultaneous equations: differences and levels equations.::p.12210" : [Methodology],
"Two postestimation tests are used in the dynamic panel models: Arellano/Bond autocorrelation and Sargan/Hansen overidentification restriction::p.12211" : [Methodology],
"per hectare support level::p.12211" : [Variable],
"there are no detailed farm-level datasets for farmers who produce cotton but do not receive support payments::p.12211" : [Survivorship_bias, Methodology, Variable], 
"weather::p.12212" : [Variable],
"pest damage::p.12212" : [Variable],
"production dynamics (lagged land variables) had a statistically significant impact on farmers’ land allocation decisions::p.12212" : [Agro_econ, Methodology, Variable],
"the total land variable may also be potentially endogenous::p.12212" : [Land_Use, Methodology, Variable],
"fragmented land types::p.12214" : [Land_Use, Variable],
"efficiency of farming::p.12214" : [Land_Use, Variable, Food_Security, Food_Sovereignty],
"plot number variable negatively affects farmers’ decisions related to their land used for cotton farming::p.12214" : [Agroecology, TR_landUse, Variable],
"we thought that ownership issues might have an impact on farmers’ land allocation decisions::p.12214" : [Methodology, TR_Peasant, Variable],
"extreme year for cotton producers, and we controlled that extremity by adding the year dummy::p.12214" : [Methodology, Variable],
"in developing countries, agriculture is seen as a social sector::p.12215" : [Food_Security, Food_Sovereignty, Rural_Family],
"policymakers face a dilemma: should they support small farmers with more social supports, or should they give more support for high yield regions in order to obtain the required production for the industry::p.12215" : [Agro_econ, Food_Security, Food_Sovereignty],
"soil salinity::p.12215" : [Agroecology, Variable],
"not all support tools have the same effect on income inequality::p.12215" : [Agro_policy, Methodology, Small_holder],
"Farmers with larger land sizes receive much more support from the government than small farmers. This issue becomes a problem primarily for family farmers operating in Turkey::p.12216" : [Food_Sovereignty, TR_agroGov],
"farmers’ lagged land elasticities::p.12217" : [Agro_econ, Methodology, Variable],
"The impact of cotton deficiency payments increased according to land size.::p.12217" : [TR_agroGov],
"farmers’ experience, age, education, or similar social factors may be considered::p.12217" : [Variable]
}

add_annots_from_dict(Demirdogen2022, Demirdogen2022_annot)

Demirdogen2022.add_to_excel("literature_annotation.xlsx")

# %%
Dorlach2019= Annotation()

Dorlach2019.Title = "Retrenchment of social policy by other means: A comparison of agricultural and housing policy in Turkey"
Dorlach2019.Citation = "Dorlach, T. (2019). Retrenchment of social policy by other means: A comparison of agricultural and housing policy in Turkey. Journal of Comparative Policy Analysis: Research and Practice, 21(3), 270-286."
Dorlach2019.In_Text_Citation = "Dorlach, 2019"

Dorlach2019_annot = {
"Office, the farmer’s friend in dark days”. “Office” refers to the Turkish Grain Board (Toprak Mahsulleri Ofisi, TMO), which was established in 1938...his agricultural support system was cut back significantly during the 2000s. Emblematically, the TMO’s silo has been defunct since 2005::p.270" : [History, TR_agroGov],
"international pressure by the World Trade Organization (WTO), on the basis of its 1995 Agricultural Agreement, explains the repeal of the Japanese Rice Laws in the 1990s and 2000s::p.273" : [Agro_international, Agro_policy],
"state supported agricultural incomes through a variety of policy instruments, including state monopolies, support purchases, as well as input and credit subsidies::p.274" : [Agro_policy, TR_agroGov],
"Agricultural Retrenchment::p.277" : [History, TR_agroGov],
"narrow focus of mainstream welfare state research on formal social policies, which can lead to the inaccurate conclusion that informal and rural sector workers are excluded from public social protection::p.283" : [TR_agroEcon, TR_ruralGov]
}

add_annots_from_dict(Dorlach2019, Dorlach2019_annot)

Dorlach2019.add_to_excel("literature_annotation.xlsx")

# %%
Ceylan2019 = Annotation()

Ceylan2019.Title = "Neoliberal Ekonomi ve Türkiye Tarım Politikaları Arasında Küçük Köylülüğün Dönüşümü: Edirne İli Örneği (1980-2015)"
Ceylan2019.Citation = "Ceylan, O. (2019). Neoliberal Ekonomi ve Türkiye Tarım Politikaları Arasında Küçük Köylülüğün Dönüşümü: Edirne İli Örneği (1980-2015). Anadolu İktisat Ve İşletme Dergisi, 3(2), 134-152."
Ceylan2019.In_Text_Citation = "Ceylan, 2019"

Ceylan2019_annot = {
"Yeşil Devrim” olarak adlandırılan gübre, petrol, makine ve tarımsal ilaç kullanımı ile üretimin artması ve 1948 Marshall Planından sonra karayollarının inşasıdır.::p.135" : [Agro_policy, History],
"Köylülüğü yaşatan ise sanayi, hizmetler ve ticaret gibi tarım sektörü dışında çalışıp gelir elde etmektir::p.136" : [Rural_Livelihood],
"1999’da Tarım Reformu Uygulama Projesi (ARIP) adıyla DTÖ, IMF ve AB Gümrük Birliği Antlaşmaları::p.137" : [Agro_international, TR_agroGov],
"az gelişmiş ülkeler gıdada giderek bağımlı hale gelmektedir::p.138" : [Agro_econ, Food_Sovereignty],
"Üretim süreçlerinde ise neoliberal düzen kamu, çiftçi ve tüketici zincirini kırarak şirket-çiftçi ve şirket-tüketici zincirini ortaya çıkarmıştır::p.138" : [Food_Sovereignty, Food_Network, Food_Security],
"Tohum hazırlama ve pazarlamada ise özel firmalar 1990’larda ortaya çıkmıştır...Bugün Türkiye’de tohum pazarının %40’ı özel tohum şirketlerinin elindedir. Sayıları 660’ı bulan tohum firmalarının 640’ı yerli 17’si yabancı ve 3’ü de yerli-yabancı ortaklığı ile faaliyet göstermektedir.::p.138" :[Seed],
"2011 yılında Türkiye’de 40.000 ton tarım ilacı kullanılmıştır. Türkiye’de %90’nı ithal olan tarım ilaçları pazarında % 20’lik pay Hektaş’a aittir::p.139" : [Variable],
"küçük köylülüğün yaşadığı ekonomik sistemle uyumlu olmasını sağlayan toprağa sahip olması ve aile emeğinin örgütlenmesiyle üretimdir::p.139" : [Rural_Family, Rural_Livelihood],
"sanayi bölgelerine yakın olup::p.140" : [Variable],
"Bu durum verim artışı ve bunu mümkün kılan tarımsal mekanizasyon, yeni tohum çeşitleri ve girdi kullanımıyla ifade edilebilir. Ancak bu durum tahıllar, yağlı tohumlar, sanayi bitkileri, baklagiller ve sebzemeyveler özelinde incelendiğinde ekili arazi ve üretime dair farklılıklar::p.142" : [TR_agroEcon, Variable, Seed],
"Toplam tahıl ekili alanların 1980 yılından 2000’ne arttığı ancak daha sonraki yıllarda sabit kaldığı ya da düştüğü görülmektedir::p.142" : [Agro_econ, Food_Sovereignty, TR_landUse],
"çeltik tarımı, çiftçileri diğer ürünlere kıyasla daha çok mekanizasyona, kredi kullanmaya ve tarımsal girdi kullanmaya yönlendirmektedir::p.143" : [Methodology, Variable],
"çiftçi hanelerinin yoğun tarım ilacı kullanmaları sonucunda ipekböceklerinin ölümü ile açıklanabileceği gibi ipekböceğinin yoğun ve büyük bir itina gerektiren bakım döneminin çeltik ekim ve bakım dönemine rastlaması ve ipekböcekçiliğinin karlı bir iş olmaktan çıkmasıyla::p.145" : [Agroecology, Rural_Livelihood],
"depolanabilir ürünler::p.147" : [Variable],
"Su kirliliği::p.149" : [Agroecology, Variable],
"Ergene’deki su kirliliği yüzünden Ergene Ovasında 70.000 dekar arazi çeltik ekilemediği için 50.000 ton çeltik kaybı olmaktadır::p.149" : [Agroecology]
}

add_annots_from_dict(Ceylan2019, Ceylan2019_annot)

Ceylan2019.add_to_excel("literature_annotation.xlsx")

# %%
Yagci2019 = Annotation()

Yagci2019.Title = "Policy knowledge, collective action and advocacy coalitions: regulating GMOs in Turkey"
Yagci2019.Citation = "Yagci, A. H. (2019). Policy knowledge, collective action and advocacy coalitions: regulating GMOs in Turkey. Journal of European public policy, 26(6), 927-945."
Yagci2019.In_Text_Citation = "Yagci, 2019"

Yagci2019_annot = {
"Turkey adopted a Biosafety Law (No. 5977) in 2010 primarily to regulate the agricultural GMOs::p.928" : [Health, Seed, TR_agroGov],
"Yet, it is allowed to import GM food and animal feed through a case-bycase approval procedure::p.928" : [Food_Sovereignty, Health, TR_ruralGov],
"industry prefers to supply from wherever it is cheaper, industry leader Rint Akyüz explains that ‘We do not have specific interests relating to whether GM crops are grown in our country::p.930" : [Agro_econ, Food_Network],
"Turkish Union of Chambers of Agriculture (TZOB). TZOB is a corporatist organization that was instituted by the state between 1958 and 1963, and required by law to have a Chamber in every town.::p.934" : [History, Seed],
"In 1998, about two years after the GMOs were first commercialized in the world::p.934" : [History, Seed, Food_Sovereignty],
"Agricultural Research (TAGEM) was considered to be the appropriate address to handle the issue::p.935" : [Agro_tech, Seed, TR_agroGov],
"yield increases (due to reduced damage by pests) of around 30%35% compared to non-GM high-yield hybrid seeds. The projected impact on farmer’s gross profit would be dependent on terms of access to seeds, though: if increased production translated to lower commodity prices by around 30%, farmer profits would actually decline under the price differentials assumed::p.936" : [Food_Sovereignty, Seed, TR_agroEcon],
"farmer’s gross profit would be dependent on terms of access to seeds::p.936" : [Agro_econ, Variable],
"feasible to implement the regulation as intended as it would increase supply costs dramatically::p.938" : [Agro_econ, Food_Security, TR_agroEcon],
"ÇB’s secretary Oana Çorat has been a rare voice by publicly questioning the idea that completely banning the GM seeds would be Turkey’s best choice, and arguing that Turkish cotton and corn farmers could definitely use help from insect-resistant GM varieties::p.940" : [Agro_econ, Food_Security, Food_Sovereignty],
"AÇB had to shift the focus of its discourse and started criticizing the fact that while Turkish farmers cannot use GM seeds they nonetheless have to compete with commodity imports originating from such seeds, amounting to unfair competition. Cotton producers from the export-oriented Aegean region too went through a similar strategy readjustment::p.940" : [Agro_international, Cooperatives],
"Mehmet Akif Paksoy described the outcome evocatively: After passing this law, maybe it will be possible to protect our biological resources but it will be more difficult to develop new varieties using modern biotechnology. It will be more difficult for our universities and research institutes to bring in research material from abroad::p.941" : [Agro_tech, TR_agroGov]
}

add_annots_from_dict(Yagci2019, Yagci2019_annot)

Yagci2019.add_to_excel("literature_annotation.xlsx")

# %%
Celebican1972 = Annotation()

Celebican1972.Title = "Köy Envanter Etüdler’ne göre Türkiye’de tarımsal toprakların dağılımı"
Celebican1972.Citation = "Çelebican, G. (1972). Köy Envanter Etüdler’ne göre Türkiye’de tarımsal toprakların dağılımı. Ankara Üniversitesi Hukuk Fakültesi Dergisi, 29(1). https://doi.org/10.1501/Hukfak_0000000998"
Celebican1972.In_Text_Citation = "Celebican, 1972"

Celebican1972_annot = {
"Gerçekten de, beş ilâ yedi yıl önce derlenen bilgilerin yansıttığı olgularda zaman­ la bazı değişmelerin meydana gelmiş olduğu kesinlikle söylenebilir.::p.325" : [History, TR_agroGov, TR_ruralGov],
"67 ile bağlı 35.640 köyü ve bucağı kapsamaktadır::p.327" : [Methodology, History, Variable],
"Köy Envanter Etüdleri'nden elde edilen sonuçlar, tarla, orman, mera ve çayırlar dışındaki toprakların birbirleriyle toplanması yo­ luna gidilerek::p.330" : [TR_landUse],
"Köy Envanter Etüdleri'ne göre, 4.282.838 ailenin 4.125. 534'ü çiftçilikle uğraşmakta, 157.304'ü ise geçimlerini tarım dışı faaliyetlerden sağlamaktadır...4.125.534 çiftçi ailesinden 2.857.442'si tarımsal topraklara sahip olup, bunlara ait toprakların yüzölçümü 121.078.858 dönüm­dür. Buna karşılık, hiç toprağı bulunmayan ve ortakçı, kiracı ya da tanm işçisi olarak çalışan çiftçi ailelerinin sayısı, 1.268.092'dir.. Topraksız ailelerin 72.787.'si ortakçılık, 12.672'si kiracılık, 1.175.959u da tarım işçiliği yoluyla::p.332" : [Rural_Family, Rural_Livelihood, TR_Peasant],
"Türkiye'deki 726 köyde toprakların tüm olarak ya tek bir kişiye, ya bir aileye ya da bir sülâleye ait bulunduğu, Köy Envan­ter Etüdleri'nden anlaşılmaktadır::p.333" : [Rural_Livelihood, TR_agroEcon],
"Topraksız aileler sayısının çiftçi ailelerine oranı::p.337" : [Variable],
"Kentlerde yaşayan fakat köylerde toprağı olan ailelere ait toprakların, il kümeleri içindeki oransal önemi de benzer bir sıra izlemektedir::p.337" : [Variable],
"topraklı çiftçi ailelerine ait top­ raklar olduğundan küçük gösterilmiş ve böylece mülkiyet durumu belirlenmeyen 145 milyon dönüm genişliğinde toprak farkı::p.340" : [TR_ruralGov],
"bazı illerde da­ ha belirgin olarak ortaya çıkmaktadır::p.441" : [Food_Sovereignty, Methodology, Variable]

}

add_annots_from_dict(Celebican1972, Celebican1972_annot)

Celebican1972.add_to_excel("literature_annotation.xlsx")

# %%
Baktybekova2024 = Annotation()

Baktybekova2024.Title = "Constructing a composite indicator to measure quality of life in the selected region"
Baktybekova2024.Citation = "Baktybekova, Z. (2024). Constructing a composite indicator to measure quality of life in the selected region [Master's thesis, Czech University of Life Sciences Prague, Faculty of Economics and Management]. https://theses.cz/id/7gev2g/"
Baktybekova2024.In_Text_Citation = "Baktybekova, 2024"

Baktybekova2024_annot = {
"collective effects of composite indicators::p.11" : [Methodology],
"interconnections between different dimensions and their impact on overall::p.11" : [Methodology],
"potential variations in the impact of composite indicators on QoL::p.11" : [Methodology],
"provide insights into policy implications::p.11" : [Methodology],
"HRQoL is influenced by the bio-psychosocial viewpoint on health and has become a significant aspect of contemporary medicine and practice during the last twenty years (Awad et al. 1997). Due to the interconnectedness of individuals and their environment, both HRQoL and non-HRQoL intersect.::p.14" : [Methodology],
"job quality refers to the variety of aspects which are associated to jobs and employment which have a way of favorably and significantly influencing the well-being of individuals::p.16" : [Methodology, Variable],
"family dynamics influence Family Quality of Life (FQOL) as well as collaborate with human being and family-level assistance, services, and behaviors in order that determine FQOL::p.22" : [Methodology],
"social fitness can predict a person's future health status, although subjective wellbeing is not as effective in predicting social well-being::p.27" : [Methodology],
"Survey Design::p.35" : [Methodology],
"Maslow's (1948) seminal work on the hierarchy of needs laid the groundwork for understanding the fundamental role of security in fostering well-being::p.50" : [Methodology]
}

add_annots_from_dict(Baktybekova2024, Baktybekova2024_annot)

Baktybekova2024.add_to_excel("literature_annotation.xlsx")

# %%
Schulthess2017 = Annotation()

Schulthess2017.Title = "A composite indicator framework for general household resilience on Mahé, Seychelles"
Schulthess2017.Citation = "Schulthess, A. (2017). A composite indicator framework for general household resilience on Mahé, Seychelles [Master's thesis, ETH Zurich]. https://ethz.ch/content/dam/ethz/special-interest/usys/tdlab/docs/education/theses/2017-msc-schulthess.pdf"
Schulthess2017.In_Text_Citation = "Schulthess, 2017"

Schulthess2017_annot = {
"The indicator income fluctuation is assessed using a forced-choice ordinal scale question with four choices. For this thesis, I assume that the ordinal scale using the choices strongly agree to strongly disagree can be interpreted as an interval scale with fixed intervals. Therefore, the answers are scored accordingly with a score of 0, 0.33, 0.66 and 1 respectively. The indicator presence of gambling behaviour is assessed using a dichotomous question. A “yes” answer receives a resilience score of 0 and a “no” answer a score of 1.::p.56" : [Methodology],
"The answer of each question is scored individually and the indicator score is then calculated by averaging the two scores::p.56" : [Methodology],
"The overall indicator score is calculated by averaging the scores of the three questions::p.57" : [Methodology],
"equal weights of all the indicators in the composite indicator (in this thesis abbreviated with EIN)...The second approach equal weights of all the dimensions and indicators (abbreviated with EDI)...third approach expert weights for the indicators (abbreviated with EXP) was to assign weights to all indicators for the calculation of the composite indicator score based on expert opinions::p.59" : [Methodology],
"The dimension weights, however, change considerably based on the selected weighting approach::p.62" : [Methodology],
"First, local knowledge has been considered as recommended (e.g. ProVention, 2006; USAID et al., 2014). Second, the selection of each indicator is explained and justified. This contributes to the transparency of the developing process which is of special importance (OECD, 2008)::p.70" : [Methodology],
"some contribution to this difficulty can be attributed to the fact that Seychellois are not often interviewed using this question type (personal communication, February 2, 2017). It can, therefore, be assumed that this difficulty vanishes as soon as the households get used it::p.71" : [Interdisciplinary],
"The scores of the different dimensions should not be compared with each other. The score of each dimension is calculated differently::p.78" : [Methodology],
"Ideally, all potential sources of uncertainty should be addressed::p.81" : [Methodology]
}

add_annots_from_dict(Schulthess2017, Schulthess2017_annot)

Schulthess2017.add_to_excel("literature_annotation.xlsx")

# %%
AlmeidaFerre2019 = Annotation()

AlmeidaFerre2019.Title = "Internationally-based indicators to measure Agri-food systems sustainability using food sovereignty as a conceptual framework"
AlmeidaFerre2019.Citation = "Ruiz-Almeida, A., & Rivera-Ferre, M. G. (2019). Internationally-based indicators to measure Agri-food systems sustainability using food sovereignty as a conceptual framework. Food Security, 11(6), 1321-1337."
AlmeidaFerre2019.In_Text_Citation = "Ruiz-Almeida & Rivera-Ferre, 2019"

AlmeidaFerre2019_annot = {
"women in the struggle for food sovereignty. In that manner, gender issues have become central to the proposal, suggesting the need to add this new category::p.6" : [Methodology, Gender],
"The final collection consisted of 97 indicators. Almost every indicator has been standardized by dividing it with another variable to allow for comparability across countries::p.6" : [Methodology, Variable],
"resource re-distribution and identification to fight rural poverty::p.6" : [Methodology],
"Access to seeds is one of the most important demands of the food sovereignty proponents::p.11" : [Food_Sovereignty, Seed],
"Indicators for two attributes are missing here; those reflecting small producers’ participation in agricultural policies, and those showing human rights and peasant organizations in every country. Both attributes are essential for the food sovereignty proposal, but unfortunately, there is no information available at the international level::p.12" : [Methodology],
"gender-sensitive indicators (GSI)::p.12" : [Variable, Gender],
"Also, country information should be based on detailed data collected at field level by different government agencie::p.13" : [Methodology, Variable]
}

add_annots_from_dict(AlmeidaFerre2019, AlmeidaFerre2019_annot)

AlmeidaFerre2019.add_to_excel("literature_annotation.xlsx")

# %%
Barclay2019 = Annotation()

Barclay2019.Title = "The problem with composite indicators"
Barclay2019.Citation = "Barclay, M., Dixon-Woods, M., & Lyratzopoulos, G. (2019). The problem with composite indicators. BMJ quality & safety, 28(4), 338-344"
Barclay2019.In_Text_Citation = "Barclay et al., 2019"

Barclay2019_annot = {
"A popular approach involves use of composite indicators that combine information on individual measures of care quality into single scores::p.338" : [Methodology],
"Too often, however, composite indicators are presented with limited or no information about the derivation and interpretation of constituent measures::p.338" : [Methodology],
"composite indicators purporting to provide a broad overview of organisational quality may be dominated by a few clinical areas or by surveillance measures that are unsuitable for measuring quality::p.338" : [Food_Security, Food_Sovereignty, Methodology],
"Yet such hospitals report fewer measures than general hospitals and are substantially more likely to be classed as high-performing than the average hospital::p.339" : [Interdisciplinary, Methodology],
"But rates of missing data vary substantially... some public reporting schemes purposefully suppress measures when they are based on a small number of patients or when there are data quality concerns::p.339" : [Methodology],
"Many composite indicator schemes apply threshold-based classification rules to standardise disparate individual measures to a consistent scale...This approach violates the general statistical principle that such categorisation reduces statistical power and potentially hides important differences::p.340" : [Methodology],
"The weighting assigned to individual measures contributing to composites is another problem area. As few hospitals perform equally well in all areas, performance can be artificially improved by giving higher weight to individual measures...But that criticism is also applicable to the decision to adopt equal weights::p.340" : [Methodology, Variable],
"Requirements, steps forward and remaining challenges for robust and useful composite indicators::p.341" : [Methodology],
"The reasons for missing data should be explored::p.342" : [Methodology]
}

add_annots_from_dict(Barclay2019, Barclay2019_annot)

Barclay2019.add_to_excel("literature_annotation.xlsx")

# %%
Uzundumlu2012 = Annotation()

Uzundumlu2012.Title = "Tarım Sektörünün Ülke Ekonomisindeki Yeri ve Önemi"
Uzundumlu2012.Citation = "Uzundumlu, A. S. (2012). Tarım Sektörünün Ülke Ekonomisindeki Yeri ve Önemi. Alinteri Journal of Agriculture Science, 22(1), 34-44."
Uzundumlu2012.In_Text_Citation = "Uzundumlu, 2012"

Uzundumlu2012_annot = {
"kırsal alandaki işletmeler 6-7 kişilik bireylerden oluşmakta::p.35" : [Rural_Livelihood, Variable],
"tarım sektörünün istihdamdaki payı::p.36" : [Variable],
"tarımdaki işsizlik oranının toplam işsizlik oranından düşük olduğu görülmekte::p.36" : [TR_agroEcon, Variable],
"göçle gelen emeğe yeterince istihdam sağlayacak yapısal ve sektörel gelişme sağlanamadığı için kentlerde plansız gelişmede, işsizlikte ve hırsızlıkta artışlara neden olmuştur::p.36" : [Migration, Urbanization],
"mevcut tarım işletmelerinin %67,4’ünde bitkisel ve hayvansal üretim birlikte yapılırken, sadece hayvansal üretim yapan işletmelerin oranı %2,4’tür::p.36" : [TR_agroEcon, Variable],
"GSMH içinde tarımsal üretimin payı::p.37" : [Variable],
"toplam tarımsal üretim değeri içerisinde hayvansal üretimin payı %31,0 olarak tespit edilmiştir::p.37" : [Agro_econ, Methodology, Variable],
"Türkiye’de 2010 yılı itibari ile 16,3 milyon ha toplam tarım arazisinin %67’sini tahıllar ve diğer bitkisel ürünler oluştururken, %17,4’ünü nadas arazi, %3,3’ünü sebze bahçeleri ve % 12,5’ini meyve içecek ve baharat bitkiler oluşturmaktadır::p.37" : [TR_landUse, Variable],
"Endüstri bitkileri üretiminde son yıllarda önemli gelişmeler kaydedilmiştir. Özellikle pamuk, patates ve ayçiçeği üretiminde yeni çeşitlerin üretime alınması ve tarım teknolojisindeki gelişmelerle verimde büyük artışlar sağlanmıştır::p.38" : [Agro_international, Agro_tech, Variable],
"Büyükbaş Hayvan Sayıları ve Üretim Miktarları::p.38" : [Variable],
"2010 yılında 780 000 ton kırmızı et üretilmiş ve 160 000 ton kırmızı et ithal edilmiştir::p.38" : [Food_Security, Food_Sovereignty, Variable],
"Küçükbaş Hayvan Sayıları ve Üretim Miktarları::p.39" : [Variable],
"tarımsal hammaddeleri işleyen sanayi dalları imalat sanayi içerisinde yer alan gıda sanayi ve dokuma sanayi olmak üzere iki ana gruptan oluşmaktadır::p.39" : [Variable],
"İthal/İhraç edilen tarımsal ürünler::p.41" : [Food_Network, Food_Sovereignty, Variable]
}

add_annots_from_dict(Uzundumlu2012, Uzundumlu2012_annot)

Uzundumlu2012.add_to_excel("literature_annotation.xlsx")

# %%
Gursoy2012 = Annotation()

Gursoy2012.Title = "GÜNEYDOĞU ANADOLU BÖLGESİNDE TARIMSAL ÜRETİMİN GELİŞMESİNDE MEKANİZASYONUN ROLÜ"
Gursoy2012.Citation = "Gürsoy, S. (2012). GÜNEYDOĞU ANADOLU BÖLGESİNDE TARIMSAL ÜRETİMİN GELİŞMESİNDE MEKANİZASYONUN ROLÜ. Batman Üniversitesi Yaşam Bilimleri Dergisi, 1(2), 339-346."
Gursoy2012.In_Text_Citation = "Gürsoy, 2012"

Gursoy2012_annot = {
"Endüstrisi yeteri kadar gelişmemiş ülkelerde kırsal nüfusun büyük bir kısmının açıkta bırakılması, işçi sorununa neden olacağı söylense de tarımsal mekanizasyon geliştikçe tarımla ilgili birçok iş alanları açılmaktadır ve makinanın tarıma girmesi sonucunda açılan bu iş alanlarında yaratılan iş miktarı, açıkta bıraktığı iş kuvvetinden daha fazla bir kuvveti uğraştıracak kadar fazla olduğu ifade edilmektedir::p.340" : [Agro_econ],
"bölgede bulunan tarımsal işletme sayısı, işletmelerin arazi miktarları, parçalılık durumu, işletmelerin kredi kaynakları, hane halkı ortaklığı, işletmelerde çalışan kişilerin eğitimi, kişi sayısı, yaşları ve cinsiyetleri; hayvansal ve bitkisel üretimi bakımından tarımsal işletmelerin üretim cinsleri ve üretime ayırdıkları arazi miktarları; bitkisel üretim yapan işletmelerde sulanan, sulanmayan, ekilen, nadasa bırakılan, tarıma elverişli olan arazi miktarları, üretim desenleri ve işletmelerdeki tarımsal mekanizasyon düzeyi::p.340" : [Variable],
"Kişi başına düşen gelir miktarı yönünden Güneydoğu Anadolu Bölgesi Türkiye'nin en düşük bölgelerinden biridir::p.341" : [Variable],
"2002 yılında GAP Bölgesi'nde yapılan ihracatın ülke geneli içindeki payı::p.341" : [Food_Sovereignty, Variable],
"Bölgesel Gayrisafi Hasıla'nın, Gayrısafi yurtiçi hasıla içindeki payı::p.341": [Variable],
"birinci sınıf arazi oranı::p.342" : [Variable],
"sulamaya açılmıştır::p.342" : [Variable],
"sulamayla birlikte ürün deseninin de önemli ölçüde değiştiği görülmektedir::p.342" : [TR_agroGov, TR_landUse, Methodology],
"hayvancılık genellikle meraya dayalı ekstansif olarak::p.343" : [Agroecology, Food_Sovereignty, Variable],
"Tarımsal mekanizasyon düzeyi çeşitli veriler ile açıklanmaktadır. Bunlar, birim alandaki güç tüketimi, hektara düşen traktör sayısı, traktör başına düşen tarımsal alan, traktör başına düşen tarım iş makinası ağırlığı, tarımsal kesimde kullanılan enerji çeşitliliği, traktör kullanım süresi ve üreticinin traktör alım gücü, tarım makinalarının araştırmalarına ayrılan parasal olanak ve tarımda çalışan birim insan gücünün üretim değeri gibi verilerdir::p.343" : [Agro_tech, Rural_Livelihood, Variable],
"birim alana düşen mekanik güç büyüklüğü (kw/hA)::p.343" : [Variable],
"Bitki deseninin değişmesine paralel olarak, tarım alet ve makinalarının çeşitliliğinde de artış meydana gelmiştir::p.343": [Rural_Livelihood, TR_Peasant],
"Tarımsal mekanizasyon, her işletmenin teknik ve ekonomik yapısına bağlı olarak farklı düzeylerde uygulanmaktadır::p.344" : [Agro_tech, Land_Use, Small_holder],
"bölgede gereksinim duyulacak işgücünün 2.8 milyona çıkacağı tahmin edilmiştir::p.345" : [Food_Sovereignty, Rural_Livelihood, TR_Peasant]
}

add_annots_from_dict(Gursoy2012, Gursoy2012_annot)

Gursoy2012.add_to_excel("literature_annotation.xlsx")

# %%
oecd2008 = Annotation()

oecd2008.Title = "Handbook on Constructing Composite Indicators: Methodology and User Guide"
oecd2008.Citation = "OECD, European Union, & Joint Research Centre - European Commission. (2008). Handbook on Constructing Composite Indicators: Methodology and User Guide. OECD. https://doi.org/10.1787/9789264043466-en"
oecd2008.In_Text_Citation = "OECD et al., 2008"

oecd2008_annot = {
"studying the relationship between information flowing in and out of the model. More formally, sensitivity analysis is the study of how the variation in the output can be apportioned, qualitatively or quantitatively, to different sources of variation in the assumptions, and of how the given composite indicator depends upon the information fed into it. Sensitivity analysis is thus closely related to uncertainty analysis, which aims to quantify the overall uncertainty in country rankings as a result of the uncertainties in the model input::p.119" : [Methodology],
"The analysis is conducted as a single Monte Carlo experiment, e.g. by exploring all uncertainty sources simultaneously to capture all possible synergy effects among uncertain input factors::p.120" : [Methodology],
"sensitivity analysis using variance-based techniques are model-free and display additional properties convenient in the present analysis::p.123"  : [Methodology],
"A model without interactions among its input factors is said to be additive::p.124" : [Methodology],
"favoured by the combination of “geometric mean system” with “BAP weighting”, and not favoured by the combination of “Multi-criteria system” with “AHP weighting::p.128" : [Methodology, Survivorship_bias],
"choice of the aggregation system is to some extent dictated by the use of the index and by the expectation of its stakeholders::p.131" : [Methodology],
"Neither imputation nor normalisation significantly affect countries’ rankings when uncertainties of higher order are present. In the current set-up, the uncertainties of higher order are expert selection and weighting scheme::p.133" : [Methodology],
"Path analysis, conceived by the biologist S. Wright in the 1920s, is an extension of regression analysis in which many endogenous and exogenous variables can be analysed simultaneously::p.134" : [Methodology],
"SEM is an extension of the general linear model that simultaneously estimates relationships between multiple independent, dependent and latent variables::p.137" : [Methodology],
"the usefulness of composite indicators for analytic purposes should not be discounted::p.140" : [Methodology]
}

add_annots_from_dict(oecd2008, oecd2008_annot)

oecd2008.add_to_excel("literature_annotation.xlsx")

# %%
jrc2017 = Annotation()

jrc2017.Title = "The use of the Global Food Security Index to inform the situation in food insecure countries"
jrc2017.Citation = "European Commission, Joint Research Centre, Thomas, A., d’Hombres, B., Casubolo, C. (2017). The use of the Global Food Security Index to inform the situation in food insecure countries, Publications Office. https://data.europa.eu/doi/10.2760/83356"
jrc2017.In_Text_Citation = "European Commission et al., 2017"

jrc2017_annot = {
"The review of conceptual framework indicates that the GFSI has to be interpreted as a food security environment rating. It focuses on the food security determinants rather than on the food security outcomes::p.3" : [Food_Security, Methodology],
"Indicators included in the GFSI are measured at the national level and not at the household level. Inequality indicators are not included. The GFSI is thus measuring the average situation in the countries rather than focusing on food insecure households::p.3" : [Food_Security, Food_Sovereignty, Methodology],
"GFSI ranking can be considered, for the vast majority of countries, robust to variations in the weighting scheme and the aggregation method::p.4" : [Methodology],
"the countries ranking obtained with the GFSI is compared with the one obtained with the IFPRI Global Hunger Index (GHI) and the FAO Prevalence of Undernourishment (PoU)::p.7" : [Food_Security, Methodology],
"The main data sources used in the GFSI are the EIU, the World Bank Group, the International Monetary Fund (IMF), the UN Food and Agriculture Organisation (FAO), the UN Development Programme (UNDP), the World Health Organisation (WHO), the World Trade Organisation (WTO), the World Food Programme (WFP), Agricultural Science and Technology Indicators (ASTI) and national statistical offices::p.8" : [Methodology],
"GFSI is similar to a prevalence of food insecurity and not to the number of food insecure in absolute terms::p.11" : [Methodology],
"Syria ranks quite low (96/113) because of the consequence of the conflict::p.13" : [Methodology],
"Food security is defined as a situation where “all people, at all times, have physical and economic access to sufficient safe and nutritious food that meets their dietary needs and food preferences for an active and healthy life.” (1996 World Food Summit). This definition has been used to identity food security as a four-dimensional object (FAO, 2009). The four dimensions are: availability, access, utilization and stability::p.18" : [Agro_policy, Food_Security],
"Availability contains information on food supply and food aid that are also recorded in the ‘FAO availability’ concept::p.19" : [Methodology, Variable],
"information usually recorded in the access dimension (such as infrastructure which describes the physical access) and in the stability dimension (such as volatility of agricultural production, political stability and food loss). It also embeds other information such as the research budget, the corruption level and the urban absorption capacity. Finally, the Quality and safety dimension includes a lot of information on nutrition policies that are not usually recorded in the utilization dimension, even if they are contributing factors. The theoretical model thus only partially overlaps with the standard FAO conceptualization of food security::p.19" : [Agro_international, Food_Security],
"The GFSI is country-centered whereas FAO conceptual framework is people-centered::p.19" : [Food_Security, Food_Sovereignty, Methodology],
"The GFSI is thus designed to monitor trends in food security in a country. Alternative indicators with similar purposes4 include::p.20" : [Methodology, Variable],
"regarding the selection of indicators (see Table 2), the choice has been driven by both data availability at global level and expert judgment about which indicators to be included. Subjective (but well informed) interpretation of data is common when evaluating food insecurity in food insecurity prone countries::p.20" : [Food_Sovereignty, Methodology],
"The agricultural import tariffs indicator may make sense for developed countries but it is more questionable in food insecure countries::p.21" : [Variable],
"Imputed values are mainly concentrated on two indicators, i.e. Proportion of population under global poverty line (dimension affordability) and Public expenditure on agricultural R&D (dimension availability)::p.22" : [Agro_policy, Food_Security, Methodology],
"Yet, some indicators and sub-indicators exhibit low or very low correlations with the corresponding pillar and the overall GFSI score. This is the case of the following indicators Volatility of agricultural production and Urban absorption capacity (dimension Availability), and of two variables, namely National nutrition plan or strategy and Dietary availability of vegetal iron belonging to the third dimension Quality and Safety. Note that while these two variables are relatively influential at the indicator level, their information content is lost at the dimension and overall GFSI index levels::p.25" : [Methodology],
"The three dimensions in the GFSI framework, availability, affordability and quality and safety are strongly interrelated despite that the design gives the impression of independent dimensions::p.28" : [Methodology],
"Table 15 underlines that, at the Availability dimension level, two indicators, namely Volatility of agricultural production and Urban Absorption capacity have almost no impact on the score attributed to this dimension::p.33" : [Methodology, Variable],
"However, we note that for a small number of countries, the ranks are sensitive with variations in the weighting scheme and aggregation function. This is particularly the case for Qatar, Botswana, Egypt and Kazakhstan::p.36" : [Methodology],
"Comparison of the GFSI with other indicators::p.39" : [Methodology],
"The GFSI is that it is based on contributing factors rather than outcomes of food security::p.45" : [Food_Security, Methodology],
"The GFSI, like any other composite indicator, does not allow to draw any causal inference::p.45" : [Methodology]
}

add_annots_from_dict(jrc2017, jrc2017_annot)

jrc2017.add_to_excel("literature_annotation.xlsx")

# %%
Barret2010 = Annotation() # Example Usage
# Create the annotation class


# Add references with functions
Barret2010.Title = "Measuring Food Insecurity"
Barret2010.Citation = "Barrett, C. B. (2010). Measuring food insecurity. Science, 327(5967), 825-828."
Barret2010.In_Text_Citation = "Barret, 2010"

# Combine all annotations with their chosen categories
Barret2010_annot = {
"1996 World Food Summit, holds that food security represents “a situation that exists when all people, at all times, have physical, social and economic access to sufficient, safe and nutritious food that meets their dietary needs and food preferences for an active and healthy life.::p.825" : [Food_Security],
"was a response to lack of progress in individual-level indicators despite growth in aggregate food supplies and incomes::p.826" : [Agro_econ, Food_Security, Food_Sovereignty, Methodology],
"Research is appropriately and increasingly moving toward survey-based anthropometric and perceptions measures::p.827" : [Food_Security, Methodology]
}
add_annots_from_dict(Barret2010, Barret2010_annot)

Barret2010.add_to_excel("literature_annotation.xlsx")

# %%
Bowman2015 = Annotation()

Bowman2015.Title = " Sovereignty, Risk and Biotechnology: Zambia's 2002 GM Controversy in Retrospect"
Bowman2015.Citation = "Bowman, A. (2015). Sovereignty, risk and biotechnology: Zambia's 2002 GM controversy in retrospect. Development and Change, 46(6), 1369-1391."
Bowman2015.In_Text_Citation = "Bowman, 2015"

Bowman2015_annot = {
"which has led the promotion of public–private partnerships in seed technology — called this situation a ‘farce’, signalling ‘the arbitrariness and unpredictability of public policy::p.1370" : [Agro_policy],
"When the World Food Programme (WFP) attempted to distribute GM maize as food aid, governments protested and temporarily blocked distribution, citing concerns over health and agroecological impacts::p.1370" : [Agro_policy, Agroecology, Seed],
"The introduction of GM food aid to Zambia, without prior notification, from the United Nations World Food Programme (WFP) and the United States Agency for International Development (USAID) was interpreted among sections of the Zambian policy elite as another example of international institutions attempting to override Zambian government sovereignty::p.1372" : [Agro_policy, Food_Security, Food_Sovereignty],
"A debt crisis in the 1980s made Zambia dependent upon assistance from the Bretton Woods institutions. The accompanying conditionalities, first via the structural adjustment programme and then through the Heavily Indebted Poor Countries Initiative, meant Zambian decision makers operated within a ‘bounded autonomy::p.1377" : [Agro_econ, Autonomy, History],
"another school of thought that felt that we were losing too much of the indigenous seeds in various crops and that this may not necessarily be a good thing, that we needed to keep some of these natural seeds as a fall-back position to the hybrids. Then of course politics got into the argument, and some people were saying, ‘why is it that companies like Monsanto are monopolizing the development of new seed varieties::p.1378" : [Big_agro, Food_Sovereignty, Seed]
}

add_annots_from_dict(Bowman2015, Bowman2015_annot)

Bowman2015.add_to_excel("literature_annotation.xlsx")

# %%
Claeys2018 = Annotation()

Claeys2018.Title = "The rise of new rights for peasants. From reliance on NGO intermediaries to direct representation"
Claeys2018.Citation = "Claeys, P. (2018). The rise of new rights for peasants: from reliance on NGO intermediaries to direct representation. Transnational Legal Theory, 9 (3-4), 386-399."
Claeys2018.In_Text_Citation = "Claeys, 2018"

Claeys2018_annot = {
"LVC represents 200 million peasant farmers across 73 countries (through more than 164 organisations) and is well known for its 20 years of struggles against trade liberalisation and the World Trade Organization (WTO), Genetically Modified Organisms (GMOs) and land grabbing.::p.2" : [Food_Sovereignty],
"a Peasant Rights’ Charter was elaborated through village workshops. Initially conceived of as a tool to oppose the ‘green revolution’, the Charter recognised 61 rights to ‘peasants and their families, personally or as group’ in the following eight areas: livelihood, resource control (land, biological diversity), production (including technology choices), consumption (including what to produce), marketing (market access, quality protection and property rights), political and social arenas, reproduction (including both human reproduction and biodiversity) and freedom of expression (language, culture, religion and arts).::p.4" : [Food_Network, Food_Sovereignty, Rural_Development],
"At a regional conference in 2002, members of LVC in the region adopted a ‘Declaration about the protection of the peasant right’, which included a preamble and 10 main articles: 1) right to life and proper living standard, 2)right to agrarian resources 3) right to seeds, 4) right to capital and means of agricultural production, 5) right to access to information and agricultural technology, 6) right to freedom in determining price and market for agricultural production, 7) right to protection of agricultural values, 8) right to biological diversity, 9) right to environmental preservation, and 10) right to freedom of association::p.5" : [Autonomy, Food_Sovereignty]
}

add_annots_from_dict(Claeys2018, Claeys2018_annot)

Claeys2018.add_to_excel("literature_annotation.xlsx")

# %%
Datt1998 = Annotation()

Datt1998.Title = "Computational tools for poverty measurement and analysis"
Datt1998.Citation = "Datt, G. (1998). Computational tools for poverty measurement and analysis."
Datt1998.In_Text_Citation = "Datt, 1998"

Datt1998_annot = {
"How do we construct poverty measures from such grouped data? Two broad approaches can be identified: simple interpolation methods and methods based on parameterized Lorenz curves::p.1" : [Methodology],
"function of the ratio of the mean consumption : to the poverty line z and the parameters of the Lorenz curve::p.3" : [Methodology],
"the growth component of a change in the poverty measure is defined as the change in poverty due to a change in the mean::p.17" : [Food_Security, Food_Sovereignty, Methodology],
"Simulating the contribution of regional or sectoral disparities in mean consumption to aggregate poverty::p.18" : [Agro_econ, Methodology]    
}

add_annots_from_dict(Datt1998, Datt1998_annot)

Datt1998.add_to_excel("literature_annotation.xlsx")

# %%
FAO2016 = Annotation()

FAO2016.Title = "Climate change, agriculture and food security"
FAO2016.Citation = "FAO (Ed.). (2016). Climate change, agriculture and food security. FAO."
FAO2016.In_Text_Citation ="FAO, 2016"

FAO2016_annot = {
"However, improvements in infrastructure, extension, climate information, access to credit, and social insurance, which are at the heart of rural development, need to go hand in hand in order to foster the adoption of improved practices and the diversification of rural livelihoods::p.xiii" : [Rural_Development, Rural_Livelihood],
"In both temperate and tropical regions, farming system diversification and croplivestock-tree integration could increase farmscale efficiency, reduce emissions intensity and raise productivity::p.xiv" : [Agroecology, Food_Security],
"Drivers vary significantly between countries and regions smallholder farmers do not have the same capacity as global agribusinesses to respond to policy and market signals::p.xv" : [Big_agro, Small_holder],
"Some measures, such as input subsidies, may induce inefficient use of agrochemicals and increase the emissions intensity of production::p.xvi" : [Agro_policy, Agroecology],
"The agriculture sectors are, therefore, also unique in their potential contribution to stabilizing the world’s climate, through better management of crops, land and livestock, in a way that reduces emissions and increases carbon sequestration in plant biomass and soils::p.5" : [Agroecology, Risks_Global],
"Annual anthropogenic GHG emissions that are classified in IPCC reports as originating in “agriculture, forestry and other land use” (AFOLU) are caused mainly by deforestation, livestock production and soil and nutrient management::p.6" : [Agroecology, Land_Policy],
"Productivity declines and losses of income would tend to be concentrated in some of the most food-insecure and vulnerable geographic areas and population groups::p.10" : [Food_Network, Food_Security, Food_Sovereignty],
"Improving and protecting rural livelihoods and social well-being. Enhancing the resilience of people, communities and ecosystems::p.15" : [Food_Security, Food_Sovereignty],
"food supply chain, from producer to consumer, is affected by – and contributes to – climate change, sometimes to a larger extent than primary agriculture itself::p.15" : [Agroecology, Food_Network],
"it increases temperature and precipitation variability, reduces the predictability of seasonal weather patterns and increases the frequency and intensity of severe weather-related events such as floods, cyclones and hurricanes::p.22" : [Agroecology, Risks_Global],
"yields suffer more in tropical regions than at higher latitudes and impacts are more severe with increased warming::p.22" : [Agroecology, Food_Security],
"They include the delivery of a clean and reliable water supply, protection against landslides erosion and land degradation, provision or enhancement of the habitats of aquatic and terrestrial animals::p.28" : [Agroecology],
"At the national level, reduced production due to climate change can trigger an increase in the prices of food and feed, negatively affecting the socio-economic status of the whole population and its food security::p.32" : [Agroecology, Food_Security],
"THREE MAIN SOURCES OF AGRICULTURAL GREENHOUSE GAS EMISSIONS IN 2014, BY REGION::p.41" : [Agroecology],
"During extreme events, they adopt precautionary strategies – for example, selling cattle – which may protect them against catastrophic losses but undermine long-term livelihood opportunities and can trap them in chronic poverty::p.48" : [Rural_Livelihood, TR_Peasant],
"According to HLPE (2016), agroecology applies ecological concepts and principles to farming systems. Through its focus on the interactions between plants, animals, humans and the environment, it fosters sustainable agricultural development, which in turn ensures food security and nutrition::p.51" : [Agroecology],
"Polycultures exhibit greater yield stability and suffer fewer productivity declines during a drought than monocultures::p.51" : [Monoculture_Poli],
"THE AGRICULTURE SECTORS FACE A UNIQUE CHALLENGE: to produce more food while reducing greenhouse gas emissions caused by food production- decoupling::p.71" : [Agroecology, Food_Security],
"intensive storage. The choice of refrigerants is also important – the leakage of refrigerant gases from old or poorly maintained equipment depletes the ozone layer in the atmosphere and has significant global warming potential. More stable dried, smoked and salted products processed in artisanal supply chains require methods of transport that are not time-sensitive and produce lower levels of GHG::p.80" : [Food_Network],
"Fischbeck, Tom and Hendrickson (2016) have shown that following United States dietary guidelines for healthy weights would increase energy use by 38 percent, water use by 10 percent and GHG emissions by 6 percent::p.87" : [Food_Security]
}

add_annots_from_dict(FAO2016, FAO2016_annot)

FAO2016.add_to_excel("literature_annotation.xlsx")

# %%
Cibils2021 = Annotation()

Cibils2021.Title = "When land meets finance in Latin America: Some intersections between financialization and land grabbing in Argentina and Brazil"
Cibils2021.Citation =  "Garcia-Arias, J., Cibils, A., Costantino, A., Fernandes, V. B., & Fernández-Huerga, E. (2021). When land meets finance in Latin America: Some intersections between financialization and land grabbing in Argentina and Brazil. Sustainability, 13(14), 8084."
Cibils2021.In_Text_Citation = "Cibils, 2021"

Cibils2021_annot = {
"accumulation by dispossession::p.1" : [Agro_econ, History, Land_Consolidation],
"finance-dominated regime of accumulation as a response to the fall in productivity of the late 1960s::p.5" : [History],
"financial liberalization and financialization have resulted in a series of profound changes, both globally and locally::p.5" : [History],
"This center/periphery financialization model implemented in Brazil required, in order to attract permanent foreign capital flows to a country:.p.8" : [Agro_econ, Agro_international],
"financial speculation in commodities::p.10" : [Agro_econ, Food_Sovereignty],
"As a result, flex-crops incentivize megamergers to achieve economies of scale and thus satisfy investor profit expectations::p.10" : [Agro_tech, Big_agro],
"large-scale acquisitions, as a speculative asset has a long history in many Latin American countries. Certainly, this is the case in Brazil, where land grabs date back to the colonial period [82,84]. Similar arguments could be made in the case of Argentina, where large tracts of land were given to army officers as a reward for pushing back and defeating the indigenous populations::p.11" : [Agro_policy, History, Land_Consolidation],
"Furthermore, in five countries of the region (Brazil, Argentina, Paraguay, Bolivia and Uruguay) the focus of land concentration and foreign capital mainly revolves around the cultivation of oilseeds, especially soybean::p.13" : [Agro_econ, Agro_international],
"‘silent exclusion’ was forced by neoliberal policies: economic opening, deregulation of agriculture and poor market conditions (in terms of prices, interest rates, exchange rates). Many small and medium-sized producers were forced to abandon::p.17" : [Agro_econ, Small_holder],
"Argentina’s economic crisis—which was particularly severe on medium and small producers—and the subsequent devaluation of the peso in 2002, which explains the massive arrival of land investments due to the cheapening of domestic assets::p.17" : [Agro_econ, Deruralization, Rural_Livelihood],
"Another evidence of the size of foreign investment funds operation in the Brazilian farmland market [144] maps 423 thousand hectares of deforestation linked to foreign investors since 2000 in the Cerrado (Matopiba region)::p.25" : [Agroecology, History],
"In Argentina, even before the 2002 peso devaluation, many peasants indebted by such neoliberal policies were forced to abandon or hand over their land to banks::p.30" : [Debt, Deruralization]
}

add_annots_from_dict(Cibils2021, Cibils2021_annot)

Cibils2021.add_to_excel("literature_annotation.xlsx")

# %%
#EnsorHoddy2018 = Annotation()

#EnsorHoddy2018.Title = 
#EnsorHoddy2018.Citation = "Hoddy, E. T., & Ensor, J. E. (2018). Brazil's landless movement and rights' from below'. Journal of rural studies, 63, 74-82."

# %%
Chen2021 = Annotation()

Chen2021.Title = "Should policy makers trust composite indices? A commentary on the pitfalls of inappropriate indices for policy formation"
Chen2021.Citation = "Kaiser, M., Chen, A. T. Y., & Gluckman, P. (2021). Should policy makers trust composite indices? A commentary on the pitfalls of inappropriate indices for policy formation. Health research policy and systems, 19, 1-11."
Chen2021.In_Text_Citation = "Chen et al., 2021"

Chen2021_annot = {
"we can see how the GHSI ranked countries into three levels of preparedness::p.2" : [Methodology],
"ranking countries based on weighted scores across indicators that are scored variably and are not directly comparable with one another is problematic::p.4" : [Methodology],
"According to Mazziotta and Pareto [8] the following decision steps are crucial 1-Defining the problem 2-Selecting a group of individual indicators 3-Normalizing the selected indicators 4-Aggregating the normalized indicators::p.4" : [Methodology],
"Most commonly this could be done by using weighted arithmetic mean values, but since this can imply that bad performance on one indicator can be countered by sufficiently good performance on others, it may not be adequate for what we want to measure in the combined index::p.5" : [Methodology],
"they communicate easily to decision makers::p.5" : [Methodology],
"A case in point is the Human Development Index [15], for which there has been wide agreement on the basic three individual indicators. In the case of the GHSI, biological preparedness was broken down into six categories with 34 indicators and 85 sub-indicators::p.6" : [Methodology],
"However, in times of an imminent crisis one must assume that each crisis provides its own complex challenges::p.6" : [Buyuksehir_Law, Methodology],
"It has also been pointed out in areas outside of health that composite indices may be misleading and may hide important information in some of its elements::p.7" : [Methodology],
"all modelling it is widely recognized that there is trade-off between precision and complexity::p.7" : [Methodology]
}

add_annots_from_dict(Chen2021, Chen2021_annot)

Chen2021.add_to_excel("literature_annotation.xlsx")

# %%
Levidow2015 = Annotation()

Levidow2015.Title = "European transitions towards a corporate-environmental food regime: Agroecological incorporation or contestation?"
Levidow2015.Citation = "Levidow, L. (2015). European transitions towards a corporate-environmental food regime: Agroecological incorporation or contestation?. Journal of Rural Studies, 40, 76-89."
Levidow2015.In_Text_Citation = "Levidow, 2015"

Levidow2015_annot = {
"agendas for a European bioeconomy, featuring Life Sciences versus agroecology. Those agendas advocate different policy frameworks to transform agriculture and society::p.77" : [Agro_tech, Agroecology],
"In the global South ‘agroecology’ has been adopted as a political agenda, explicitly dissociated from organic food as an elite market sector. In Europe, by contrast, the organic sector is seen as central for elaborating agroecological methods which have wider relevance::p.77" : [Agroecology],
"As recast by the Life Sciences agenda, however, ‘bioeconomy’ has meant instead that biological material becomes a more flexible raw material for global value chains::p.81" : [Agro_econ]
}

add_annots_from_dict(Levidow2015, Levidow2015_annot)

Levidow2015.add_to_excel("literature_annotation.xlsx")

# %%
Louis2015 = Annotation()

Louis2015.Title = "We Plant Only Cotton to Maximize Our Earnings”: The Paradox of Food Sovereignty in Rural Telengana, India"
Louis2015.Citation = "Louis, E. (2015). “We Plant Only Cotton to Maximize Our Earnings”: The Paradox of Food Sovereignty in Rural Telengana, India. The Professional Geographer, 67(4), 586-594."
Louis2015.In_Text_Citation = "Louis, 2015"

Louis2015_annot = {
"The Telengana region has experienced high levels of agrarian distress, especially after India introduced neoliberal economic policies in the 1990s::p.586" : [History],
"It distinguishes itself from the productivist food security paradigm that emerged after World War II as a state-sponsored strategy to increase food production to achieve food self-sufficiency, revive economies, and increase political legitimacy::p.586" : [Food_Security, Food_Sovereignty],
"The ideological basis of food sovereignty implies control and autonomy over the food system, something that is not addressed by food security paradigms::p.587" : [Food_Sovereignty],
"deployed food sovereignty to oppose the General Agreement on Trade and Tariffs (GATT)::p.587" : [Food_Sovereignty, History],
"“Traditional crops are not being cultivated as much because with a crop like cotton one can make twenty to thirty thousand rupees in profit as opposed to very low profits from traditional crops::p.590" : [Agro_econ, Food_Sovereignty],
"we do not have enough cash to educate our children, for marriages, sickness, and so on::p.590" : [Rural_Family],
"Of the 150 households surveyed, 50 percent borrowed money for costs of cultivation (including leasing land and sinking borewells), about 40 percent for marriages and other ceremonies, 30 percent for housing construction, and 25 percent for education and health::p.590" : [Debt, Methodology],
"absolute dominance of private actors in the seed sector. Farmers complained that the state had abdicated its role in providing the research and extension support::p.590" : [Agro_policy, Big_agro]
}

add_annots_from_dict(Louis2015, Louis2015_annot)

Louis2015.add_to_excel("literature_annotation.xlsx")

# %%
Ali2023 = Annotation()

Ali2023.Title = "A systematic literature review of indicators measuring food security"
Ali2023.Citation = "Manikas, I., Ali, B. M., & Sundarakani, B. (2023). A systematic literature review of indicators measuring food security. Agriculture & food security, 12(1), 10."
Ali2023.In_Text_Citation = "Ali et al., 2023"

Ali2023_annot = {
"four food security dimensions [5]: availability, access, utilisation, and stability::p.1" : [Food_Security],
"food security measurement poses two fundamental yet distinct problems [8]: determining what is being measured and how it is measured::p.2" : [Food_Security, Food_Sovereignty, Methodology],
"Third, some indicators are quantitative, whereas others are qualitative measures based on individuals’ perceptions::p.2" : [Methodology],
"As we noted above, an ideal food security indicator should capture all the four food security dimensions at individual level to reflect the 1996 World Food Summit definition of food security::p.13" : [Methodology],
"Koren and Bagozzi [48] used per capita cropland as a food security measure, which is not a valid indicator for the multidimensional food security concept::p.13" : [Food_Security, Food_Sovereignty, Methodology],
"quantity and quality components of food security, whereas the food safety and preference/cultural acceptability components were rarely captured during food security measurements::p.20" : [Food_Security, Food_Sovereignty],
"Proteus Composite Index (PCI) for measuring food security at national level::p.23" : [Food_Security],
"effects of resilience capacity in reducing the effect of shocks on household food security using HHS and FAQ. The results of their fixed effect panel data model showed that resilience capacity enhancing attributes such as household assets, human capital, social capital, information access, women empowerment, diversity of livelihood, safety nets, and market access reduce the negative effect of flooding on household food security::p.25" : [Food_Security, Food_Sovereignty],
"their own sets of food security indicators (e.g. World Food Programme: FCS, USAID: HFIAS; FAO: POU and FIES; and EIU: GFSI::p.25" : [Food_Security, Methodology],
"(sustainability and agency) to improve the framework of food security analyses. Therefore, we recommend future research to operationalize literature reviews according to the six food security dimensions (i.e. availability, access, utilisation, stability, sustainability and agency)::p.28" : [Food_Security, Food_Sovereignty, Methodology],
"household-level calorie adequacy measure was the most frequently used indicator in the literature as a sole measure of food security. Dietary diversity indicators (HDDS, WDDS, IDDS, and FCS) and experience-based indicators (HFSSM, FIES, HFIAS, HHS, ELCSA) were almost equally in use and popular. In terms of the food security dimensions, food utilisation (13%) and stability (18%) were seldom captured::p.28" : [Food_Security, Methodology]
}

add_annots_from_dict(Ali2023, Ali2023_annot)

Ali2023.add_to_excel("literature_annotation.xlsx")

# %% [markdown]
# ### Corresponging author needs check before here

# %%
Menavasconez2016 = Annotation()

Menavasconez2016.Title = "Food or flowers? Contested transformations of community food security and water use priorities under new legal and market regimes in Ecuador's highlands"
Menavasconez2016.Citation = "Mena-Vásconez, P., Boelens, R., & Vos, J. (2016). Food or flowers? Contested transformations of community food security and water use priorities under new legal and market regimes in Ecuador's highlands. Journal of Rural Studies, 44, 227-238."
Menavasconez2016.In_Text_Citation = "Mena-Vasconez et al., 2016"

Menavasconez2016_annot = {
"Aside from pollution and health problems (e.g., Breilh, 2007), water over-extraction and large water demands by a (flowergrowing) minority generate tensions inside communities::p.228" : [Agro_econ, Agroecology, Food_Sovereignty],
"Community’-‘market’ dealings are mutual but not equivalent: they are grounded in unequal powers and continuous extraction of peasants' resources::p.229" : [Agro_econ, Small_holder],
"I have many loans to pay. In total around 75,000 dollars. And I have to pay the breeder's rights, one dollar per plant. I have 40,000 plants, so ... Damn, how do I pay that?!” This also jeopardized the entire production process::p.233" : [Debt, Small_holder],
"One could be her brother, who started his own greenhouse beside Ana's. But, in general, intra-family relations had come under great stress after the transformation. Ana: “Since I told my father that I started a greenhouse, it seems he makes a distinction in our family::p.233" : [Gender, Rural_Family],
"Some had drilled wells to mix aquifer water with acequia water. This extraction at the expense of minifundio subsistence agriculture generated major conflicts in the watershed::p.234" : [Agroecology, Food_Sovereignty],
}

add_annots_from_dict(Menavasconez2016, Menavasconez2016_annot)

Menavasconez2016.add_to_excel("literature_annotation.xlsx")

# %%
RobaeyTimmermann2016 = Annotation()

RobaeyTimmermann2016.Title = "Agrobiodiversity under different property regimes"
RobaeyTimmermann2016.Citation = "Timmermann, C., & Robaey, Z. (2016). Agrobiodiversity under different property regimes. Journal of Agricultural and Environmental Ethics, 29, 285-303."
RobaeyTimmermann2016.In_Text_Citation = "Robaey & Timmermann, 2016"

RobaeyTimmermann2016_annot = {
"It is estimated that of the over 7000 species of food crops under cultivation, only 103 species are used to secure over 90 % of the global food production::p.285" : [Big_agro, Seed],
"Third, the boundaries between wild, semi-wild and domesticated varieties are far from sharp::p.286" : [Monoculture_Poli],
"Biodiversity in general is not only a mere resource, but holds for many cultures and worldviews, intrinsic values which are not compatible with monetary valuation::p.288" : [Agroecology, Food_Sovereignty],
"Therefore, the number of crop varieties available in the public domain shrinks when people are inadequately incentivized to contribute to the common pool::p.289" : [Agro_policy, Seed],
"Extensive monocultures are already a major socioecological problem, especially taking the wide dominance of genetically-modified soy in South America::p.290" : [Monoculture],
"Those who do not establish and follow regulation on the sustainable use of the commons contribute to essentially aggregative harm: genetic erosion. Seed producers and land owners thereby acquire the responsibility that the seed types they sell or plant do not become so dominant::p.293" : [Agro_policy, Seed],
"Hardin’s (1968) pasture, an open access regime that allows cattle holders unrestricted use with the likely negative effect of deterioration of the resource held in common. In order to counter deterioration a number of resources are subject to usage restriction, changing access restriction from openness to specific community membership (Klink 1991), as we will discuss in the next section under commons::p.294" : [Agro_policy, Buyuksehir_Law],
"Such regulated efforts can thrive along a competitive seed industry characterized by polycentric decision-making. However, we have largely lost this institutional diversity due to enormous concentration within the seed industry and food retailers::p.230" : [Autonomy, Food_Sovereignty, Seed]
}

add_annots_from_dict(RobaeyTimmermann2016, RobaeyTimmermann2016_annot)

RobaeyTimmermann2016.add_to_excel("literature_annotation.xlsx")

# %%
HillWald2016 = Annotation()


HillWald2016.Title = "Rescaling’alternative food systems: from food security to food sovereignty"
HillWald2016.Citation = "Wald, N., & Hill, D. P. (2016). ‘Rescaling’alternative food systems: from food security to food sovereignty. Agriculture and Human Values, 33, 203-213."
HillWald2016.In_Text_Citation = "Hill & Wald, 2016"

HillWald2016_annot = {
"Over the last 20 years a large body of literature has developed on alternative food networks. Such networks are understood to be different from dominating ‘mainstream’ food systems, characterised by industrialised modes of producing and processing food, based on efficiency maximisation through large or global scale systems of finance, distribution and governance::p.205" : [Food_Network, Shortfood, Small_holder],
"AFNs include a myriad of activities along the different stages of the food chain, from production through distribution and to retail. To name but a few, these include farmers’ markets, community gardens and food cooperatives::p.205" : [Collectives, Cooperatives],
"A focal feature of AFNs, and especially within activist discourse, has often been their ‘local’ affixation (Goodman et al. 2012). Therefore, AFNs are conventionally perceived as ‘local food networks’ (LFNs)::p.206" : [Food_Network, Shortfood],
"Edelman (2014) argues that contrary to common belief, La Vı ́a Campesina did not coin the term ‘food sovereignty’ in 1996. Rather, at that time this term had already been used for more than a decade. Edelman traces the genealogical origin of this term back to a national food programme of the Mexican government in 1983::p.207" : [Food_Sovereignty, History],
"In its 1996 articulation, La Vı ́a Campesina perceived food sovereignty as a ‘precondition to genuine food security::p.208" : [Food_Security, Food_Sovereignty] 
}

add_annots_from_dict(HillWald2016, HillWald2016_annot)

HillWald2016.add_to_excel("literature_annotation.xlsx")

# %%
Wattnem2016 = Annotation()

Wattnem2016.Title = "Seed laws, certification and standardization: outlawing informal seed systems in the Global South"
Wattnem2016.Citation = "Wattnem, T. (2016). Seed laws, certification and standardization: outlawing informal seed systems in the Global South. The Journal of Peasant Studies, 43(4), 850-867."
Wattnem2016.In_Text_Citation = "Wattnem, 2016"

Wattnem2016_annot = {
"Until about a century ago, most people thought of seeds as a public good, as the common heritage::p.850" : [History, Seed],
"protecting’ of germplasm via mechanisms such as plant breeders’ rights (PBR). Together, these biological and political changes have set the stage for the possibility of commodifying and monopolizing seeds::p.851" : [Big_agro, Seed],
"It is now estimated that ‘ten companies account for about two-thirds (65 percent) of the world’s proprietary seed – that is, branded varieties subject to intellectual property protections – for major crops::p.852" : [Big_agro, Seed],
"PR laws applicable to germplasm that authorize and legitimize its privatization through mechanisms such as plant variety protection acts, PBR, ‘sui generis systems’, or patent laws for living materials. 2. Non-IPR seed laws that oblige farmers, breeders and seed companies to certify and/ or register seeds according to pre-established standards, usually for marketing::p.854" : [Agro_policy, Seed, Small_holder],
"As of 2013, however, 12 Latin American countries were officially members of UPOV, and some of them were trying to implement rules from UPOV 1991, restricting seed saving and exchange to unprecedented degrees::p.856" : [Agro_policy, Food_Sovereignty, Seed],
"Even though informal seed systems and the commercialization of non-homogeneous varieties are legal in the United States, the political economy of agriculture is such that, as in Europe, they are not as widespread as they could – or perhaps – should be, if the preservation of biodiversity were a serious objective::p.858" : [Agroecology, Food_Network, Seed],
"The contemporary politics of seed in Colombia is one of the most dramatic and controversial examples of the attempt to outlaw farmers’ seed systems, and of resistance to the imposition of legislation that does so.... The introduction of this decree coincided with the negotiations that preceded the signing of the Free Trade Agreement with the United States, in which Colombia agreed to undertake several legal reforms that would bring the country in line with international agribusiness expectations and standards::p.861" : [Agro_international, Agro_policy, Seed],
"If it is illegal to commercialize uncertified seeds, then the exchange of many local varieties is effectively forbidden::p.861" : [Agro_policy, Food_Sovereignty, Seed]
}

add_annots_from_dict(Wattnem2016, Wattnem2016_annot)

Wattnem2016.add_to_excel("literature_annotation.xlsx")

# %%
DagnesBarbera2016 = Annotation()



DagnesBarbera2016.Title = "Building Alternatives from the Bottom-up: The Case of Alternative Food Networks"
DagnesBarbera2016.Citation = "Barbera, F., & Dagnes, J. (2016). Building alternatives from the bottom-up: the case of alternative food networks. Agriculture and agricultural science procedia, 8, 324-331."
DagnesBarbera2016.In_Text_Citation = "Dagnes & Barbera, 2016"

DagnesBarbera2016_annot = {
"The term AFNs is usually used for grassroots experiments in re-organising a portion of the agri-food sector, in accordance with some ethical and moral principles::p.325" : [Collectives, Cooperatives, Food_Network],
"AFNs share the characteristic of being self-organized, with a central role of local individual actors::p.325" : [Autonomy, Food_Network],
"AFNs are often regionally embedded, with circuits of production and consumption organised locally and independently (Dansero and Puttilli 2014). The Italian context is particularly interesting also because it combines some innovative practices related to the agri-food sector (for instance, box schemes, community-supported agriculture, solidarity-based purchasing groups) with the renovation and the reinterpretation of some traditional supply forms, such as some kinds of on-farm and off-farm direct sales::p.326" : [Collectives, Food_Network, Shortfood],
"Coldiretti and Confederazione Italiana Agricoltori. Their local branches in Piemonte are active in promoting initiatives related to the regional food culture, both in terms of educational projects in schools and farmers’ markets to foster direct sales. There are also numerous associations on a territorial scale, bringing together the farmers located in the same area and/or cultivating the same specific product::p.327" : [Autonomy, Collectives, Education],
"From a spatial point of view, this means that the AFNs are distributed within the territory and easily reachable by the people who want to use them::p.327" : [Shortfood],
"both the production economy and ecology depend on the number of produced items (Schlich and Fleissner 2005). Preliminary data on the AFNs in Piemonte highlights that also in this case, the environmental impact of the AFNs can be higher than the conventional supply chain (Peano et al. 2015). This depends, among other elements, on the different packaging used (paradoxically the wooden crates, used by the farmers, have a shorter operating time and a greater environmental impact than the plastic packaging adopted by the supermarkets), and on the transport logistic (for instance, farmers directly selling in local markets or farmers markets drive 28 km on average, often with highly polluting vehicles::p.328" : [Agroecology, Collectives, Shortfood],
"a unitary idea of the hard quality prevails, while multiple conceptions about the soft quality take shape::p.330" : [Agro_econ]
}

add_annots_from_dict(DagnesBarbera2016, DagnesBarbera2016_annot)

DagnesBarbera2016.add_to_excel("literature_annotation.xlsx")

# %%
Dunford2015 = Annotation()


Dunford2015.Title = "Peasant activism and the rise of food sovereignty: Decolonising and democratising norm diffusion?"
Dunford2015.Citation = ""
Dunford2015.In_Text_Citation = "Dunford, 2015"


Dunford2015_annot = {
"suggesting that elite agents may be marginalising the influence of Southern and grassroots voices by prompting changes to the meaning of food sovereignty::p.2" : [Agro_international, Food_Security, Food_Sovereignty],
"Agricultural modernisation between 1964 and 1985 in Brazil, for instance, had ‘devastating social effects’, including increasing land inequality and mass migration from rural areas into urban slums::p.6" : [History, Migration],
"The term ‘food sovereignty’ had been used to mean something akin to national food security or food self-sufficiency in a Mexican government programme in the early 1980s::p.7" : [Food_Sovereignty, History],
"First, food sovereignty makes environmentally friendly and autonomous smallholder production central, demanding not only access to or a right to food, but also rights to territory and agricultural inputs, including seeds::p.12" : [Agroecology, Food_Sovereignty],
"Finally, where the right to food focuses on protecting individuals, food sovereignty is a fundamentally collective right providing shared access to and shared use of resources within a territory::p.12" : [Agro_policy, Food_Sovereignty]
}

add_annots_from_dict(Dunford2015, Dunford2015_annot)

Dunford2015.add_to_excel("literature_annotation.xlsx")

# %%
Schiavoni2015 = Annotation()

Schiavoni2015.Title = "Competing Sovereignties, Contested Processes: Insights from the Venezuelan Food Sovereignty Experiment"
Schiavoni2015.Citation = "Christina M. Schiavoni (2015) Competing Sovereignties, Contested Processes: Insights from the Venezuelan Food Sovereignty Experiment, Globalizations, 12:4, 466-480,"
Schiavoni2015.In_Text_Citation = "Schiavoni, 2015"

Schiavoni2015_annot = {
"competing sovereignties’ are shaping the political construction of food sovereignty through the three interconnected analytical lenses of scale, geography, and institutions::p.468" : [Food_Sovereignty, Methodology],
"Among the outputs were the following six pillars of food sovereignty (Nye ́le ́ni,2007b): I. Focuses on Food for People II. Values Food Providers III. Localises Food Systems IV. Puts Food Locally V. Builds Knowledge and Skills VI. Works with Nature::p.471" : [Food_Sovereignty],
"This question brings us to ‘competing sovereignties’ around scale::p.471" : [Food_Sovereignty],
"a lack of consistency in the use of the term ‘scale’ in reference to food sovereignty::p.471" : [Food_Sovereignty, Methodology],
"proponents of food sovereignty is how it translates over to non-agrarian contexts. That is, how relevant is food sovereignty to the broader nonfarming population, particularly the more than 50% of the global population (and growing) that lives in cities::p.473" : [Food_Sovereignty],
"nutritional needs are met despite the shortages indicates that Venezuela has reached a certain level of food security, but is still far from food sovereignty::p.474" : [Food_Security, Food_Sovereignty],
"A burning question that remains, looking at Venezuela, is the extent to which newly emerging grassroots-led food sovereignty efforts and already existing food security efforts will coexist, clash, or complement one another::p.478" : [Agro_policy, Food_Security, Food_Sovereignty]
}

add_annots_from_dict(Schiavoni2015, Schiavoni2015_annot)

Schiavoni2015.add_to_excel("literature_annotation.xlsx")

# %%
Bauluz2020 = Annotation()

Bauluz2020.Title = "Global Land Inequality"
Bauluz2020.Citation = ""
Bauluz2020.In_Text_Citation = "Bauluz et al., 2020"

Bauluz2020_annot = {
"South Asia and Latin America exhibit the highest inequality with top 10% landowners capturing up to 75% of agricultural land, followed by Africa and ‘Communist’ Asia (China and Vietnam) at levels around 55-60%::p.0" : [Food_Sovereignty, Small_holder],
"Despite the importance of land for the world poor, we know almost nothing about its value and distribution, since the existing estimates neither reflect land ownership inequality nor value inequality and do not account for the landless population::p.1" : [Food_Sovereignty, Rural_Livelihood],
"Operational holdings are economic units of agricultural production under single management (FAO, 2018). Hence, these estimates pose serious conceptual challenges for measuring land ownership inequality since they do not capture the ownership of land holdings nor do they account for differences in the value of land (e.g. due to soil quality or location)::p.2" : [Methodology],
"estimates of land Gini coefficients::p.4" : [Methodology],
"the implicit assumption behind such a proxy for landless household is that each agricultural holding has a single owner::p.5" : [Food_Network],
"At the moment, we do not include communal land in our definition of ownership but we plan to investigate it in future versions of the paper, as it plays a relevant role in certain countries (e.g. in Africa or Latin America)::p.8" : [Food_Sovereignty, Methodology],
"Gini coefficient and land shares (i.e. the percentage of the land owned by a population group such as top 10%, middle 40% or bottom 50%)::p.8" : [Methodology],
"Importantly, the results indicate that land-value inequality can be significantly different from the land-area inequality::p.11" : [Agro_econ, Food_Security, Food_Sovereignty, Methodology]
}

add_annots_from_dict(Bauluz2020, Bauluz2020_annot)

Bauluz2020.add_to_excel("literature_annotation.xlsx")

# %%
Ziegler2004 = Annotation()

Ziegler2004.Title = "ECONOMIC, SOCIAL AND CULTURAL RIGHTS The right to food"
Ziegler2004.Citation = ""
Ziegler2004.In_Text_Citation = ""

Ziegler2004_annot = {
"progress in reducing hunger and malnutrition has virtually come to a halt::p.2" : [Food_Security],
"He looks at the reasons why international trade in food and agriculture is not necessarily benefiting the vast majority of the poor and marginalized people, but rather creating even greater marginalization and inequality. He examines the negative impacts of the current imbalances and inequities in the global trading rules under the World Trade Organization::p.2" : [Food_Security, Food_Sovereignty],
"Many observers suggest that the main reason for this was the intransigence and double standards of the developed countries of the North on the question of agriculture and food security, and the failure of the WTO Agreement on Agriculture to meet the needs of the poorer, developing countries to ensure their own food security::p.7" : [Agro_international, Food_Security, Food_Sovereignty],
"developed countries (with the notable exception of Australia) continue to protect agriculture as a question of national security, food security or multifunctionality, many of the poorest developing countries are left at a severe disadvantage, as they cannot afford to subsidize their agriculture, but must reduce tariffs and open up to unfair competition from subsidized products of the developed countries::p.8" : [Agro_econ, Food_Sovereignty, Food_Security],
"Food sovereignty means the primacy of people’s and community’s rights to food and food production, over trade concerns. This entails the support and promotion of local markets and producers over production for export and food imports::p.10" : [Food_Network, Food_Sovereignty, Small_holder],
"The Norwegian proposal for example, suggests that “every country should be granted flexibility in national policy design to foster domestic agricultural production necessary to address domestic non-trade concerns::p.11" : [Agro_international, Agro_policy, Food_Security],
"dumping of imported, subsidized food in local markets which destroys local farmers::p.11" : [Food_Sovereignty],
"Just 10 corporations (which include Aventis, Monsanto, Pioneer and Syngenta) control one-third of the US$ 23 billion commercial seed market and 80 per cent of the US$ 28 billion global pesticide market.29 Monsanto alone controls 91 per cent of the global market for genetically modified seed::p.14" : [Big_agro, Food_Security, Food_Sovereignty],
"AO Assistant Director General Louise Fresco revealed recently that 85 per cent of all plantings of transgenic crops are soybean, maize and cotton, modified to reduce input and labour costs for large-scale production systems, but not designed “to feed the world or increase food quality::p.14" : [Food_Security],
"A marked paradigm shift has occurred from a system seeking to foster food security on the basis of the free exchange of knowledge, to a system seeking to achieve the same goal on the basis of the private appropriation of knowledge. Monsanto has recently filed 475 lawsuits against farmers. One particular case has caught the headlines::p.14" : [Food_Sovereignty, Seed],
"There is also the growing power of transnational corporations over the supply of water, as this is increasingly liberalized across the world. The privatization of water services::p.15" : [Agroecology, Big_agro, Food_Sovereignty],
"The growing power of transnational corporations and their extension of power through privatization, deregulation and the rolling back of the State, also means that it is now time to develop binding legal norms that hold corporations to human rights standards::p.19" : [Agro_policy, Big_agro, Rural_Livelihood],
}

add_annots_from_dict(Ziegler2004, Ziegler2004_annot)

Ziegler2004.add_to_excel("literature_annotation.xlsx")

# %%
CetinOzturk2023 = Annotation() # Example Usage
# Create the annotation class


# Add references with functions
CetinOzturk2023.Title = "Agriculture and Food Problems and Solutions: Challenges and Capacity of the Capitalist System in the Twenty-First Century"
CetinOzturk2023.Citation = "Çetin, M., Öztürk, M. (2023). Agriculture and Food Problems and Solutions: Challenges and Capacity of the Capitalist System in the Twenty-First Century. In: Ari, A. (eds) Capitalism at a Crossroads. Springer Studies in Alternative Economics. Springer, Cham. https://doi.org/10.1007/978-3-031-23257-2_4"
CetinOzturk2023.In_Text_Citation = "Çetin & Öztürk, 2023"

# Combine all annotations with their chosen categories
CetinOzturk2023_annot = {"First, they use natural sources converted into food, foodstuffs, and other products. Thus, agro-food economies have established a reciprocal bond with nature and society::p.59": [Agroecology, Rural_Family],
    "Thus, farming implies a double exchange, an ecological exchange and an economic one, and these two need to be balanced carefully::p.59" : [Agro_econ, Agroecology],
    "Food production brings environmental costs involving land conversion and deforestation, topsoil and biodiversity loss, aquatic and terrestrial ecosystem pollution, water resource degradation, and the production of greenhouse gases (GHGs)::p.61" : [Agroecology],
    "agro-food system activities taken as a whole—agricultural production, transport, storage, processing, packaging, and retail along with food loss and waste have a huge impact on man’s contribution to atmospheric GHGagro-food system activities taken as a whole—agricultural production, transport, storage, processing, packaging, and retail along with food loss and waste have a huge impact on man’s contribution to atmospheric GHG::p.61" : [Agroecology, Food_Network],
    "Some 10% oftheworld population currentlylives incondition sofhunger. Basic needs arenotmetonamassive scale even though world food productionandcrop supplyhave more than tripled, andanimalproduction hasincreased 2.5-foldinthe recent past::p.62" : [Food_Network, Food_Security],
    "accumulation through dispossession::p.63" : [Agro_international, Deruralization, Rural_Family],
    "Giant transnational producers, such as Monsanto, Bayer, and Syngenta, have monopolistic power in the input markets::p64" : [Big_agro, Food_Sovereignty],
    "As can beseen in this example, the globalization of food trade and the intensification of trade dependency can reduce the resilience of the agro-food system because markets sporadically fail for a variety of economic and political reasons::p.64" : [Agro_econ, Autonomy, Food_Sovereignty],
    "Land acquisition investments lead to many problems, in developing countries particularly. Corporations may turn farmers into employees and increase their vulnerability to food price volatility::p.65" : [Agro_econ, Rural_Livelihood],
    "Contrary to the neoliberal promotion of free trade, market openness has not had a meaningful effect on food security (Dikshit & Gopinath, 2021). According to the advocates of free trade in agriculture and food, the efforts to protect small, local producers are barriers to trade that need to be eliminated. Therefore, the agreements made, and measures taken to curtail such supports benefit the multinational corporations that already dominate the world production and exchange of goods::p66" : [Big_agro, Food_Security, Small_holder],
    "it is apparent that we certainly cannot expect the benefits of biogenetics developments to be well shared, let alone fairly. In other words, we should not place much faith in the emerging future of the current system to deliver food security for all, with biotechnology offered as a promissory note, a Green Revolution-type silver bullet, which is already badly tarnished::p.71" : [Agro_econ, Food_Security],
    "The six pillars of food sovereignty listed by the European Coordination Via Campesina (2002) state that it 2022 Focuses on food for people. 2022 Values food providers. 2022 Localizes food systems. 2022 Puts control locally. 2022 Builds knowledge and skills. 2022 Works with nature::p.72" : [Food_Sovereignty],
    "Agroecology is effectively an efficiency in production, but for peoples’ movements and civil society organizations that are struggling for food sovereignty, its meaning is more inclusive::p.73" : [Agroecology, Food_Security, Food_Sovereignty]

        }

# Add annotations to the Annotation object    
add_annots_from_dict(CetinOzturk2023, CetinOzturk2023_annot)

# Add to excel
CetinOzturk2023.add_to_excel('literature_annotation.xlsx')
