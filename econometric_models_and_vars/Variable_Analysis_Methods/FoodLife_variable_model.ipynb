# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
variables_df = pd.read_excel("annots_variables_working.xlsx")

# %% [markdown]
# Here are the general 9 categories that I defined:
# - Economic conditions: Market values, costs, credits, interest and exchange rates
# - Ecological conditions: Climate conditions (humidity, water source, soil), land structure, vegetation
# - Land use: Land size, land fragmentation, land types
# - Policies: Financial support, social security, rural administration status
# - Rural development: Social facilities (school, health center, consultancy, infrastructure)
# - Rural life: Household structure, non-agricultural employment, migration, ethnic structure, gender equality
# - Agricultural diversity: Food and industrial agriculture, import-export balances, plant species
# - Agricultural ownership: Land ownership and farm scale, ratio of local/foreign inputs
# - Agricultural development: Cooperativization, mechanization, capitalization, networks
#
#
# After an analysis of the initially tagged variables, here are simplified numbers for categories:
# - Land Use             18
# - Governance           19
# - Ecology              14
# - Market               13
# - Household            10
# - Rural Development   7
# - Crop Type            8
# - Costs                8
# - Finance              10
# - Demography           5
# - Water                 6
# - Land Security         6
# - Autonomy              5
# - Regional              7
# - Network               5
# - Agroecology          6
# - Scale                 4
# - Spatial               4
# - Tech Capital         5
# - Food Sovereignty      4
# - Cooperative           6
# - Husbandry             3
# - Seed Sovereignty      3
# - Farmer Dynamics       3
# - Ethnicity             2
# - Gender                1
# - Income                1

# %%
print("Total number of variable categories:", variables_df["FSoI_Class"].nunique())
print("Total number of articles:", variables_df["Title"].nunique())

# %matplotlib inline
plt.figure(figsize=(10,6))
variables_df['FSoI_Class'].value_counts(sort=True).plot(kind='bar')
plt.xticks(fontsize=9, rotation=90)
plt.show()
# Out:
# Total number of variable categories: 28
# Total number of articles: 40

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Land Use"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

#Ekilebilir tarım arazisi - tarım dışı arazi
#Tarım arazisi (Ekili arazi, Nadasa bırakılan arazi, ekilmeyen arazi) = işlenebilir arazi
#Tarım yapılabilen tipe göre arazi (arazi düzlüğü)
#Ekilebilir tarım arazisi değişimi (yapılaşma)
#şehirleşme modeli (saçaklanma, yayılma, sıçrama) ve hızı
#toplu tarım arazileri sayısı (havza yönetimi)
#toprağın sahibinin yaşadığı yer
#toprağın elastisitesi
#ortalama parsel büyüklüğü (şehirler için? ülke geneli? kişi başı veya arazi  başı?)
#parsel büyüklüğü değişimi (fragmentation)
#Land Use (crop type) tahıl ekilen alan::p.20
#Land Use(ecology) APTS çalışmaları kapsamında kullanılan arazi kullanımı / örtüsü sınıflandırma sistemleri, tarım arazilerinin anlaşılması için gereken detaylı toprak sınıflaması anlayışından uzaktır::p.211
#Land Use (crop type) “5403AraziTuru” kod listesi ile betimlenen “tur” özniteliğidir. Bu öznitelik aslında, elde edilen diğer veriler aracılığıyla karar verilen sınıflandırma sonucu olup, arazinin mutlak, marjinal, örtü altı, dikili ya da özel ürün tarım arazisi olması arazi kullanım planlaması kararlarını doğrudan etkilemektedir::p.215
#Arazi sahipliğinin karmaşıklığı? ortak arazi kullanımı?
#Arazilerin tapu'ya kayıtlılık durumu
#CATAK destekleme kategorisi
#Gıda Sertifikası
#Bitkisel ürün tipine göre tarım arazisi büyüklüğü, oranları (crop type?)
# Out:
# Land Use nadasa bırakılan arazilerde yıllar itibariyle azalma görülmesine rağmen ekilen araziler her yıl azalmaktadı::p.373
# Land Use 5 milyar hektarını tar ım arazileri oluşturmaktadır::p.373
# Land Use İşlemeli Tarıma Uygun Araziler::p.373
# Land Use 21,4 milyon hektarı işlenen tarım arazisi olup::p.374
# Land Use tarım arazileri üzerindeki yapılaşma::p.376
# Land Use konut yapmak için yeterli alan olmadığından::p.379
# Land Use arasındakini değişimini yorumlayabilmek adına 1990-2000-2006-2012 ve 2019 yılları arazi kullanım haritaları oluşturulurmuştur::p.3
# Land Use hangi yayılma modelinin (saçaklanma,yayılma, sıçrama)::p.6
# Land Use havza yönetimi::p.130
# Land Use Kentlerde yaşayan fakat köylerde toprağı olan ailelere ait toprakların, il kümeleri içindeki oransal önemi de benzer bir sıra izlemektedir::p.337
# Land Use farmers’ lagged land elasticities::p.12217
# ...

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Governance"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

 
# büyükşehir yasası sonrası değişimler (endogeneous variable)
# altyapı politikaları
# Ziraat Odası sayısı
# Kalkınma Ajansı sayısı
# köy envanteri kapsana alanı
# çiftçi destekleme politikaları (kimler için, kimler başvurmuş, süreklilik durumu nedir)
# ürün tipine göre tarımsal destek
# tarımsal üretim miktarı harici çiftçi destek politikaları (decoupled payments)
# tarımsal üretim miktarına göre destek politikaları (deficiency payments)
# arazi büyüklüğüne göre tarımsal destek politikaları (per hectare support)
# *tarımsal destek politikaları % döviz değişim değeri veya satın alma gücü*
# piyasa önlemlerine yönelik tarımsal politikalar, fiyat denetimleri
# tarımsal üretim sertifikasına göre destek politikaları
# bölgeye göre tarımsal destek politikalarının farklılığı (DGD, IPARD)
# tarımsal desteklerin bütçe içindeki payı
# belediyelerin tarımsal politikalara-üretime dahil olma durumu
# tarımsal kamu yönetimi kuruluşları
# kırsal alanın kurumsal tanımı
# tarımsal üretim harici tarımsal politikalar (teknolojik malzeme, gübre ve tohum, ihracat)
# Out:
# Governance büyükşehir hâline getirilmesi ile kırsal yerleşmeler sosyal, demografik ve ekonomik açıdan nasıl etkilenmiştir? Midyat kırsal yerleşmelerinde altyapı sorunlarının::p.138
# Governance alt yapı destekleme politikaları::p.86
# Governance İzmir ili ve ilçelerinde toplam 21 adet Ziraat Odası bulunmaktadır::p.196
# Governance Türkiye’de her bir NUTS 2 bölgesinde bir tane olacak şekilde 26 adet Kalkınma Ajansı faaliyet göstermektedir::p.202
# Governance 67 ile bağlı 35.640 köyü ve bucağı kapsamaktadır::p.327
# ...

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Ecology"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# mevsimlere ve aylara göre yağmurun dağılımı
# sel riski
# arazilerin yağış alma miktarı
# doğal kaynak potansiyeli?
# su kirliliği
# iklim şartları
# su kaynakları
# bitki örtüsü (yeşillik durumu)
# toprak tuzluluk miktarı
# toprak tipi-kalitesi
# erozyon riski durumu
# birinci sınıf arazi oranı
# 5403 sınıflandırma tipi
# ??sulu tarım susuz tarım
# Out:
# Ecology mevsimsel yağışlara::p.379
# Ecology sel baskını::p.379
# Ecology yağış alan arazilerin::p.140
# Ecology mevsim ve aylara göre günleri ve yağmurun dağılımını::p.137
# Ecology doğal kaynak potansiyelini::p.194
# Ecology Su kirliliği::p.149
# Ecology İklim, arazi yapısı, jeoloji, su kaynakları, bitki örtüsü::p.159
# Ecology soil salinity::p.12215
# Ecology weather::p.12212
# Ecology pest damage::p.12212
# Ecology soil analysis::p.207
# Ecology erozyon kontrolü::p.604
# Ecology su kaynaklarının korunması::p.604
# Ecology toprağın kalite, miktar ve niteliklerini::p.18
# Ecology iklim şartları::p.23
# Ecology birinci sınıf arazi oranı::p.342
# Ecology 5403 Sınıflandırma Veri Tipi ve Kapsadığı Kod Listeleri::p.216
# Ecology Kalker ve mermerlerden oluşan plato sahasında çok tipik olarak görülen ekilmeyen tarım alanlarında erozyonun şiddetine bağlı olarak yer yer ana kaya yüzeylenmiştir. Buna karşın sulu tarım alanlarında ve geniş vadi tabanlarında::p.172
# ...

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Market"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# tarımsal üretim miktarı değişimi (haneye veya işletmeye göre)
# tarımsal ürün arzı (yıllara göre)
# tarımsal ürünlerin fiyatları, fiyat esnekliği (yıllara göre)
# tarımsal girdi fiyatları (yıllara göre)
# tarımsal kredi performansı
# tarım sektörünün GSYİH-GSMH içindeki oranı
# (network veya autonomy) üreticilerin pazarlama gücü
# arazilerde ekili ürünlerin piyasayayla ilişkisi
# yıllar içinde görülen fiyat şokları
# çiftçilerin risk algısı ve risk tercihi
# çiftçilerin market algısına göre (fiyat tahmini) ürün ekimi
# tarımsal gelir miktarı değişimi (haneye veya işletmeye göre)
# Kırsal üretimde hayvansal-tarımsal üretim dağılımı
# Out:
# Market Tarımsal üretimdeki dalgalanmaya bağlı olarak, tarımsal gelir de dalgalanmaktadır::p.59
# Market Tarımsal ürün arzının fiyat esnekliği düşüktür::p.59
# Market Tarımsal girdi fiyatları, ürün fiyatlarına göre daha hızlı artmaktadır::p.59
# Market Tarımsal Kredi Performans Oranına Göre::p.63
# Market tarım sektörünün GSYİH’ ya katkısı %6,1::p.59
# Market pazarlama gücü::p.196
# Market production dynamics (lagged land variables) had a statistically significant impact on farmers’ land allocation decisions::p.12212
# Market extreme year for cotton producers, and we controlled that extremity by adding the year dummy::p.12214
# Market farmer’s risk preferences::p.12209
# Market The farmer forecasts the yield and prices after the harvest::p.12209
# Market tarımsal gelirde dalgalanmalar::p.23
# Market bitkisel ve hayvansal üretime ilişkin verim düzeyi::p.23
# ...

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Household"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# Reel index (CPI)
# Kırsal hanehalkı büyüklüğü
# Kırsal hanehalkı sosyo-ekonomik durumu
# Kırsal hanehalkı mesleki durumlar, tarım dışı gelir getirici faaliyetler
# Kırsal hanehalkı geçim durumu değişimi, geliri, alım gücü (yıllara göre)
# Hanedeki sigortalılık durumu, çiftçilerin sosyal güvencesi
# Hanehalkı demografik durumu (yaş, cinsiyet)
# Kırsal kesimde yoksulluk (bölge-şehir)
# Tarımsal istihdamın işteki durumu (yevmiyeli, kendi-ailesi adına, ticari üretim)
# Kırsal bölgede yaşayanların tarımsal üretime katılımı % bölgedeki tarımsal istihdam
# Out:
# Household Kırsal yaşamın kalabalık aile yapısı zamanla yerini daha az bireye sahip ailelere bırakmaya başlamıştır::p.143
# Household hanehalkı kümeleri::p.138
# Household meslek::p.138
# Household Geçim analizi İstikrar::p.137
# Household to real terms using TurkStat’s Producer Price Index::p.12208
# Household Sosyal güvenlik sahibi çiftçilerle sosyal güvencesi olmayanlar hemen hemen eşittir.::p.14
# Household Hane Başkanlarının Yaş ve Cinsiyeti::p.13
# Household Narman kırsalında tarımla uğraşan çiftçilerin genelde orta yaştaki kişilerden oluştuğu, gençlerin çiftçiliği tercih etmedikleri tespit edilmiştir.::p.16
# Household Aile Büyüklüğü::p.14
# Household gelir::p.14
# Household Kişi başına düşen gelir miktarı yönünden Güneydoğu Anadolu Bölgesi Türkiye'nin en düşük bölgelerinden biridir::p.341
# Household tarım kesiminde yoksulluk oranı::p.6
# Household tarımda istihdamın işteki durumu ile ilgili::p.38
# ...

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Rural Development"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# Sağlık ocağı, doktor vs. sağlık olanakları
# Kırsal bölgeye ulaşım hizmetleri
# Çöp toplama (hijyen)
# Okul bulunma durumu
# Tarımsal mesleki eğitim - kırsal danışmanlık ofisleri
# Altyapı ? (kanalizasyon)
# Tarımsal kayıtdışılık
# Out:
# Rural Development sağlık ocağı::p.377
# Rural Development Nüfusu az olan bu köylerin minibüsü olmadığından::p.145
# Rural Development Sağlık olanakları::p.146
# Rural Development çöp toplama::p.147
# Rural Development okulu bulunmayan köyler::p.156
# Rural Development Kapasite geliştirme::p.133
# Rural Development köy sağlığı teşviki::p.130
# Rural Development kent temizliği önlemleri::p.130
# Rural Development okul::p.137
# Rural Development insan kaynakları ve sosyal sermayenin geliştirilmesi::p.203
# Rural Development Eğitim Durumu::p.13
# Rural Development sağlık, eğitim ve altyapı::p.605
# Rural Development sektördeki kayıtdışılık::p.23
# Rural Development Kırsal alandaki eğitim ihtiyacının giderilmesi için gerekli yatırımların yapılması şarttır. Okuma-yazma ya da MEB müfredatı dışında tarımsal üretim, finansman, pazarlama ve yönetim ile ilgili temel eğitimlerin verilmesi gerekmektedir.... Ülkemizde tarım alanında meslek okulları vardır.::p.256
# ...

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Crop Type"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# Ticari değeri yüksek ürünler (High Value Crops)
# Girdisi yüksek ürünler (High barrier entry crops, mekanizasyon, gübre vs.)
# Hububat, Bakliyat, Sebze ve Meyve, Yağlı Yohumlar, Sanayi Bitkileri, Süs Bitkileri
# Depolanabilir ürünler
# Ürün tipine göre finansal verimlilik
# İhraç edilen türler, ithal edilen türler - Küresel geleneksel ihracat ürünleri
# Hasat sayısı, hasat süresi
# Tarımsal işçi emeği yoğun ürünler
# Out:
# Crop Type Fıstık üretiminin ticari anlamda önemli kazanç kaynağı olacağının düşünülmesi nedeniyle, son yıllarda insanların ilgisini çekmeye başlamıştır.::p.153
# Crop Type Fıstık üretiminin ticari anlamda önemli kazanç kaynağı olacağının düşünülmesi nedeniyle, son yıllarda insanların ilgisini çekmeye başlamıştır.::p.153
# Crop Type çeltik tarımı, çiftçileri diğer ürünlere kıyasla daha çok mekanizasyona, kredi kullanmaya ve tarımsal girdi kullanmaya yönlendirmektedir::p.143
# Crop Type Bu durum verim artışı ve bunu mümkün kılan tarımsal mekanizasyon, yeni tohum çeşitleri ve girdi kullanımıyla ifade edilebilir. Ancak bu durum tahıllar, yağlı tohumlar, sanayi bitkileri, baklagiller ve sebzemeyveler özelinde incelendiğinde ekili arazi ve üretime dair farklılıklar::p.142
# Crop Type depolanabilir ürünler::p.147
# Crop Type the total land area used for cotton farming::p.12207
# Crop Type Tahıl üretim ve verimliliği::p.20
# ...

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Costs"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# Akaryakıt fiyatı
# Tohumluk, fide, fidan ithalatı ve ihracatı, fiyatları
# Gayrimenkul yatırımı
# Gübre ve tarım ilacı kullanım miktarı
# Birim ürün maliyeti
# İşçi maliyeti
# Mekanizasyon maliyeti
# Girdi ihtiyaçlarının karşılanma menşeinin oranı
# Out:
# Costs akaryakıt::p.201
# Costs tohumluk, fide, fidan::p.201
# Costs Gayrimenkul yatırımları::p.204
# Costs 2011 yılında Türkiye’de 40.000 ton tarım ilacı kullanılmıştır. Türkiye’de %90’nı ithal olan tarım ilaçları pazarında % 20’lik pay Hektaş’a aittir::p.139
# Costs ürettiği ürünün satış fiyatının, ürün maliyetini karşılamadığını belirtmiştir.
# Costs fuel oil prices::p.12208
# Costs input usage::p.12210
# Costs gübre ve tarımsal ilaçların yanlış kullanımı::p.23
# Costs minimal labor::p.525
# Costs hammadde ihtiyaçlarını yerel kaynaklardan ne ölçüde elde edip edemedikleri::p.61
# Costs Akaryakıt satış fiyatı::p.29
# Costs 1970 yılında .. 2.2 milyon tonluk gübre tüketimi::p.30

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Finance"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])


# Tarımsal kredilere yönelik uygulamalar
# Tarımda kredi kullanımı oranı
# Tarımsal kredilerinin ürün tipine göre dağılımı
# Tarımsal kredi kullanımının bölgesel dağılımı
# Tarımsal kredi faiz oranları
# Mikro kredi kuruluşları
# Tarımda verimlilik oranı (faiz oranına göre)
# Tarımda sigortalılık durumu, sigorta kapsamı ve maliyeti
# Bütçede tarımsal desteğe ayrılan oran
# Tarımda vergilendirme durumu
# Out:
# Finance Bu bağlamda; tarım sektörünün finansmanı çok önemlidir. Ellis’e (1996) göre, tarımsal finansman politikalarının amaçları::p.59
# Finance Tarımsal krediler - kullanımı::p.60
# Finance Tarımsal Kredi Miktarına Göre Sıralama -  <<Bölü tarımsal üretim değerine göre sıralama>>::p.63
# Finance (ihtiyaç duymama), diğer bölgelerde yüksek faiz::p.65
# Finance daha düşük faizli kredi verebilmektedir::p.63
# Finance kredilerin geri ödeme süresi, teminat süresi:.p.64
# Finance mikro kredi kuruluşları::p.130
# Finance efficiency of farming::p.12214
# Finance Tarım sigortası ödemeleri::p.26
# Finance Buna karşın bütçeden faize aktarılan kaynak hızla artmış::p.5
# Finance taxation::p.320
# Finance tarım arazilerinin % 58'i sigortalanmıştır::p.256

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Demography"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# Kırsalda (reel) nüfus değişimi, kırsal nüfus yoğunluğu, kırsal alan tanımı
# Göç istatistikleri
# Kırsalda yaş dağılımı
# İstihdamın sektörel dağılımı
# Tarımda işsizlik ve toplam işsizlik (tarımda işsizlik nasıl ölçülür?)
# Out:
# Demography nüfus değişimi::p.137
# Demography tarımsal nüfus yoğunluğu::p.19
# Demography alınan göç, verilen göç ve net göç istatistiklerine::p.33
# Demography 15 yaş ve üstü nüfusun yıldan yıla artış göstererek, 2004 yılında 3.764.000 iken 2020 yılında 5.791.000’e ulaştığı görülmektedir::p.34
# Demography istihdamın sektörel dağılımında::p.35
# Demography OECD'ye göre kırsal alan, nüfus yoğunluğunun kilometre kare başına 150 kişinin altında olduğu yerlerdir.... OECD kırsal alan kavramını açıklarken 'kırsallığı baskın bölgeler', 'önemli ölçüde kırsal bölgeler' ve 'kentselliği baskın bölgeler olmak üzere 3'lü bir tasnif yapmıştır. Buna göre eğer nüfusun % 50'den fazlası kırsal kesimde ise kırsallığı baskın bölge, %15 ile % 50 arası ise önemli ölçüde kırsal bölge ve %15'ten az ise kentselliği baskın bölge olarak bir ayrım yapılmıştır::p.259
# Demography Kontrolsüz göçün durdurulması ve tarımsal istihdam::p.46
# ...

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Water"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# Kullanılabilir su kaynağı, yararlanma miktarı
# Tarımda kullanılan su miktarı, hane kullanım miktarı, sanayi kullanım miktarı
# Sulamaya açık tarım alanı
# Sulamaya açılan tarım alanı
# Sulama sistemleri kullanımı
# Sulama sistemleri maliyeti, verimliliği (karbon eşdeğeri)
# Out:
# Water 112 milyar m3 kullanılabilir su kaynağından yararlanma oranı yaklaşık %39 olup, bu kaynağın yaklaşık 32 milyar m3 ‘ü (%73) sulamada, geri kalan ise içme/kullanım ile sanayide::p.86
# Water sulama sistemlerinin toplam içindeki payları::p.87
# Water GAP ile sulamaya açılan alanları::p.89
# Water hibe desteği ile alınan hareketli başlıklı yağmurlama sulama sistem::p.90
# Water Sulama sistemleri içinde kurulum (enerjisi) karbon eşdeğeri/ha olarak en fazla yağmurlama::p.92
# Water sulamaya açılmıştır::p.342
# Water Sulanan arazi miktarı::p.31
# Water AQUASTAT verilerine göre Türkiye’de 2019 yılında toplam su kullanımının yaklaşık %84,7’si tarım sektörü tarafından gerçekleştirilmiştir. Şekil 2’den de izlenebileceği gibi bu oran 2000’li yıllar boyunca %80’in üzerinde seyretmiştir.::p.128

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Land Security"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# Kişi başına düşen ortalama (bölgesel, ulusal) tarımsal arazi, çiftçi ailesi başına düşen tarımsal arazi
# Topraksız aileler sayısının çiftçi ailelere oranı
# Toprak sahibi ailelerin arazi kullanım durumu
# Bölgeye göre tarımsal arazi sahipliği durumu
# Toprak sahipliğini kaybedenler (yıllara göre toprak sahibi sayısı)
# Farklı mülkiyet biçimleri (ortak aile, kooperatif, kiracı)
# Out:
# Land Security kişi başına düşen ortalama tarımsal arazi miktarları::p.154
# Land Security Topraksız aileler sayısının çiftçi ailelerine oranı::p.337
# Land Security we thought that ownership issues might have an impact on farmers’ land allocation decisions::p.12214
# Land Security Çiftçilikle uğraşanların tamamının kendi toprağı vardır.::p.14
# Land Security toprağını tamamen kaybeden ve tarımsal işçi durumuna düşenler::p.32
# Land Security mülkiyet biçimleri::p.31
# Land Security Çiftçi ailesi başına düşen tarım alanı::p.173

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Autonomy"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# Bütçe yönetimine dair bilgi ve eğitime erişimi
# Kooperatif dışı çiftçi ailelerin iş birliği durumu
# Çiftçi ailelerin ürün işleme tesisi sahipliği
# Çiftçilerin sermaye birikim durumu
# Çiftçi ailelerin pazarlama kapasitesi
# Out:
# Autonomy Köylülerin kendi plan, bütçelerini ve programlarını hazırlayıp::p.138
# Autonomy karşılıklı kritik yapma ve yardımlaşma::p.138
# Autonomy sahip olduğu tesislerde::p.200
# Autonomy farmers’ experience, age, education, or similar social factors may be considered::p.12217
# Autonomy farmer's training:.p.207
# Autonomy sermaye birikimi::p.23
# Autonomy işleme/ pazarlama kapasitesi::p.114

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Regional"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# Destekleme politikalarının bölgesel değişimi
# Bölgesel tarım üretiminin ülke içindeki payı
# Bölgede bulunan ortalama arazi miktarı, işletme sayısı, kredi kullanım durumu
# Bölgeye göre hayvansal ve bitkisel üretim değişimi
# Bölgeye göre sulanan, sulanmayan, ekilen, nadasa bırakılan, tarıma elverişli arazi miktarı
# Bölgeye göre tarımda mekanizasyon düzeyi
# Bölgedeki işgücü ve istihdam
# Out:
# Regional bazı illerde da­ ha belirgin olarak ortaya çıkmaktadır::p.441
# Regional the impact of a support policy may vary considerably between farmers and regions::p.12205
# Regional 2002 yılında GAP Bölgesi'nde yapılan ihracatın ülke geneli içindeki payı::p.341
# Regional bölgede bulunan tarımsal işletme sayısı, işletmelerin arazi miktarları, parçalılık durumu, işletmelerin kredi kaynakları, hane halkı ortaklığı, işletmelerde çalışan kişilerin eğitimi, kişi sayısı, yaşları ve cinsiyetleri; hayvansal ve bitkisel üretimi bakımından tarımsal işletmelerin üretim cinsleri ve üretime ayırdıkları arazi miktarları; bitkisel üretim yapan işletmelerde sulanan, sulanmayan, ekilen, nadasa bırakılan, tarıma elverişli olan arazi miktarları, üretim desenleri ve işletmelerdeki tarımsal mekanizasyon düzeyi::p.340
# Regional Bölgesel Gayrisafi Hasıla'nın, Gayrısafi yurtiçi hasıla içindeki payı::p.341
# Regional bölgedeki işgücü ve istihdam::p.34

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Network"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# Tarıma Dayalı İhtisas Organize Sanayi Bölgelerine uzaklık
# Ziraat ve zirai tesislerinin dağılımı (girdi satış yeri, tohum, depolama)
# İşleme tesislerinin uzaklığı
# Bölgesel fiyat farklılıkları
# Gıda sanayi ve gıda dışı tarım sanayi
# Out:
# Network <<TDİOSB'ler>>Bursa Ovası ve Yenişehir Ovası 2000 yılı ve öncesi şeftali, zeytin ya da sebze bahçesi olarak kullanılan tarımsal alanların yoğunlukta olduğu bir kesit iken (Ünaldı ve ark. 2007); bugün BursaEskişehir karayolu üzerinde yer alan soğuk hava depoları, meyve suyu fabrikalarının yanı sıra 2001 yılında Uludağ (Gürsu) Organize Sanayi Bölgesi ve ardından 2004 yılında Kestel Organize Sanayi Bölgesi (KOSAB) tescilini alması ile iki adet sanayi bölgesi bulunmaktadır.::p.7
# Network veteriner ilaçları, gübre, tohum gibi girdi satış yerleri, her türlü ziraat ve ziraî sanayi tesisleri, fidanlık ve ağaçlıklar, damızlık ve örnek ahır ve ağılları, aşım durakları, ziraat işletmeleri, çiftçi danışmanlığı merkezleri::p.195
# Network sanayi bölgelerine yakın olup::p.140
# Network price variable varies between provinces (in our case, two provinces) and years::p.12208
# Network Sanayi sektörü ve tarım sektörü arasında yakın ilişki::p.18
# ...

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Agroecology"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# Biyoçeşitlilik
# Meraların dağılımı
# Ormanların dağılımı
# Kimyasal kullanımının bölgesel - ürünsel dağılımı
# Atık üretiminin bölgesel - ürünsel dağılımı
# Tarım tesislerinin çevresek temizliğine yönelik durumlar
# Out:
# Agroecology biyolojik çeşitlilik::p.604
# Agroecology mera varlığı, “Türkiye Geneli Mera Tespit ve Tahdit Çalışmaları::p.212
# Agroecology “OrmanNesne” özellik tipi, “OrmanAlanlari”, “OrmanYangin” ve “2bAlanlari” özellik tiplerini kapsamaktadır. 6831 sayılı Orman Kanunu’nun tanımları::p.215
# Agroecology Tarımsal üretimde kimyasala en az başvurulan bölge olma özelliğini de taşımaktadır::p.42
# Agroecology Less waste::p.320
# Agroecology İşletmeler Çevresel Temizliğe::p.65

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Scale"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# Tarımsal işletmenin ölçeği - ciro
# Tarımsal işletmenin çalışan sayısı
# Ölçek ekonomisine göre verimlilik düzeyi
# İşletme ölçeğine göre sayılar ve sahip oldukları arazi miktarları
# Out:
# Scale model of the farmer::p.12209
# Scale işletmelerin bölünmüşlüğü::p.23
# Scale kırsal alandaki işletmeler 6-7 kişilik bireylerden oluşmakta::p.35
# Scale ölçek ekonomisinin tarımsal üretim araçlarına ve üretime olan etkisi araştırılmaktadır::p.196
# Scale küçük ve küçük orta ölçekli tarımsal işletmelerin sayısındaki azalmayla birlikte orta büyük ve büyük işletmelerin sayısında ve tasarrufunda bulundukları arazilerin oranında artış olarak gerçekleşmiştir. 1990’ların başından itibaren 5 hektara kadar araziyi tasarrufunda bulunduran işletmelerin sayısında süreklilik gösteren azalışa 2000’li yıllarda 20 hektarın üzerindeki araziyi tasarrufunda bulunduran işletmelerin sayısında artış eşlik etmiştir.::p.126

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Spatial"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# Köylerin merkeze olan uzaklıkları ile gelişmişlik düzeyi arasındaki ilişki
# Köylerin kurulduğu alanın yükseltisi
# Köylerin arazi yapısı - engebe ve dağlık alanlar durumu
# Uydu sensörleri
# Out:
# Spatial kuruluş yerleri ve merkeze olan uzaklıkları ile yerleşmelerin gelişimi arasında bir ilişki var mıdır::p.138
# Spatial kurulduğu alanların yükseltisi::p.139
# Spatial köylerin arazi yapısı::p.153
# Spatial TARBİL Projesi için kullanılan sensör verileri, 5403 sayılı Kanun’un yüklediği arazi kullanım planlaması ve arazi sınıflandırması sorumluluğunu yeterli derecede karşılamamaktadır... Dolayısıyla, TARBİL çalışmalarına toprak sınıflandırmasında önemli yer tutan analitik verileri üretebilecek optik, jeoelektrik, mekanik ve elektrokimyasal sensörlerin de dahil edilmesi gerekmektedir.::p.213
# Spatial Dağlık alanlar::p.114

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Tech Capital"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# Çiftçi ailelerinin tarımda mekanizasyon oranı (bölgesel), üreticinin traktör alım gücü
# Mekanizasyon ölçekleri: birim alan güç tüketimi, hektara düşen traktör, traktör başına düşen tarım iş makinası, enerji çeşitliliği, traktör kullanım süresi
# Traktör başına düşen tarımsal işçi
# ARGE yatırımı
# Hayvancılıkta mekanizasyon
# Out:
# Tech Capital çiftçilerin %9,6’sında traktör bulunmakta..Genelde geleneksel tarımsal üretim yapıldığından ve dağlık arazi yapısı modern tarımsal araçların kullanımını azaltmaktadır::p.15
# Tech Capital Tarımsal mekanizasyon düzeyi çeşitli veriler ile açıklanmaktadır. Bunlar, birim alandaki güç tüketimi, hektara düşen traktör sayısı, traktör başına düşen tarımsal alan, traktör başına düşen tarım iş makinası ağırlığı, tarımsal kesimde kullanılan enerji çeşitliliği, traktör kullanım süresi ve üreticinin traktör alım gücü, tarım makinalarının araştırmalarına ayrılan parasal olanak ve tarımda çalışan birim insan gücünün üretim değeri gibi verilerdir::p.343
# Tech Capital birim alana düşen mekanik güç büyüklüğü (kw/hA)::p.343
# Tech Capital tarımda yeni teknolojiler::p.27
# Tech Capital süt üretiminde makine kullanımı sayısı artışı - <<tarımda makine kullanımı, traktör sayıları>>::p.203

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Food Sovereignty"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# Arz açığı olan ürünler
# İhracat-ithalat dengesinin gıda-sanayi tarım maddelerine göre dağılımı (bölgesel, ulusal)
# Yerli tohum üretiminde ARGE ve yerel girişimler
# Hayvansal gıdanın ithalat-ihracat dengesi
# Out:
# Food Sovereignty arz açığı olan ürünlere::p.27
# Food Sovereignty Tarımsal ürünler içinde gıda maddelerinde ticaret fazlası verilirken, tarımsal hammaddelerde ithalat ihracattan fazla gerçekleşmiştir::p.8
# Food Sovereignty More expensive::p.320
# Food Sovereignty İthal/İhraç edilen tarımsal ürünler::p.41
# Food Sovereignty 2010 yılında 780 000 ton kırmızı et üretilmiş ve 160 000 ton kırmızı et ithal edilmiştir::p.38

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Cooperative"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# Tarımsal amaçlı kooperatifler ?
# Tarım satış kooperatiflerinin alış-satış miktarı
# Tarım kredi kooperatiflerinin kredi-faiz miktarı
# Çiftçilerin kooperatif üyeliği oranı
# Kooperatifleşme kapasitesi
# Üretici birlikleri
# Out:
# Cooperative  Tarımsal Amaçlı Kooperatifler , Tarım Satış Kooperatifleri , Tarım Kredi Kooperatifleri::p.197
# Cooperative Bölgede kütlü pamuk rekoltesinin yaklaşık %40’ını alarak::p.200
# Cooperative çiftçilerin çok azı %16,8’i kooperatif üyesidir::p.15
# Cooperative kooperatifleşme kapasitesi::p.218
# Cooperative üretici birliklerini::p.116

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Husbandry"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# Hayvanlığın mera-tesis oranı
# Meraların otlatma kapasitesi
# Büyükbaş, küçükbaş, kümes hayvan sayıları ve üretim miktarları
# Out:
# Husbandry hayvancılık yönetimi::p.130
# Husbandry hayvancılık genellikle meraya dayalı ekstansif olarak::p.343
# Husbandry Her mera alanı için, otlatma hakkı ve kapasitesi, tahsis bilgileri ve büyükbaş hayvan birimi gibi nitel ve nicel veriler öznitelik olarak eklenmiştir::p.215
# Husbandry Büyükbaş Hayvan Sayıları ve Üretim Miktarları::p.38
# Husbandry Küçükbaş Hayvan Sayıları ve Üretim Miktarları::p.39

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Seed Sovereignty"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# Yerel tohum oranı, bitkisel türe göre yerel tohum oranı
# Sertifikalı tohum oranı ve ilgili kontrol ve destek politikaları
# Çiftçilerin tohum marketine ulaşım durumu
# Out:
# Seed Sovereignty yerel bir ürün::p.137
# Seed Sovereignty sertifikalı tohum uygulamasının arttırılmasına yönelik desteklerdir::p.603
# Seed Sovereignty local wheat producing farmers::p.314
# Seed Sovereignty farmer’s gross profit would be dependent on terms of access to seeds::p.936

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Farmer Dynamics"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# Gelişmiş ülkelerde çiftçilerin durumu
# Çiftçilerin erişimi
# Çiftçilerin işletme ölçeğine göre mülkiyet dağılımı
# Out:
# Farmer Dynamics Türkiye’nin azgelişmiş bir ülke olmasının getirdiği sosyo-ekonomik ve kültürel özelliklere bağlı olarak ortaya çıktığı da söylenebilir. Bu özelliklerden bazıları, tarımın yaygın olarak küçük üreticiliğe dayalı olması, küçük ve parçalı arazi yapısı, tarımsal üreticilerin, tarımsal teknik ve becerilerindeki yetersizlikler::p.590
# Farmer Dynamics easy access to the product::p.320
# Farmer Dynamics işletme ölçeğine göre mülkiyet dağılımı::p.33

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Ethnicity"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# Bölgesel etnik karakter ile ekonomik gelişmişlik düzeyi
# İsimleri değişen köyler - şehirler
# Out:
# Ethnicity etnik ya da dinsel karakteri ile ekonomik faaliyet ve gelişmişlik düzeyi::p.138
# Ethnicity köylerin eski isimleri genellikle Süryanice ve Kürtçe kökenlidir.::p.148

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Gender"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# Cinsiyet eşitliği, ekonomik durumu
# Out:
# Gender toplumsal cinsiyet farkındalığı::p.130
# Gender cinsiyete dayalı ayrım da gözetilerek::p.37

# %%
for index, row in variables_df[variables_df["FSoI_Class"] == "Income"].iterrows():
  print(row["FSoI_Class"], row["Annotation"])

# Gelir düzeyleri - tarımsal ve ulusal
# Out:
# Income gelir düzeyi::p.155

# %%
print("national research variable count:", len(variables_df[variables_df["FSoI_Class"] != "OUT"]), "\n")

print("Variable counts in each category:", variables_df['FSoI_Class'].value_counts())
# Out:
# national research variable count: 251
#
# Variable counts in each category: FSoI_Class
# Land Use             28
# Governance           23
# OUT                  22
# Ecology              19
# Market               18
# Household            17
# Rural Development    16
# Crop Type            13
# Costs                12
# Finance              12
# Demography           11
# Water                 8
# Land Security         7
# Autonomy              7
# Regional              6
# Network               6
# Agroecology           6
# Scale                 5
# Spatial               5
# Tech Capital          5
# Food Sovereignty      5
# Cooperative           5
# Husbandry             5
# Seed Sovereignty      4
# Farmer Dynamics       3
# Ethnicity             2
# Gender                2
# Income                1
# Name: count, dtype: int64
